# %% [markdown]
# ## 2nd Model : 2 Hidden Layers
# - Network Architecture:
#     - 2 hidden layers
#     - RelU Activation on Hidden
#     - Sigmoid Activation on Output
#     - learning rate = 0.01
#     - epoch = 500

# %% [markdown]
# ## Steps:
# 1. Import Libraries
# 2. Read Data from `\Dataset` folder (Retrieved from UCI Repositories)
# 3. Clean Dataset (rename and format the column)
# 4. Data Preprocessing
# 5. Initialize the model
# 6. Train and test the data
# 7. Evaluate Performance using graph

# %% [markdown]
# ### 0. Install Library Requirements

# %%
# %pip install jupyter numpy pandas matplotlib seaborn tabulate imblearn

# %% [markdown]
# ### 1. Import Libraries
# Import necessary libraries:
# * `numpy`     : High performance array object
# * `pandas`    : Data analysis and manipulation tools
# * `matplotlib`: Data visualizations
# * `seaborn`   : Data visualizations framework based on **matplotlib**
# * `tabulate`  : Pretty-print tabular structure library
# * `imblearn`  : SMOTE class balance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
import seaborn as sns

# %% [markdown]
# #### 1.1 Helper Functions
# * Handle mathematical operation used in the `NeuralNetwork` Class

# %%
def sigmoid(x): return 1 /(1 + np.exp(-x))
def relu(x): return np.maximum(0,x)
def derivative_relu(relu_x): return (relu_x>0).astype(float)
def binary_cross_entropy(y_true, y_pred, epsilon=1e-15):
    # Clip predictions to prevent log(0)
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
    return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))

# %% [markdown]
# ### 2. Read and Display Dataset Information
# load the dataset and understand the data, and use the Interquartile Range (IQR) method to identify potential outliers in numerical columns.
# 2.1 Read dataset

# %%
def read_file(file_path: str):
    df = pd.read_csv(file_path)
    new_columns = [col.strip().replace('  ', ' ').replace(' ', '_').lower() for col in df.columns]
    df.columns = new_columns
    return df

path = r'..\Dataset\Customer Churn.csv'
df = read_file(path)
df.head(20)
# Out:
#     call_failure  complains  subscription_length  charge_amount  \
# 0              8          0                   38              0
# 1              0          0                   39              0
# 2             10          0                   37              0
# 3             10          0                   38              0
# 4              3          0                   38              0
# 5             11          0                   38              1
# 6              4          0                   38              0
# 7             13          0                   37              2
# 8              7          0                   38              0
# 9              7          0                   38              1
# 10             6          0                   38              0
# 11             9          0                   38              0
# 12            25          0                   38              3
# 13             4          0                   38              1
# 14             9          0                   37              0
# 15             3          0                   37              1
# 16             0          0                   37              0
# 17             2          0                   38              0
# 18             0          0                   37              0
# 19             3          0                   37              0
#
#     seconds_of_use  frequency_of_use  frequency_of_sms  \
# 0             4370                71                 5
# 1              318                 5                 7
# 2             2453                60               359
# 3             4198                66                 1
# 4             2393                58                 2
# 5             3775                82                32
# 6             2360                39               285
# 7             9115               121               144
# 8            13773               169                 0
# 9             4515                83                 2
# 10            5918                95                 7
# 11            2238                54                 8
# 12           15140               225                54
# 13            3095                27               483
# 14           15485               182               150
# 15            6500                86               186
# 16             875                14                 0
# 17             710                14                13
# 18               0                 0                 0
# 19            7508               127               384
#
#     distinct_called_numbers  age_group  tariff_plan  status  age  \
# 0                        17          3            1       1   30
# 1                         4          2            1       2   25
# 2                        24          3            1       1   30
# 3                        35          1            1       1   15
# 4                        33          1            1       1   15
# 5                        28          3            1       1   30
# 6                        18          3            1       1   30
# 7                        43          3            1       1   30
# 8                        44          3            1       1   30
# 9                        25          3            1       1   30
# 10                       12          3            1       1   30
# 11                       17          3            1       2   30
# 12                       32          3            1       1   30
# 13                        8          3            1       1   30
# 14                       30          2            1       1   25
# 15                       26          3            1       1   30
# 16                       11          2            1       2   25
# 17                        8          3            1       2   30
# 18                        0          2            1       2   25
# 19                       43          2            1       1   25
#
#     customer_value  churn
# 0          197.640      0
# 1           46.035      0
# 2         1536.520      0
# 3          240.020      0
# 4          145.805      0
# 5          282.280      0
# 6         1235.960      0
# 7          945.440      0
# 8          557.680      0
# 9          191.920      0
# 10         268.520      0
# 11         123.680      0
# 12         830.600      0
# 13        2056.880      0
# 14        1380.015      0
# 15        1007.440      0
# 16          40.005      1
# 17          80.960      0
# 18           0.000      1
# 19        2071.575      0

# %% [markdown]
# 2.2 Display dataset data types and null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_failure             3150 non-null   int64
#  1   complains                3150 non-null   int64
#  2   subscription_length      3150 non-null   int64
#  3   charge_amount            3150 non-null   int64
#  4   seconds_of_use           3150 non-null   int64
#  5   frequency_of_use         3150 non-null   int64
#  6   frequency_of_sms         3150 non-null   int64
#  7   distinct_called_numbers  3150 non-null   int64
#  8   age_group                3150 non-null   int64
#  9   tariff_plan              3150 non-null   int64
#  10  status                   3150 non-null   int64
#  11  age                      3150 non-null   int64
#  12  customer_value           3150 non-null   float64
#  13  churn                    3150 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 344.7 KB

# %% [markdown]
# 2.3 Display dataset shape and its statisical values

# %%
df.describe()
# Out:
#        call_failure    complains  subscription_length  charge_amount  \
# count   3150.000000  3150.000000          3150.000000    3150.000000
# mean       7.627937     0.076508            32.541905       0.942857
# std        7.263886     0.265851             8.573482       1.521072
# min        0.000000     0.000000             3.000000       0.000000
# 25%        1.000000     0.000000            30.000000       0.000000
# 50%        6.000000     0.000000            35.000000       0.000000
# 75%       12.000000     0.000000            38.000000       1.000000
# max       36.000000     1.000000            47.000000      10.000000
#
#        seconds_of_use  frequency_of_use  frequency_of_sms  \
# count     3150.000000       3150.000000       3150.000000
# mean      4472.459683         69.460635         73.174921
# std       4197.908687         57.413308        112.237560
# min          0.000000          0.000000          0.000000
# 25%       1391.250000         27.000000          6.000000
# 50%       2990.000000         54.000000         21.000000
# 75%       6478.250000         95.000000         87.000000
# max      17090.000000        255.000000        522.000000
#
#        distinct_called_numbers    age_group  tariff_plan       status  \
# count              3150.000000  3150.000000  3150.000000  3150.000000
# mean                 23.509841     2.826032     1.077778     1.248254
# std                  17.217337     0.892555     0.267864     0.432069
# min                   0.000000     1.000000     1.000000     1.000000
# 25%                  10.000000     2.000000     1.000000     1.000000
# 50%                  21.000000     3.000000     1.000000     1.000000
# 75%                  34.000000     3.000000     1.000000     1.000000
# max                  97.000000     5.000000     2.000000     2.000000
#
#                age  customer_value        churn
# count  3150.000000     3150.000000  3150.000000
# mean     30.998413      470.972916     0.157143
# std       8.831095      517.015433     0.363993
# min      15.000000        0.000000     0.000000
# 25%      25.000000      113.801250     0.000000
# 50%      30.000000      228.480000     0.000000
# 75%      30.000000      788.388750     0.000000
# max      55.000000     2165.280000     1.000000

# %% [markdown]
# 2.4. Detect Outliers

# %%
def detect_outliers_iqr(df, k=1.5):
    nums = df.select_dtypes(include='number')
    outlier_info = {}
    
    for c in nums.columns:
        #skip binary columns
        if(nums[c].nunique() <= 2):
            continue
        
        q1 = nums[c].quantile(0.25) #1st quartile
        q3 = nums[c].quantile(0.75) #3rd quartile
        iqr = q3 - q1
        lower = q1 - k * iqr
        upper = q3 + k * iqr
        mask = (nums[c] < lower) | (nums[c] > upper)
        outlier_info[c] = {
            'count': int(mask.sum()),
            'indices': nums.index[mask].tolist(),
            'lower': float(lower),
            'upper': float(upper)
        }
    return outlier_info

outliers = detect_outliers_iqr(df)
table_data = []
print('\nOutlier summary (IQR method):')
for col, info in outliers.items():
    if info['count'] > 0:
    # Calculate percentage
        perc = (info["count"] / len(df)) * 100
        
        # Add a list (row) to our table_data
        table_data.append([col, info["count"], f"{info['lower']:.3f}",
            f"{info['upper']:.3f}", f"{perc:.2f}%"])
headers = ["Column", "Outlier Count", "Lower Bound", "Upper Bound", "Percentage"]
print(tabulate(table_data, headers=headers))
# Out:
# Outlier summary (IQR method):
# Column                     Outlier Count    Lower Bound    Upper Bound  Percentage
# -----------------------  ---------------  -------------  -------------  ------------
# call_failure                          47         -15.5           28.5   1.49%
# subscription_length                  282          18             50     8.95%
# charge_amount                        370          -1.5            2.5   11.75%
# seconds_of_use                       200       -6239.25       14108.8   6.35%
# frequency_of_use                     129         -75            197     4.10%
# frequency_of_sms                     368        -115.5          208.5   11.68%
# distinct_called_numbers               77         -26             70     2.44%
# age_group                            170           0.5            4.5   5.40%
# age                                  688          17.5           37.5   21.84%
# customer_value                       116        -898.08        1800.27  3.68%

# %% [markdown]
# ### 3. Data Cleaning
# This process take step before handling with outliers and data preprocessing.
#
# 3.1 Remove Duplicate Row (if any)

# %%
df = df.drop_duplicates()
print(f'\n[Changes] Removed duplicate rows. New shape={df.shape}\n')
# Out:
# [Changes] Removed duplicate rows. New shape=(2850, 14)

# %% [markdown]
# 3.2 Remove Redundant Groups
#
# `age_group` and `age` columns both have the same values but in different types, numeric and nominal respectively.
# `age_group` column is dropped to prevent biases when learning

# %%
df = df.drop(columns=['age_group'])
print(f'\n[Changes] Dropped column: age_group due to redundancy. New shape={df.shape}\n\n')
# Out:
# [Changes] Dropped column: age_group due to redundancy. New shape=(2850, 13)

# %% [markdown]
# ### 4. Data Preprocessing
#
# The dataset will follows the exact steps to avoid any imbalance or data leakage during testing.

# %% [markdown]
# [Split] -> [Log] -> [Encode] -> [Fit] -> [Scale] -> [Balance]

# %% [markdown]
# #### 4.1 Split
#
# * Splitting the dataset into train, and test sets, and both input,X and output,Y
# * This function will reset the intialized index of X and Y dataset, and shuffle them before splitting to prevent **data leakage**
#
# @function `split_data()`:
# * params
#     * `X`, `y` as input and output
#     * `test_split` as testing split percentage ; default `0.2`
#     * `randomness` as random values for randomize dataset index before splitting ; default `None`
# * return
#     * `X_train` = Training set without `Churn`
#     * `Y_train` = `Churn` Training column
#     * `Y_train` = Testing set without `Churn`
#     * `Y_test` = `Churn` Testing column

# %%
def split_data(X, y, test_split=0.2, randomness=None):
    # Set seed for reproducibility
    if randomness is not None:
        np.random.seed(randomness)
    
    # reset X and Y current index
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    
    # Identify unique classes and their indices (0 and 1)
    unique_classes = np.unique(y)
    train_indices = []
    test_indices = []
    
    for cls in unique_classes:
        # Get indices of rows belonging to this class
        cls_indices = np.where(y == cls)[0]

        # Shuffle indices within this specific class
        np.random.shuffle(cls_indices)

        # Determine the split point
        total_count = len(cls_indices)
        test_count = int(total_count * test_split)
        
        # Split indices
        cls_test = cls_indices[:test_count]
        cls_train = cls_indices[test_count:]
        
        # Add to main lists
        test_indices.extend(cls_test)
        train_indices.extend(cls_train)
        
    # Shuffle the final combined indices so they aren't grouped by class
    np.random.shuffle(train_indices)
    np.random.shuffle(test_indices)
    
    # Use .iloc for DataFrames to select the rows
    X_train, X_test = X.iloc[train_indices], X.iloc[test_indices]
    y_train, y_test = y.iloc[train_indices], y.iloc[test_indices]
    return X_train, X_test, y_train, y_test

X = df.drop(columns=['churn'], axis=1)
Y = df['churn']
X_train,X_test,y_train,y_test = split_data(X,Y,test_split=0.2, randomness=42)
print(f'[Changes] Successfully split data into Training and Testing.')
# Out:
# [Changes] Successfully split data into Training and Testing.

# %% [markdown]
# #### 4.2 Log Transformation
#
# * This will treat the outliers found before, compressing all the values within the dataset to **reduce** the skewness of the data
# * This step is to prevent unfair patterns.
# * Use `numpy.log(1 + x)`
# * log transformation on seperated train and test set to prevent **data leakage**
#
# @function `log_transformation()`:
# * params
#     * `df_train`, `df_test` as training and testing dataset
#     * `cols_log` as list of column to be log transformed
# * return
#     * `df_train` = train dataset that have been log transformed
#     * `df_test` = test dataset that have been log transformed

# %%
def log_transformation(df_train, df_test, cols_log: list):
    for col in cols_log:
        df_train[col] = np.log1p(df_train[col])
        df_test[col] = np.log1p(df_test[col])
    print(f'[Changes] Applied log transformation to selected columns.')
    return df_train, df_test

cols_to_log = [
    'seconds_of_use',
    'frequency_of_use',
    'frequency_of_sms',
    'distinct_called_numbers',
    'call_failure',
    'customer_value',
    'charge_amount'
]
X_train, X_test = log_transformation(X_train,X_test,cols_to_log)
# Out:
# [Changes] Applied log transformation to selected columns.

# %% [markdown]
# #### 4.3 One-Hot Encoding
#
# * Convert categorical column into multiple, numeric dummy columns that values between `0` and `1`.
# * Example: `plan` have 3 categories  = `[cat1, cat2, cat3]`. It will split into dummy columns for each category, `plan_cat1`, `plan_cat2`, `plan_cat3`
# * use drop first column attribute to prevent **multicollinearity**
#
# @function `get_train_category()`:
# * params
#     * `df` as dataset
#     * `col_name` retrieve category from this column
# * return
#     * `list` = list of column name
#
#
# @function `one_hot_encoding()`:
# * params
#     * `df` as dataset
#     * `col_name` as column name that will apply one-hot encoding
#     * `categories` as category inside `col_name`
#     * `drop_first` drop first column to simplify the dummy column
# * return
#     * `converted_pd` = return the dataframe with the added dummy columns

# %%
def get_train_categories(df, col_name):
    return sorted(list(set(df[col_name].tolist())))

def one_hot_encoding(df, col_name:str, categories, drop_first = True):
    data = df[col_name].tolist()
    
    active_cats = categories[1:] if drop_first and len(categories) > 1 else categories
    
    encoded_mtx = []
    for item in data:
        row = [0] * len(active_cats)
        if item in active_cats:
            index = active_cats.index(item)
            row[index] = 1
        encoded_mtx.append(row)
    
    #rename column for one hot encoded column
    new_cols = [f'{col_name}_{cat}' for cat in active_cats]
    #convert back to dataframe
    converted_pd  = pd.DataFrame(encoded_mtx, columns=new_cols,index=df.index)
    return converted_pd

train_encoded_parts = []
test_encoded_parts = []

categorical = ['complains', 'tariff_plan', 'status']
for col in categorical:
    train_categories = get_train_categories(X_train, col)
    train_encoded_parts.append(one_hot_encoding(X_train, col, train_categories, drop_first=True))        
    test_encoded_parts.append(one_hot_encoding(X_test, col, train_categories, drop_first=True))
print(f'[Changes] Applied one hot encoding to categorical columns')

#drop old column and join new columns
X_train = X_train.drop(columns=categorical).join(train_encoded_parts)
X_test = X_test.drop(columns=categorical).join(test_encoded_parts)
# Out:
# [Changes] Applied one hot encoding to categorical columns

# %% [markdown]
# #### 4.4 Scaling Feature
#
# * Transforms features to fit within a specific range, usually `0`, by subtracting the minimum value and dividing by the range `(max - min)`
# * Using `min()` and `max()` function to retrieve the minimum and maximum value in a column
# * Scales the transformation on training data, and transform on train and test dataset to prevent data leakage
#
# @function `get_scaling_params()`:
# * params
#     * `df_train` as training input dataset
# * return
#     * `param_dict` = a dictionary contains the minimum and maximum value for every key column
#
# @function `min_max_transform()`:
# * params
#     * `df` as input dataset
#     * `params` as dicitionary containing min and max value for each column
# * return
#     * `df_scaled` = scaled dataset

# %%
def get_scaling_params(df_train):
    param_dict = {}
    for col in df_train.columns:   
        min_val = min(df_train[col])
        max_val = max(df_train[col])
        param_dict[col] = (min_val, max_val - min_val)
    return param_dict

#eg: min_max_transform(X_TEST, train_min_val, train_data_range)
def min_max_transform(df, params: dict):
    df_scaled = df.copy()

    for col, (min_v, data_range) in params.items():
        if data_range == 0:
            df_scaled[col] = 0.0 #base case float number
        else:
            df_scaled[col] = (df[col] - min_v) / data_range
            
    return df_scaled

X_train_scale_params = get_scaling_params(X_train)
X_train_scaled = min_max_transform(X_train, X_train_scale_params)
X_test_scaled = min_max_transform(X_test, X_train_scale_params)
print(f'[Changes] Applied Min Max Scaler on numerical columns')
# Out:
# [Changes] Applied Min Max Scaler on numerical columns

# %% [markdown]
# #### 4.5 Class Balancing
#
# * The dataset contains around 80% `0` (Not Churn) and 20% `1` (Churn), causing imbalance and can cause the model to become biased, favor the majority class, and perform poorly on the crucial minority class.
# * `SMOTE` is a **oversampling** technique used to create synthetic data using its algorithm to balance the class.
# * Only apply to training data only to prevent data leakage

# %%
# smote = SMOTE(sampling_strategy=0.8, random_state=42)
# X_train_final, y_train_final = smote.fit_resample(X_train_scaled, y_train)
# print(f"Before SMOTE - Class Distribution: {y_train.value_counts()}")
# print(f"After SMOTE - Class Distribution: {pd.Series(y_train_final).value_counts()}")
# print(f"Final training set size: {len(X_train_final)}")

# %% [markdown]
# ### 5. Initialize the Model
#
# #### 5.1 Intialize Variables
# * `EPOCHS`      : Iteration counts
# * `PATIENCE`    : Hyperparameter stopping condition that wait for an improvement
# * `input_dim` = input layer size (nodes)

# %%
EPOCHS = 500
PATIENCE = 100

input_dim = X_train_scaled.shape[1]

# %% [markdown]
# @Class `NeuralNetwork`
# * A multi-layer perceptron (Backpropagation Neural Network) designed for binary classification.
# * He initialization for weight stability, gradient descent, and early stopping based on patience or error thresholds.
#
# @function `feedforward()`:
# * Feed the data forward, [Input] -> w1 -> [Hidden] -> w2 -> [Output]
# * Input to hidden layer will use **ReLU** activation function to handle nonlinear
# * Hidden layer to output layer will use **Sigmoid** activation function to **0 - 1** output
#
# @function `backpropagation()`:
# * Calculates the gradients of the loss function with respect to each weight and bias in the network.
# * Uses Gradient Clipping (max value of 5.0) to prevent exploding gradients and stability.
# * Updates weight1, weight2, bias1, and bias2 using the calculated deltas and the learning rate (`alpha`).
#
# @function `train()`
# * Manages the entire learning process over a set number of EPOCHS using  Gradient Descent.
# * Shuffles the training data every epoch to improve generalization and prevent the model from learning the order of the data.
# * Stopping Condition:
#     * `max_error`
#     * `patience`
#
# @function `calculate_accuracy()`
# * Computes the percentage of correct predictions by comparing predicted probabilities against true labels
# * 0.5 threshold to convert sigmoid probabilities into binary classes (0 or 1).
#
# @function `predict()`
# * Performs a final feedforward pass on unseen data to generate class predictions.
# * Flattens the final output and applies a boolean threshold (0.5) to return integer class labels.

# %%
class NeuralNetwork:
    def __init__(self, input_dimension, hidden1_nodes=16, hidden2_nodes=8, alpha=0.01):
        self.alpha = alpha
        self.weight1 = np.random.randn(input_dimension, hidden1_nodes) * np.sqrt(2/input_dimension) #He Initializaion keeps Weight stable
        self.weight2 = np.random.randn(hidden1_nodes, hidden2_nodes) * np.sqrt(2/hidden1_nodes)
        self.weight3 = np.random.randn(hidden2_nodes, 1) * np.sqrt(2/hidden2_nodes)
        self.bias1 = np.zeros((1, hidden1_nodes))
        self.bias2 = np.zeros((1, hidden2_nodes))
        self.bias3 = np.zeros((1, 1))
        
        self.train_loss, self.test_loss, self.train_acc, self.test_acc = [], [], [], []
        self.history = {
            'train_loss': self.train_loss,
            'test_loss': self.test_loss,
            'train_acc': self.train_acc,
            'test_acc': self.test_acc
        }    
        
    def feedforward(self,X):
        self.hidden1_Z = X @ self.weight1 + self.bias1
        self.hidden1_A = relu(self.hidden1_Z)
        self.hidden2_Z = self.hidden1_A @ self.weight2 + self.bias2
        self.hidden2_A = relu(self.hidden2_Z)
        self.output_Z = self.hidden2_A @ self.weight3 + self.bias3
        self.output_A= sigmoid(self.output_Z)
        
        return self.output_A
    
    def backpropagation(self, X, y, output):
        size = y.shape[0] 
        
        d_output = (output - y)
        d_weight3 = self.hidden2_A.T @ d_output / size
        d_bias3 = np.sum(d_output, axis=0, keepdims=True) / size
        
        d_hidden2_A = d_output @ self.weight3.T
        d_hidden2_Z = d_hidden2_A * derivative_relu(self.hidden2_Z)
        d_weight2 = self.hidden1_A.T @ d_hidden2_Z / size
        d_bias2 = np.sum(d_hidden2_Z, axis=0, keepdims=True) / size
        
        d_hidden1_A = d_hidden2_Z @ self.weight2.T
        d_hidden1_Z = d_hidden1_A * derivative_relu(self.hidden1_Z)
        d_weight1 = X.T @ d_hidden1_Z / size
        d_bias1 = np.sum(d_hidden1_Z, axis=0, keepdims=True) / size
        
        #update weights using gradient descent
        self.weight3 -= self.alpha * d_weight3
        self.bias3 -= self.alpha * d_bias3
        self.weight2 -= self.alpha * d_weight2
        self.bias2 -= self.alpha * d_bias2
        self.weight1 -= self.alpha * d_weight1
        self.bias1 -= self.alpha * d_bias1

    def calculate_accuracy(self, y_true, y_pred_prob):
        # Threshold at 0.5 for binary classification
        predictions = (y_pred_prob > 0.5).astype(int)
        correct = np.sum(predictions == y_true)
        return correct / len(y_true)
    
    def train(self, X_train, y_train, X_test, y_test):
        epochs = EPOCHS
        max_error = 0.01
        best_loss = float('inf')
        patience_count = 0
        patience = PATIENCE
        
        X_tr = X_train.values if isinstance(X_train, pd.DataFrame) else X_train
        y_tr = np.array(y_train).reshape(-1, 1)
        X_te = X_test.values if isinstance(X_test, pd.DataFrame) else X_test
        y_te = np.array(y_test).reshape(-1, 1)
        
        n_samples = X_tr.shape[0]
        
        for epoch in range(epochs):
            # Shuffle data each epoch
            indices = np.random.permutation(n_samples)
            X_tr_shuffled = X_tr[indices]
            y_tr_shuffled = y_tr[indices]
            
            # Calculate metrics on full dataset
            output_full = self.feedforward(X_tr)
            self.backpropagation(X_tr, y_tr, output_full)
            
            train_loss = binary_cross_entropy(y_tr, output_full)
            train_acc = np.mean((output_full > 0.5).astype(int) == y_tr) * 100
            
            output_test = self.feedforward(X_te)
            test_loss = binary_cross_entropy(y_te, output_test)
            test_acc = np.mean((output_test > 0.5).astype(int) == y_te) * 100
            
            self.train_loss.append(train_loss)
            self.test_loss.append(test_loss)
            self.train_acc.append(train_acc)
            self.test_acc.append(test_acc)
            
            print(f'Epoch {epoch + 1}/{epochs} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%')
            
            if test_loss < best_loss:
                best_loss = test_loss
                patience_count = 0
            else:
                patience_count += 1
            
            if patience_count >= patience:
                print(f'[Training Stopped] Patience {patience} reached')
                break
            
            if train_loss <= max_error:
                print(f'[Training Stopped] Max error {max_error} reached')
                break
            
        return self.history

    def predict(self, X):
        X_vals = X.values if isinstance(X, pd.DataFrame) else X        
        h1_Z = X_vals @ self.weight1 + self.bias1
        h1_A = relu(h1_Z)
        h2_Z = h1_A @ self.weight2 + self.bias2
        h2_A = relu(h2_Z)
        o_Z = h2_A @ self.weight3 + self.bias3
        probs = sigmoid(o_Z)
        return (probs > 0.5).astype(int).flatten()

# %% [markdown]
# 5.2 Initialize, Train and Predict
#
# * Input Layer : 12 nodes
# * Hidden Layer 1 : 16 nodes
# * Hidden Layer 2 : 8 nodes
# * Learning Rate : 0.01
# * Epochs : 500

# %%
nn = NeuralNetwork(input_dimension= input_dim, alpha=0.01)
history = nn.train(X_train_scaled, y_train, X_test_scaled, y_test)    
y_hat = nn.predict(X_test_scaled)

print('Model finished training and validation.')
# Out:
# Epoch 1/500 | Train Loss: 0.9916 | Train Acc: 15.87% | Test Loss: 0.9393 | Test Acc: 16.52%
# Epoch 2/500 | Train Loss: 0.9334 | Train Acc: 16.48% | Test Loss: 0.8856 | Test Acc: 18.45%
# Epoch 3/500 | Train Loss: 0.8799 | Train Acc: 17.80% | Test Loss: 0.8368 | Test Acc: 20.91%
# Epoch 4/500 | Train Loss: 0.8315 | Train Acc: 19.95% | Test Loss: 0.7935 | Test Acc: 25.31%
# Epoch 5/500 | Train Loss: 0.7883 | Train Acc: 26.48% | Test Loss: 0.7553 | Test Acc: 35.15%
# Epoch 6/500 | Train Loss: 0.7503 | Train Acc: 37.83% | Test Loss: 0.7219 | Test Acc: 48.86%
# Epoch 7/500 | Train Loss: 0.7168 | Train Acc: 51.78% | Test Loss: 0.6929 | Test Acc: 62.39%
# Epoch 8/500 | Train Loss: 0.6878 | Train Acc: 64.58% | Test Loss: 0.6683 | Test Acc: 69.77%
# Epoch 9/500 | Train Loss: 0.6635 | Train Acc: 70.58% | Test Loss: 0.6474 | Test Acc: 71.88%
# Epoch 10/500 | Train Loss: 0.6430 | Train Acc: 73.65% | Test Loss: 0.6302 | Test Acc: 73.29%
# Epoch 11/500 | Train Loss: 0.6261 | Train Acc: 75.67% | Test Loss: 0.6163 | Test Acc: 74.69%
# Epoch 12/500 | Train Loss: 0.6126 | Train Acc: 76.63% | Test Loss: 0.6048 | Test Acc: 75.75%
# Epoch 13/500 | Train Loss: 0.6015 | Train Acc: 77.12% | Test Loss: 0.5951 | Test Acc: 76.45%
# Epoch 14/500 | Train Loss: 0.5920 | Train Acc: 78.04% | Test Loss: 0.5867 | Test Acc: 77.50%
# Epoch 15/500 | Train Loss: 0.5837 | Train Acc: 78.21% | Test Loss: 0.5792 | Test Acc: 77.68%
# Epoch 16/500 | Train Loss: 0.5762 | Train Acc: 78.30% | Test Loss: 0.5723 | Test Acc: 78.03%
# Epoch 17/500 | Train Loss: 0.5694 | Train Acc: 78.61% | Test Loss: 0.5658 | Test Acc: 78.56%
# Epoch 18/500 | Train Loss: 0.5630 | Train Acc: 78.74% | Test Loss: 0.5597 | Test Acc: 79.09%
# Epoch 19/500 | Train Loss: 0.5570 | Train Acc: 79.09% | Test Loss: 0.5539 | Test Acc: 79.44%
# Epoch 20/500 | Train Loss: 0.5511 | Train Acc: 79.57% | Test Loss: 0.5482 | Test Acc: 80.14%
# Epoch 21/500 | Train Loss: 0.5455 | Train Acc: 79.96% | Test Loss: 0.5428 | Test Acc: 81.02%
# Epoch 22/500 | Train Loss: 0.5400 | Train Acc: 80.84% | Test Loss: 0.5376 | Test Acc: 81.37%
# Epoch 23/500 | Train Loss: 0.5348 | Train Acc: 81.50% | Test Loss: 0.5325 | Test Acc: 82.25%
# Epoch 24/500 | Train Loss: 0.5297 | Train Acc: 81.98% | Test Loss: 0.5277 | Test Acc: 82.43%
# Epoch 25/500 | Train Loss: 0.5248 | Train Acc: 82.33% | Test Loss: 0.5231 | Test Acc: 82.60%
# Epoch 26/500 | Train Loss: 0.5202 | Train Acc: 82.51% | Test Loss: 0.5187 | Test Acc: 82.60%
# Epoch 27/500 | Train Loss: 0.5157 | Train Acc: 82.73% | Test Loss: 0.5145 | Test Acc: 82.60%
# Epoch 28/500 | Train Loss: 0.5115 | Train Acc: 83.30% | Test Loss: 0.5104 | Test Acc: 83.13%
# Epoch 29/500 | Train Loss: 0.5074 | Train Acc: 84.13% | Test Loss: 0.5065 | Test Acc: 83.66%
# Epoch 30/500 | Train Loss: 0.5034 | Train Acc: 84.26% | Test Loss: 0.5027 | Test Acc: 84.18%
# Epoch 31/500 | Train Loss: 0.4996 | Train Acc: 84.61% | Test Loss: 0.4991 | Test Acc: 84.71%
# Epoch 32/500 | Train Loss: 0.4960 | Train Acc: 85.05% | Test Loss: 0.4956 | Test Acc: 84.89%
# Epoch 33/500 | Train Loss: 0.4925 | Train Acc: 84.88% | Test Loss: 0.4922 | Test Acc: 85.06%
# Epoch 34/500 | Train Loss: 0.4891 | Train Acc: 85.23% | Test Loss: 0.4890 | Test Acc: 85.06%
# Epoch 35/500 | Train Loss: 0.4859 | Train Acc: 85.23% | Test Loss: 0.4859 | Test Acc: 85.41%
# Epoch 36/500 | Train Loss: 0.4828 | Train Acc: 85.40% | Test Loss: 0.4829 | Test Acc: 85.24%
# Epoch 37/500 | Train Loss: 0.4798 | Train Acc: 85.31% | Test Loss: 0.4800 | Test Acc: 84.89%
# Epoch 38/500 | Train Loss: 0.4769 | Train Acc: 85.23% | Test Loss: 0.4772 | Test Acc: 84.89%
# Epoch 39/500 | Train Loss: 0.4741 | Train Acc: 85.23% | Test Loss: 0.4745 | Test Acc: 84.53%
# Epoch 40/500 | Train Loss: 0.4714 | Train Acc: 85.31% | Test Loss: 0.4719 | Test Acc: 84.53%
# Epoch 41/500 | Train Loss: 0.4688 | Train Acc: 85.27% | Test Loss: 0.4694 | Test Acc: 84.53%
# Epoch 42/500 | Train Loss: 0.4663 | Train Acc: 85.44% | Test Loss: 0.4670 | Test Acc: 84.71%
# Epoch 43/500 | Train Loss: 0.4639 | Train Acc: 85.40% | Test Loss: 0.4647 | Test Acc: 84.71%
# Epoch 44/500 | Train Loss: 0.4616 | Train Acc: 85.40% | Test Loss: 0.4624 | Test Acc: 84.36%
# Epoch 45/500 | Train Loss: 0.4593 | Train Acc: 85.49% | Test Loss: 0.4603 | Test Acc: 84.36%
# Epoch 46/500 | Train Loss: 0.4571 | Train Acc: 85.44% | Test Loss: 0.4582 | Test Acc: 84.53%
# Epoch 47/500 | Train Loss: 0.4550 | Train Acc: 85.40% | Test Loss: 0.4561 | Test Acc: 84.89%
# Epoch 48/500 | Train Loss: 0.4530 | Train Acc: 85.36% | Test Loss: 0.4542 | Test Acc: 84.71%
# Epoch 49/500 | Train Loss: 0.4510 | Train Acc: 85.27% | Test Loss: 0.4523 | Test Acc: 84.71%
# Epoch 50/500 | Train Loss: 0.4491 | Train Acc: 85.27% | Test Loss: 0.4504 | Test Acc: 84.53%
# Epoch 51/500 | Train Loss: 0.4472 | Train Acc: 85.14% | Test Loss: 0.4486 | Test Acc: 84.71%
# Epoch 52/500 | Train Loss: 0.4454 | Train Acc: 84.96% | Test Loss: 0.4469 | Test Acc: 84.89%
# Epoch 53/500 | Train Loss: 0.4437 | Train Acc: 84.96% | Test Loss: 0.4452 | Test Acc: 84.53%
# Epoch 54/500 | Train Loss: 0.4420 | Train Acc: 84.83% | Test Loss: 0.4436 | Test Acc: 84.53%
# Epoch 55/500 | Train Loss: 0.4404 | Train Acc: 84.74% | Test Loss: 0.4420 | Test Acc: 84.53%
# Epoch 56/500 | Train Loss: 0.4388 | Train Acc: 84.66% | Test Loss: 0.4404 | Test Acc: 84.36%
# Epoch 57/500 | Train Loss: 0.4372 | Train Acc: 84.61% | Test Loss: 0.4389 | Test Acc: 84.36%
# Epoch 58/500 | Train Loss: 0.4357 | Train Acc: 84.61% | Test Loss: 0.4375 | Test Acc: 84.53%
# Epoch 59/500 | Train Loss: 0.4342 | Train Acc: 84.61% | Test Loss: 0.4361 | Test Acc: 84.53%
# Epoch 60/500 | Train Loss: 0.4328 | Train Acc: 84.61% | Test Loss: 0.4347 | Test Acc: 84.53%
# Epoch 61/500 | Train Loss: 0.4314 | Train Acc: 84.61% | Test Loss: 0.4334 | Test Acc: 84.53%
# Epoch 62/500 | Train Loss: 0.4301 | Train Acc: 84.66% | Test Loss: 0.4321 | Test Acc: 84.53%
# Epoch 63/500 | Train Loss: 0.4288 | Train Acc: 84.66% | Test Loss: 0.4308 | Test Acc: 84.36%
# Epoch 64/500 | Train Loss: 0.4275 | Train Acc: 84.66% | Test Loss: 0.4295 | Test Acc: 84.36%
# Epoch 65/500 | Train Loss: 0.4262 | Train Acc: 84.66% | Test Loss: 0.4283 | Test Acc: 84.36%
# Epoch 66/500 | Train Loss: 0.4250 | Train Acc: 84.70% | Test Loss: 0.4272 | Test Acc: 84.36%
# Epoch 67/500 | Train Loss: 0.4238 | Train Acc: 84.70% | Test Loss: 0.4260 | Test Acc: 84.36%
# Epoch 68/500 | Train Loss: 0.4226 | Train Acc: 84.70% | Test Loss: 0.4249 | Test Acc: 84.36%
# Epoch 69/500 | Train Loss: 0.4214 | Train Acc: 84.70% | Test Loss: 0.4238 | Test Acc: 84.18%
# Epoch 70/500 | Train Loss: 0.4203 | Train Acc: 84.70% | Test Loss: 0.4227 | Test Acc: 84.18%
# Epoch 71/500 | Train Loss: 0.4192 | Train Acc: 84.70% | Test Loss: 0.4217 | Test Acc: 84.18%
# Epoch 72/500 | Train Loss: 0.4182 | Train Acc: 84.74% | Test Loss: 0.4207 | Test Acc: 84.18%
# Epoch 73/500 | Train Loss: 0.4171 | Train Acc: 84.66% | Test Loss: 0.4197 | Test Acc: 84.18%
# Epoch 74/500 | Train Loss: 0.4161 | Train Acc: 84.66% | Test Loss: 0.4187 | Test Acc: 84.18%
# Epoch 75/500 | Train Loss: 0.4151 | Train Acc: 84.66% | Test Loss: 0.4177 | Test Acc: 84.18%
# Epoch 76/500 | Train Loss: 0.4141 | Train Acc: 84.66% | Test Loss: 0.4168 | Test Acc: 84.18%
# Epoch 77/500 | Train Loss: 0.4131 | Train Acc: 84.66% | Test Loss: 0.4159 | Test Acc: 84.18%
# Epoch 78/500 | Train Loss: 0.4121 | Train Acc: 84.61% | Test Loss: 0.4150 | Test Acc: 84.18%
# Epoch 79/500 | Train Loss: 0.4112 | Train Acc: 84.61% | Test Loss: 0.4141 | Test Acc: 84.18%
# Epoch 80/500 | Train Loss: 0.4103 | Train Acc: 84.61% | Test Loss: 0.4132 | Test Acc: 84.18%
# Epoch 81/500 | Train Loss: 0.4094 | Train Acc: 84.61% | Test Loss: 0.4123 | Test Acc: 84.18%
# Epoch 82/500 | Train Loss: 0.4085 | Train Acc: 84.61% | Test Loss: 0.4115 | Test Acc: 84.18%
# Epoch 83/500 | Train Loss: 0.4076 | Train Acc: 84.61% | Test Loss: 0.4107 | Test Acc: 84.18%
# Epoch 84/500 | Train Loss: 0.4068 | Train Acc: 84.61% | Test Loss: 0.4099 | Test Acc: 84.18%
# Epoch 85/500 | Train Loss: 0.4059 | Train Acc: 84.61% | Test Loss: 0.4091 | Test Acc: 84.18%
# Epoch 86/500 | Train Loss: 0.4051 | Train Acc: 84.61% | Test Loss: 0.4083 | Test Acc: 84.18%
# Epoch 87/500 | Train Loss: 0.4043 | Train Acc: 84.61% | Test Loss: 0.4075 | Test Acc: 84.18%
# Epoch 88/500 | Train Loss: 0.4035 | Train Acc: 84.57% | Test Loss: 0.4068 | Test Acc: 84.18%
# Epoch 89/500 | Train Loss: 0.4026 | Train Acc: 84.52% | Test Loss: 0.4060 | Test Acc: 84.18%
# Epoch 90/500 | Train Loss: 0.4019 | Train Acc: 84.52% | Test Loss: 0.4053 | Test Acc: 84.01%
# Epoch 91/500 | Train Loss: 0.4011 | Train Acc: 84.48% | Test Loss: 0.4046 | Test Acc: 84.01%
# Epoch 92/500 | Train Loss: 0.4003 | Train Acc: 84.48% | Test Loss: 0.4039 | Test Acc: 84.01%
# Epoch 93/500 | Train Loss: 0.3996 | Train Acc: 84.48% | Test Loss: 0.4032 | Test Acc: 84.01%
# Epoch 94/500 | Train Loss: 0.3988 | Train Acc: 84.48% | Test Loss: 0.4025 | Test Acc: 84.01%
# Epoch 95/500 | Train Loss: 0.3981 | Train Acc: 84.48% | Test Loss: 0.4018 | Test Acc: 84.01%
# Epoch 96/500 | Train Loss: 0.3973 | Train Acc: 84.48% | Test Loss: 0.4011 | Test Acc: 84.01%
# Epoch 97/500 | Train Loss: 0.3966 | Train Acc: 84.48% | Test Loss: 0.4005 | Test Acc: 84.01%
# Epoch 98/500 | Train Loss: 0.3959 | Train Acc: 84.48% | Test Loss: 0.3998 | Test Acc: 84.01%
# Epoch 99/500 | Train Loss: 0.3952 | Train Acc: 84.48% | Test Loss: 0.3992 | Test Acc: 84.01%
# Epoch 100/500 | Train Loss: 0.3945 | Train Acc: 84.48% | Test Loss: 0.3985 | Test Acc: 84.01%
# Epoch 101/500 | Train Loss: 0.3938 | Train Acc: 84.48% | Test Loss: 0.3979 | Test Acc: 84.01%
# Epoch 102/500 | Train Loss: 0.3931 | Train Acc: 84.48% | Test Loss: 0.3973 | Test Acc: 84.01%
# Epoch 103/500 | Train Loss: 0.3925 | Train Acc: 84.48% | Test Loss: 0.3967 | Test Acc: 84.01%
# Epoch 104/500 | Train Loss: 0.3918 | Train Acc: 84.48% | Test Loss: 0.3960 | Test Acc: 84.01%
# Epoch 105/500 | Train Loss: 0.3911 | Train Acc: 84.48% | Test Loss: 0.3954 | Test Acc: 84.01%
# Epoch 106/500 | Train Loss: 0.3905 | Train Acc: 84.44% | Test Loss: 0.3948 | Test Acc: 84.01%
# Epoch 107/500 | Train Loss: 0.3898 | Train Acc: 84.44% | Test Loss: 0.3943 | Test Acc: 84.01%
# Epoch 108/500 | Train Loss: 0.3891 | Train Acc: 84.44% | Test Loss: 0.3937 | Test Acc: 84.18%
# Epoch 109/500 | Train Loss: 0.3885 | Train Acc: 84.44% | Test Loss: 0.3931 | Test Acc: 84.18%
# Epoch 110/500 | Train Loss: 0.3879 | Train Acc: 84.48% | Test Loss: 0.3925 | Test Acc: 84.18%
# Epoch 111/500 | Train Loss: 0.3872 | Train Acc: 84.52% | Test Loss: 0.3920 | Test Acc: 84.18%
# Epoch 112/500 | Train Loss: 0.3866 | Train Acc: 84.57% | Test Loss: 0.3914 | Test Acc: 84.36%
# Epoch 113/500 | Train Loss: 0.3860 | Train Acc: 84.61% | Test Loss: 0.3909 | Test Acc: 84.36%
# Epoch 114/500 | Train Loss: 0.3854 | Train Acc: 84.61% | Test Loss: 0.3903 | Test Acc: 84.36%
# Epoch 115/500 | Train Loss: 0.3848 | Train Acc: 84.66% | Test Loss: 0.3898 | Test Acc: 84.36%
# Epoch 116/500 | Train Loss: 0.3842 | Train Acc: 84.79% | Test Loss: 0.3892 | Test Acc: 84.36%
# Epoch 117/500 | Train Loss: 0.3836 | Train Acc: 84.83% | Test Loss: 0.3887 | Test Acc: 84.36%
# Epoch 118/500 | Train Loss: 0.3830 | Train Acc: 84.88% | Test Loss: 0.3882 | Test Acc: 84.36%
# Epoch 119/500 | Train Loss: 0.3825 | Train Acc: 84.88% | Test Loss: 0.3876 | Test Acc: 84.36%
# Epoch 120/500 | Train Loss: 0.3819 | Train Acc: 84.92% | Test Loss: 0.3871 | Test Acc: 84.36%
# Epoch 121/500 | Train Loss: 0.3813 | Train Acc: 84.92% | Test Loss: 0.3866 | Test Acc: 84.36%
# Epoch 122/500 | Train Loss: 0.3808 | Train Acc: 84.92% | Test Loss: 0.3861 | Test Acc: 84.36%
# Epoch 123/500 | Train Loss: 0.3802 | Train Acc: 84.92% | Test Loss: 0.3856 | Test Acc: 84.36%
# Epoch 124/500 | Train Loss: 0.3796 | Train Acc: 84.92% | Test Loss: 0.3850 | Test Acc: 84.36%
# Epoch 125/500 | Train Loss: 0.3791 | Train Acc: 84.92% | Test Loss: 0.3845 | Test Acc: 84.36%
# Epoch 126/500 | Train Loss: 0.3785 | Train Acc: 84.92% | Test Loss: 0.3840 | Test Acc: 84.36%
# Epoch 127/500 | Train Loss: 0.3780 | Train Acc: 84.96% | Test Loss: 0.3835 | Test Acc: 84.36%
# Epoch 128/500 | Train Loss: 0.3774 | Train Acc: 84.96% | Test Loss: 0.3830 | Test Acc: 84.36%
# Epoch 129/500 | Train Loss: 0.3769 | Train Acc: 85.01% | Test Loss: 0.3826 | Test Acc: 84.36%
# Epoch 130/500 | Train Loss: 0.3764 | Train Acc: 85.01% | Test Loss: 0.3821 | Test Acc: 84.53%
# Epoch 131/500 | Train Loss: 0.3758 | Train Acc: 85.01% | Test Loss: 0.3816 | Test Acc: 84.53%
# Epoch 132/500 | Train Loss: 0.3753 | Train Acc: 85.05% | Test Loss: 0.3811 | Test Acc: 84.53%
# Epoch 133/500 | Train Loss: 0.3748 | Train Acc: 85.14% | Test Loss: 0.3807 | Test Acc: 84.53%
# Epoch 134/500 | Train Loss: 0.3743 | Train Acc: 85.18% | Test Loss: 0.3802 | Test Acc: 84.53%
# Epoch 135/500 | Train Loss: 0.3738 | Train Acc: 85.18% | Test Loss: 0.3797 | Test Acc: 84.53%
# Epoch 136/500 | Train Loss: 0.3733 | Train Acc: 85.18% | Test Loss: 0.3793 | Test Acc: 84.53%
# Epoch 137/500 | Train Loss: 0.3728 | Train Acc: 85.18% | Test Loss: 0.3788 | Test Acc: 84.53%
# Epoch 138/500 | Train Loss: 0.3723 | Train Acc: 85.27% | Test Loss: 0.3784 | Test Acc: 84.53%
# Epoch 139/500 | Train Loss: 0.3718 | Train Acc: 85.27% | Test Loss: 0.3780 | Test Acc: 84.53%
# Epoch 140/500 | Train Loss: 0.3713 | Train Acc: 85.27% | Test Loss: 0.3775 | Test Acc: 84.71%
# Epoch 141/500 | Train Loss: 0.3708 | Train Acc: 85.23% | Test Loss: 0.3771 | Test Acc: 84.71%
# Epoch 142/500 | Train Loss: 0.3703 | Train Acc: 85.27% | Test Loss: 0.3767 | Test Acc: 84.71%
# Epoch 143/500 | Train Loss: 0.3698 | Train Acc: 85.27% | Test Loss: 0.3762 | Test Acc: 84.71%
# Epoch 144/500 | Train Loss: 0.3693 | Train Acc: 85.27% | Test Loss: 0.3758 | Test Acc: 84.71%
# Epoch 145/500 | Train Loss: 0.3689 | Train Acc: 85.27% | Test Loss: 0.3754 | Test Acc: 84.71%
# Epoch 146/500 | Train Loss: 0.3684 | Train Acc: 85.27% | Test Loss: 0.3749 | Test Acc: 84.89%
# Epoch 147/500 | Train Loss: 0.3679 | Train Acc: 85.23% | Test Loss: 0.3745 | Test Acc: 84.89%
# Epoch 148/500 | Train Loss: 0.3675 | Train Acc: 85.23% | Test Loss: 0.3741 | Test Acc: 84.89%
# Epoch 149/500 | Train Loss: 0.3670 | Train Acc: 85.23% | Test Loss: 0.3737 | Test Acc: 84.89%
# Epoch 150/500 | Train Loss: 0.3665 | Train Acc: 85.23% | Test Loss: 0.3733 | Test Acc: 84.89%
# Epoch 151/500 | Train Loss: 0.3661 | Train Acc: 85.23% | Test Loss: 0.3729 | Test Acc: 84.89%
# Epoch 152/500 | Train Loss: 0.3656 | Train Acc: 85.23% | Test Loss: 0.3724 | Test Acc: 84.89%
# Epoch 153/500 | Train Loss: 0.3652 | Train Acc: 85.23% | Test Loss: 0.3720 | Test Acc: 84.89%
# Epoch 154/500 | Train Loss: 0.3647 | Train Acc: 85.23% | Test Loss: 0.3716 | Test Acc: 84.89%
# Epoch 155/500 | Train Loss: 0.3643 | Train Acc: 85.27% | Test Loss: 0.3712 | Test Acc: 85.06%
# Epoch 156/500 | Train Loss: 0.3639 | Train Acc: 85.27% | Test Loss: 0.3708 | Test Acc: 85.06%
# Epoch 157/500 | Train Loss: 0.3634 | Train Acc: 85.27% | Test Loss: 0.3705 | Test Acc: 84.89%
# Epoch 158/500 | Train Loss: 0.3630 | Train Acc: 85.31% | Test Loss: 0.3701 | Test Acc: 84.53%
# Epoch 159/500 | Train Loss: 0.3626 | Train Acc: 85.31% | Test Loss: 0.3697 | Test Acc: 84.53%
# Epoch 160/500 | Train Loss: 0.3621 | Train Acc: 85.31% | Test Loss: 0.3693 | Test Acc: 84.53%
# Epoch 161/500 | Train Loss: 0.3617 | Train Acc: 85.36% | Test Loss: 0.3689 | Test Acc: 84.53%
# Epoch 162/500 | Train Loss: 0.3613 | Train Acc: 85.36% | Test Loss: 0.3686 | Test Acc: 84.36%
# Epoch 163/500 | Train Loss: 0.3609 | Train Acc: 85.40% | Test Loss: 0.3682 | Test Acc: 84.36%
# Epoch 164/500 | Train Loss: 0.3605 | Train Acc: 85.40% | Test Loss: 0.3678 | Test Acc: 84.36%
# Epoch 165/500 | Train Loss: 0.3600 | Train Acc: 85.40% | Test Loss: 0.3674 | Test Acc: 84.36%
# Epoch 166/500 | Train Loss: 0.3596 | Train Acc: 85.40% | Test Loss: 0.3671 | Test Acc: 84.36%
# Epoch 167/500 | Train Loss: 0.3592 | Train Acc: 85.40% | Test Loss: 0.3667 | Test Acc: 84.36%
# Epoch 168/500 | Train Loss: 0.3588 | Train Acc: 85.40% | Test Loss: 0.3664 | Test Acc: 84.36%
# Epoch 169/500 | Train Loss: 0.3584 | Train Acc: 85.40% | Test Loss: 0.3660 | Test Acc: 84.36%
# Epoch 170/500 | Train Loss: 0.3580 | Train Acc: 85.44% | Test Loss: 0.3657 | Test Acc: 84.36%
# Epoch 171/500 | Train Loss: 0.3576 | Train Acc: 85.44% | Test Loss: 0.3653 | Test Acc: 84.36%
# Epoch 172/500 | Train Loss: 0.3572 | Train Acc: 85.44% | Test Loss: 0.3650 | Test Acc: 84.36%
# Epoch 173/500 | Train Loss: 0.3568 | Train Acc: 85.44% | Test Loss: 0.3646 | Test Acc: 84.36%
# Epoch 174/500 | Train Loss: 0.3564 | Train Acc: 85.44% | Test Loss: 0.3643 | Test Acc: 84.18%
# Epoch 175/500 | Train Loss: 0.3560 | Train Acc: 85.44% | Test Loss: 0.3639 | Test Acc: 84.18%
# Epoch 176/500 | Train Loss: 0.3556 | Train Acc: 85.44% | Test Loss: 0.3636 | Test Acc: 84.18%
# Epoch 177/500 | Train Loss: 0.3552 | Train Acc: 85.44% | Test Loss: 0.3633 | Test Acc: 84.18%
# Epoch 178/500 | Train Loss: 0.3549 | Train Acc: 85.44% | Test Loss: 0.3629 | Test Acc: 84.18%
# Epoch 179/500 | Train Loss: 0.3545 | Train Acc: 85.44% | Test Loss: 0.3626 | Test Acc: 84.18%
# Epoch 180/500 | Train Loss: 0.3541 | Train Acc: 85.44% | Test Loss: 0.3623 | Test Acc: 84.18%
# Epoch 181/500 | Train Loss: 0.3537 | Train Acc: 85.44% | Test Loss: 0.3619 | Test Acc: 84.18%
# Epoch 182/500 | Train Loss: 0.3533 | Train Acc: 85.44% | Test Loss: 0.3616 | Test Acc: 84.18%
# Epoch 183/500 | Train Loss: 0.3530 | Train Acc: 85.44% | Test Loss: 0.3613 | Test Acc: 84.18%
# Epoch 184/500 | Train Loss: 0.3526 | Train Acc: 85.44% | Test Loss: 0.3610 | Test Acc: 84.18%
# Epoch 185/500 | Train Loss: 0.3522 | Train Acc: 85.44% | Test Loss: 0.3607 | Test Acc: 84.18%
# Epoch 186/500 | Train Loss: 0.3519 | Train Acc: 85.44% | Test Loss: 0.3603 | Test Acc: 84.18%
# Epoch 187/500 | Train Loss: 0.3515 | Train Acc: 85.44% | Test Loss: 0.3600 | Test Acc: 84.18%
# Epoch 188/500 | Train Loss: 0.3511 | Train Acc: 85.44% | Test Loss: 0.3597 | Test Acc: 84.18%
# Epoch 189/500 | Train Loss: 0.3508 | Train Acc: 85.44% | Test Loss: 0.3594 | Test Acc: 84.18%
# Epoch 190/500 | Train Loss: 0.3504 | Train Acc: 85.44% | Test Loss: 0.3591 | Test Acc: 84.18%
# Epoch 191/500 | Train Loss: 0.3501 | Train Acc: 85.44% | Test Loss: 0.3588 | Test Acc: 84.18%
# Epoch 192/500 | Train Loss: 0.3497 | Train Acc: 85.44% | Test Loss: 0.3585 | Test Acc: 84.18%
# Epoch 193/500 | Train Loss: 0.3493 | Train Acc: 85.44% | Test Loss: 0.3582 | Test Acc: 84.18%
# Epoch 194/500 | Train Loss: 0.3490 | Train Acc: 85.44% | Test Loss: 0.3579 | Test Acc: 84.18%
# Epoch 195/500 | Train Loss: 0.3486 | Train Acc: 85.44% | Test Loss: 0.3576 | Test Acc: 84.18%
# Epoch 196/500 | Train Loss: 0.3483 | Train Acc: 85.44% | Test Loss: 0.3573 | Test Acc: 84.18%
# Epoch 197/500 | Train Loss: 0.3479 | Train Acc: 85.44% | Test Loss: 0.3570 | Test Acc: 84.18%
# Epoch 198/500 | Train Loss: 0.3476 | Train Acc: 85.44% | Test Loss: 0.3567 | Test Acc: 84.18%
# Epoch 199/500 | Train Loss: 0.3472 | Train Acc: 85.44% | Test Loss: 0.3564 | Test Acc: 84.18%
# Epoch 200/500 | Train Loss: 0.3469 | Train Acc: 85.44% | Test Loss: 0.3561 | Test Acc: 84.18%
# Epoch 201/500 | Train Loss: 0.3465 | Train Acc: 85.44% | Test Loss: 0.3558 | Test Acc: 84.18%
# Epoch 202/500 | Train Loss: 0.3462 | Train Acc: 85.44% | Test Loss: 0.3555 | Test Acc: 84.18%
# Epoch 203/500 | Train Loss: 0.3459 | Train Acc: 85.44% | Test Loss: 0.3552 | Test Acc: 84.18%
# Epoch 204/500 | Train Loss: 0.3455 | Train Acc: 85.44% | Test Loss: 0.3549 | Test Acc: 84.18%
# Epoch 205/500 | Train Loss: 0.3452 | Train Acc: 85.44% | Test Loss: 0.3546 | Test Acc: 84.18%
# Epoch 206/500 | Train Loss: 0.3448 | Train Acc: 85.44% | Test Loss: 0.3543 | Test Acc: 84.18%
# Epoch 207/500 | Train Loss: 0.3445 | Train Acc: 85.44% | Test Loss: 0.3540 | Test Acc: 84.18%
# Epoch 208/500 | Train Loss: 0.3442 | Train Acc: 85.44% | Test Loss: 0.3537 | Test Acc: 84.18%
# Epoch 209/500 | Train Loss: 0.3438 | Train Acc: 85.44% | Test Loss: 0.3535 | Test Acc: 84.18%
# Epoch 210/500 | Train Loss: 0.3435 | Train Acc: 85.44% | Test Loss: 0.3532 | Test Acc: 84.18%
# Epoch 211/500 | Train Loss: 0.3432 | Train Acc: 85.44% | Test Loss: 0.3529 | Test Acc: 84.18%
# Epoch 212/500 | Train Loss: 0.3428 | Train Acc: 85.44% | Test Loss: 0.3526 | Test Acc: 84.18%
# Epoch 213/500 | Train Loss: 0.3425 | Train Acc: 85.44% | Test Loss: 0.3523 | Test Acc: 84.18%
# Epoch 214/500 | Train Loss: 0.3422 | Train Acc: 85.44% | Test Loss: 0.3521 | Test Acc: 84.18%
# Epoch 215/500 | Train Loss: 0.3419 | Train Acc: 85.44% | Test Loss: 0.3518 | Test Acc: 84.18%
# Epoch 216/500 | Train Loss: 0.3415 | Train Acc: 85.44% | Test Loss: 0.3515 | Test Acc: 84.18%
# Epoch 217/500 | Train Loss: 0.3412 | Train Acc: 85.44% | Test Loss: 0.3512 | Test Acc: 84.18%
# Epoch 218/500 | Train Loss: 0.3409 | Train Acc: 85.44% | Test Loss: 0.3510 | Test Acc: 84.18%
# Epoch 219/500 | Train Loss: 0.3406 | Train Acc: 85.44% | Test Loss: 0.3507 | Test Acc: 84.18%
# Epoch 220/500 | Train Loss: 0.3402 | Train Acc: 85.44% | Test Loss: 0.3504 | Test Acc: 84.18%
# Epoch 221/500 | Train Loss: 0.3399 | Train Acc: 85.44% | Test Loss: 0.3501 | Test Acc: 84.18%
# Epoch 222/500 | Train Loss: 0.3396 | Train Acc: 85.44% | Test Loss: 0.3499 | Test Acc: 84.18%
# Epoch 223/500 | Train Loss: 0.3393 | Train Acc: 85.44% | Test Loss: 0.3496 | Test Acc: 84.18%
# Epoch 224/500 | Train Loss: 0.3390 | Train Acc: 85.44% | Test Loss: 0.3493 | Test Acc: 84.18%
# Epoch 225/500 | Train Loss: 0.3386 | Train Acc: 85.44% | Test Loss: 0.3491 | Test Acc: 84.18%
# Epoch 226/500 | Train Loss: 0.3383 | Train Acc: 85.44% | Test Loss: 0.3488 | Test Acc: 84.18%
# Epoch 227/500 | Train Loss: 0.3380 | Train Acc: 85.44% | Test Loss: 0.3485 | Test Acc: 84.18%
# Epoch 228/500 | Train Loss: 0.3377 | Train Acc: 85.44% | Test Loss: 0.3483 | Test Acc: 84.18%
# Epoch 229/500 | Train Loss: 0.3374 | Train Acc: 85.44% | Test Loss: 0.3480 | Test Acc: 84.18%
# Epoch 230/500 | Train Loss: 0.3371 | Train Acc: 85.44% | Test Loss: 0.3477 | Test Acc: 84.18%
# Epoch 231/500 | Train Loss: 0.3368 | Train Acc: 85.44% | Test Loss: 0.3475 | Test Acc: 84.18%
# Epoch 232/500 | Train Loss: 0.3365 | Train Acc: 85.44% | Test Loss: 0.3472 | Test Acc: 84.18%
# Epoch 233/500 | Train Loss: 0.3362 | Train Acc: 85.44% | Test Loss: 0.3470 | Test Acc: 84.18%
# Epoch 234/500 | Train Loss: 0.3358 | Train Acc: 85.44% | Test Loss: 0.3467 | Test Acc: 84.18%
# Epoch 235/500 | Train Loss: 0.3355 | Train Acc: 85.44% | Test Loss: 0.3464 | Test Acc: 84.18%
# Epoch 236/500 | Train Loss: 0.3352 | Train Acc: 85.44% | Test Loss: 0.3462 | Test Acc: 84.18%
# Epoch 237/500 | Train Loss: 0.3349 | Train Acc: 85.49% | Test Loss: 0.3459 | Test Acc: 84.18%
# Epoch 238/500 | Train Loss: 0.3346 | Train Acc: 85.49% | Test Loss: 0.3457 | Test Acc: 84.18%
# Epoch 239/500 | Train Loss: 0.3343 | Train Acc: 85.49% | Test Loss: 0.3454 | Test Acc: 84.53%
# Epoch 240/500 | Train Loss: 0.3340 | Train Acc: 85.49% | Test Loss: 0.3452 | Test Acc: 84.53%
# Epoch 241/500 | Train Loss: 0.3337 | Train Acc: 85.49% | Test Loss: 0.3449 | Test Acc: 84.53%
# Epoch 242/500 | Train Loss: 0.3334 | Train Acc: 85.53% | Test Loss: 0.3446 | Test Acc: 84.53%
# Epoch 243/500 | Train Loss: 0.3331 | Train Acc: 85.53% | Test Loss: 0.3444 | Test Acc: 84.53%
# Epoch 244/500 | Train Loss: 0.3328 | Train Acc: 85.53% | Test Loss: 0.3441 | Test Acc: 84.53%
# Epoch 245/500 | Train Loss: 0.3325 | Train Acc: 85.53% | Test Loss: 0.3439 | Test Acc: 84.53%
# Epoch 246/500 | Train Loss: 0.3322 | Train Acc: 85.53% | Test Loss: 0.3436 | Test Acc: 84.53%
# Epoch 247/500 | Train Loss: 0.3319 | Train Acc: 85.53% | Test Loss: 0.3434 | Test Acc: 84.53%
# Epoch 248/500 | Train Loss: 0.3316 | Train Acc: 85.53% | Test Loss: 0.3431 | Test Acc: 84.53%
# Epoch 249/500 | Train Loss: 0.3313 | Train Acc: 85.53% | Test Loss: 0.3429 | Test Acc: 84.53%
# Epoch 250/500 | Train Loss: 0.3310 | Train Acc: 85.53% | Test Loss: 0.3426 | Test Acc: 84.53%
# Epoch 251/500 | Train Loss: 0.3307 | Train Acc: 85.53% | Test Loss: 0.3424 | Test Acc: 84.53%
# Epoch 252/500 | Train Loss: 0.3304 | Train Acc: 85.58% | Test Loss: 0.3421 | Test Acc: 84.53%
# Epoch 253/500 | Train Loss: 0.3301 | Train Acc: 85.58% | Test Loss: 0.3419 | Test Acc: 84.53%
# Epoch 254/500 | Train Loss: 0.3298 | Train Acc: 85.58% | Test Loss: 0.3416 | Test Acc: 84.53%
# Epoch 255/500 | Train Loss: 0.3295 | Train Acc: 85.58% | Test Loss: 0.3414 | Test Acc: 84.53%
# Epoch 256/500 | Train Loss: 0.3293 | Train Acc: 85.58% | Test Loss: 0.3412 | Test Acc: 84.53%
# Epoch 257/500 | Train Loss: 0.3290 | Train Acc: 85.58% | Test Loss: 0.3409 | Test Acc: 84.53%
# Epoch 258/500 | Train Loss: 0.3287 | Train Acc: 85.58% | Test Loss: 0.3407 | Test Acc: 84.53%
# Epoch 259/500 | Train Loss: 0.3284 | Train Acc: 85.58% | Test Loss: 0.3404 | Test Acc: 84.53%
# Epoch 260/500 | Train Loss: 0.3281 | Train Acc: 85.58% | Test Loss: 0.3402 | Test Acc: 84.53%
# Epoch 261/500 | Train Loss: 0.3278 | Train Acc: 85.58% | Test Loss: 0.3399 | Test Acc: 84.53%
# Epoch 262/500 | Train Loss: 0.3275 | Train Acc: 85.58% | Test Loss: 0.3397 | Test Acc: 84.53%
# Epoch 263/500 | Train Loss: 0.3272 | Train Acc: 85.58% | Test Loss: 0.3395 | Test Acc: 84.53%
# Epoch 264/500 | Train Loss: 0.3269 | Train Acc: 85.58% | Test Loss: 0.3392 | Test Acc: 84.53%
# Epoch 265/500 | Train Loss: 0.3266 | Train Acc: 85.58% | Test Loss: 0.3390 | Test Acc: 84.53%
# Epoch 266/500 | Train Loss: 0.3264 | Train Acc: 85.58% | Test Loss: 0.3387 | Test Acc: 84.53%
# Epoch 267/500 | Train Loss: 0.3261 | Train Acc: 85.58% | Test Loss: 0.3385 | Test Acc: 84.53%
# Epoch 268/500 | Train Loss: 0.3258 | Train Acc: 85.58% | Test Loss: 0.3383 | Test Acc: 84.53%
# Epoch 269/500 | Train Loss: 0.3255 | Train Acc: 85.58% | Test Loss: 0.3380 | Test Acc: 84.53%
# Epoch 270/500 | Train Loss: 0.3252 | Train Acc: 85.58% | Test Loss: 0.3378 | Test Acc: 84.53%
# Epoch 271/500 | Train Loss: 0.3249 | Train Acc: 85.58% | Test Loss: 0.3375 | Test Acc: 84.53%
# Epoch 272/500 | Train Loss: 0.3246 | Train Acc: 85.58% | Test Loss: 0.3373 | Test Acc: 84.53%
# Epoch 273/500 | Train Loss: 0.3244 | Train Acc: 85.58% | Test Loss: 0.3371 | Test Acc: 84.53%
# Epoch 274/500 | Train Loss: 0.3241 | Train Acc: 85.58% | Test Loss: 0.3368 | Test Acc: 84.53%
# Epoch 275/500 | Train Loss: 0.3238 | Train Acc: 85.58% | Test Loss: 0.3366 | Test Acc: 84.53%
# Epoch 276/500 | Train Loss: 0.3235 | Train Acc: 85.58% | Test Loss: 0.3364 | Test Acc: 84.53%
# Epoch 277/500 | Train Loss: 0.3232 | Train Acc: 85.58% | Test Loss: 0.3361 | Test Acc: 84.53%
# Epoch 278/500 | Train Loss: 0.3229 | Train Acc: 85.58% | Test Loss: 0.3359 | Test Acc: 84.53%
# Epoch 279/500 | Train Loss: 0.3227 | Train Acc: 85.58% | Test Loss: 0.3357 | Test Acc: 84.53%
# Epoch 280/500 | Train Loss: 0.3224 | Train Acc: 85.58% | Test Loss: 0.3354 | Test Acc: 84.53%
# Epoch 281/500 | Train Loss: 0.3221 | Train Acc: 85.58% | Test Loss: 0.3352 | Test Acc: 84.53%
# Epoch 282/500 | Train Loss: 0.3218 | Train Acc: 85.58% | Test Loss: 0.3350 | Test Acc: 84.53%
# Epoch 283/500 | Train Loss: 0.3215 | Train Acc: 85.58% | Test Loss: 0.3347 | Test Acc: 84.53%
# Epoch 284/500 | Train Loss: 0.3213 | Train Acc: 85.58% | Test Loss: 0.3345 | Test Acc: 84.53%
# Epoch 285/500 | Train Loss: 0.3210 | Train Acc: 85.58% | Test Loss: 0.3343 | Test Acc: 84.53%
# Epoch 286/500 | Train Loss: 0.3207 | Train Acc: 85.58% | Test Loss: 0.3341 | Test Acc: 84.53%
# Epoch 287/500 | Train Loss: 0.3204 | Train Acc: 85.58% | Test Loss: 0.3338 | Test Acc: 84.53%
# Epoch 288/500 | Train Loss: 0.3202 | Train Acc: 85.58% | Test Loss: 0.3336 | Test Acc: 84.53%
# Epoch 289/500 | Train Loss: 0.3199 | Train Acc: 85.58% | Test Loss: 0.3334 | Test Acc: 84.53%
# Epoch 290/500 | Train Loss: 0.3196 | Train Acc: 85.62% | Test Loss: 0.3331 | Test Acc: 84.53%
# Epoch 291/500 | Train Loss: 0.3194 | Train Acc: 85.62% | Test Loss: 0.3329 | Test Acc: 84.53%
# Epoch 292/500 | Train Loss: 0.3191 | Train Acc: 85.62% | Test Loss: 0.3327 | Test Acc: 84.53%
# Epoch 293/500 | Train Loss: 0.3188 | Train Acc: 85.62% | Test Loss: 0.3325 | Test Acc: 84.53%
# Epoch 294/500 | Train Loss: 0.3185 | Train Acc: 85.62% | Test Loss: 0.3322 | Test Acc: 84.53%
# Epoch 295/500 | Train Loss: 0.3183 | Train Acc: 85.62% | Test Loss: 0.3320 | Test Acc: 84.53%
# Epoch 296/500 | Train Loss: 0.3180 | Train Acc: 85.62% | Test Loss: 0.3318 | Test Acc: 84.53%
# Epoch 297/500 | Train Loss: 0.3177 | Train Acc: 85.62% | Test Loss: 0.3316 | Test Acc: 84.53%
# Epoch 298/500 | Train Loss: 0.3175 | Train Acc: 85.62% | Test Loss: 0.3314 | Test Acc: 84.53%
# Epoch 299/500 | Train Loss: 0.3172 | Train Acc: 85.62% | Test Loss: 0.3311 | Test Acc: 84.53%
# Epoch 300/500 | Train Loss: 0.3169 | Train Acc: 85.62% | Test Loss: 0.3309 | Test Acc: 84.53%
# Epoch 301/500 | Train Loss: 0.3167 | Train Acc: 85.71% | Test Loss: 0.3307 | Test Acc: 84.53%
# Epoch 302/500 | Train Loss: 0.3164 | Train Acc: 85.75% | Test Loss: 0.3305 | Test Acc: 84.53%
# Epoch 303/500 | Train Loss: 0.3161 | Train Acc: 85.75% | Test Loss: 0.3303 | Test Acc: 84.53%
# Epoch 304/500 | Train Loss: 0.3159 | Train Acc: 85.75% | Test Loss: 0.3300 | Test Acc: 84.53%
# Epoch 305/500 | Train Loss: 0.3156 | Train Acc: 85.75% | Test Loss: 0.3298 | Test Acc: 84.53%
# Epoch 306/500 | Train Loss: 0.3154 | Train Acc: 85.75% | Test Loss: 0.3296 | Test Acc: 84.53%
# Epoch 307/500 | Train Loss: 0.3151 | Train Acc: 85.75% | Test Loss: 0.3294 | Test Acc: 84.53%
# Epoch 308/500 | Train Loss: 0.3148 | Train Acc: 85.80% | Test Loss: 0.3292 | Test Acc: 84.53%
# Epoch 309/500 | Train Loss: 0.3146 | Train Acc: 85.80% | Test Loss: 0.3290 | Test Acc: 84.53%
# Epoch 310/500 | Train Loss: 0.3143 | Train Acc: 85.80% | Test Loss: 0.3287 | Test Acc: 84.53%
# Epoch 311/500 | Train Loss: 0.3141 | Train Acc: 85.84% | Test Loss: 0.3285 | Test Acc: 84.53%
# Epoch 312/500 | Train Loss: 0.3138 | Train Acc: 85.84% | Test Loss: 0.3283 | Test Acc: 84.53%
# Epoch 313/500 | Train Loss: 0.3135 | Train Acc: 85.93% | Test Loss: 0.3281 | Test Acc: 84.53%
# Epoch 314/500 | Train Loss: 0.3133 | Train Acc: 85.93% | Test Loss: 0.3279 | Test Acc: 84.53%
# Epoch 315/500 | Train Loss: 0.3130 | Train Acc: 85.93% | Test Loss: 0.3277 | Test Acc: 84.53%
# Epoch 316/500 | Train Loss: 0.3128 | Train Acc: 85.93% | Test Loss: 0.3275 | Test Acc: 84.53%
# Epoch 317/500 | Train Loss: 0.3125 | Train Acc: 85.93% | Test Loss: 0.3272 | Test Acc: 84.53%
# Epoch 318/500 | Train Loss: 0.3123 | Train Acc: 85.93% | Test Loss: 0.3270 | Test Acc: 84.53%
# Epoch 319/500 | Train Loss: 0.3120 | Train Acc: 85.93% | Test Loss: 0.3268 | Test Acc: 84.53%
# Epoch 320/500 | Train Loss: 0.3117 | Train Acc: 85.93% | Test Loss: 0.3266 | Test Acc: 84.53%
# Epoch 321/500 | Train Loss: 0.3115 | Train Acc: 85.97% | Test Loss: 0.3264 | Test Acc: 84.53%
# Epoch 322/500 | Train Loss: 0.3112 | Train Acc: 85.97% | Test Loss: 0.3262 | Test Acc: 84.53%
# Epoch 323/500 | Train Loss: 0.3110 | Train Acc: 85.97% | Test Loss: 0.3260 | Test Acc: 84.53%
# Epoch 324/500 | Train Loss: 0.3107 | Train Acc: 85.97% | Test Loss: 0.3258 | Test Acc: 84.53%
# Epoch 325/500 | Train Loss: 0.3105 | Train Acc: 85.97% | Test Loss: 0.3256 | Test Acc: 84.53%
# Epoch 326/500 | Train Loss: 0.3102 | Train Acc: 85.97% | Test Loss: 0.3254 | Test Acc: 84.53%
# Epoch 327/500 | Train Loss: 0.3100 | Train Acc: 85.97% | Test Loss: 0.3251 | Test Acc: 84.53%
# Epoch 328/500 | Train Loss: 0.3097 | Train Acc: 85.97% | Test Loss: 0.3249 | Test Acc: 84.53%
# Epoch 329/500 | Train Loss: 0.3095 | Train Acc: 85.97% | Test Loss: 0.3247 | Test Acc: 84.53%
# Epoch 330/500 | Train Loss: 0.3092 | Train Acc: 85.97% | Test Loss: 0.3245 | Test Acc: 84.53%
# Epoch 331/500 | Train Loss: 0.3090 | Train Acc: 85.97% | Test Loss: 0.3243 | Test Acc: 84.53%
# Epoch 332/500 | Train Loss: 0.3087 | Train Acc: 85.97% | Test Loss: 0.3241 | Test Acc: 84.53%
# Epoch 333/500 | Train Loss: 0.3085 | Train Acc: 86.01% | Test Loss: 0.3239 | Test Acc: 84.53%
# Epoch 334/500 | Train Loss: 0.3082 | Train Acc: 86.06% | Test Loss: 0.3237 | Test Acc: 84.53%
# Epoch 335/500 | Train Loss: 0.3080 | Train Acc: 86.06% | Test Loss: 0.3235 | Test Acc: 84.53%
# Epoch 336/500 | Train Loss: 0.3078 | Train Acc: 86.06% | Test Loss: 0.3233 | Test Acc: 84.53%
# Epoch 337/500 | Train Loss: 0.3075 | Train Acc: 86.06% | Test Loss: 0.3231 | Test Acc: 84.53%
# Epoch 338/500 | Train Loss: 0.3073 | Train Acc: 86.06% | Test Loss: 0.3229 | Test Acc: 84.53%
# Epoch 339/500 | Train Loss: 0.3070 | Train Acc: 86.06% | Test Loss: 0.3227 | Test Acc: 84.71%
# Epoch 340/500 | Train Loss: 0.3068 | Train Acc: 86.06% | Test Loss: 0.3225 | Test Acc: 84.71%
# Epoch 341/500 | Train Loss: 0.3065 | Train Acc: 86.10% | Test Loss: 0.3223 | Test Acc: 84.71%
# Epoch 342/500 | Train Loss: 0.3063 | Train Acc: 86.10% | Test Loss: 0.3221 | Test Acc: 84.71%
# Epoch 343/500 | Train Loss: 0.3061 | Train Acc: 86.10% | Test Loss: 0.3219 | Test Acc: 84.71%
# Epoch 344/500 | Train Loss: 0.3058 | Train Acc: 86.15% | Test Loss: 0.3217 | Test Acc: 84.89%
# Epoch 345/500 | Train Loss: 0.3056 | Train Acc: 86.15% | Test Loss: 0.3215 | Test Acc: 84.89%
# Epoch 346/500 | Train Loss: 0.3053 | Train Acc: 86.15% | Test Loss: 0.3213 | Test Acc: 84.89%
# Epoch 347/500 | Train Loss: 0.3051 | Train Acc: 86.15% | Test Loss: 0.3211 | Test Acc: 84.89%
# Epoch 348/500 | Train Loss: 0.3049 | Train Acc: 86.15% | Test Loss: 0.3209 | Test Acc: 84.89%
# Epoch 349/500 | Train Loss: 0.3046 | Train Acc: 86.15% | Test Loss: 0.3207 | Test Acc: 84.89%
# Epoch 350/500 | Train Loss: 0.3044 | Train Acc: 86.15% | Test Loss: 0.3205 | Test Acc: 84.89%
# Epoch 351/500 | Train Loss: 0.3041 | Train Acc: 86.15% | Test Loss: 0.3203 | Test Acc: 84.89%
# Epoch 352/500 | Train Loss: 0.3039 | Train Acc: 86.15% | Test Loss: 0.3201 | Test Acc: 84.89%
# Epoch 353/500 | Train Loss: 0.3037 | Train Acc: 86.19% | Test Loss: 0.3199 | Test Acc: 84.89%
# Epoch 354/500 | Train Loss: 0.3034 | Train Acc: 86.19% | Test Loss: 0.3197 | Test Acc: 84.89%
# Epoch 355/500 | Train Loss: 0.3032 | Train Acc: 86.19% | Test Loss: 0.3195 | Test Acc: 84.89%
# Epoch 356/500 | Train Loss: 0.3030 | Train Acc: 86.19% | Test Loss: 0.3193 | Test Acc: 84.89%
# Epoch 357/500 | Train Loss: 0.3027 | Train Acc: 86.23% | Test Loss: 0.3191 | Test Acc: 84.89%
# Epoch 358/500 | Train Loss: 0.3025 | Train Acc: 86.23% | Test Loss: 0.3189 | Test Acc: 84.89%
# Epoch 359/500 | Train Loss: 0.3023 | Train Acc: 86.23% | Test Loss: 0.3187 | Test Acc: 84.89%
# Epoch 360/500 | Train Loss: 0.3020 | Train Acc: 86.23% | Test Loss: 0.3186 | Test Acc: 84.89%
# Epoch 361/500 | Train Loss: 0.3018 | Train Acc: 86.23% | Test Loss: 0.3184 | Test Acc: 84.89%
# Epoch 362/500 | Train Loss: 0.3016 | Train Acc: 86.28% | Test Loss: 0.3182 | Test Acc: 84.89%
# Epoch 363/500 | Train Loss: 0.3014 | Train Acc: 86.28% | Test Loss: 0.3180 | Test Acc: 84.89%
# Epoch 364/500 | Train Loss: 0.3011 | Train Acc: 86.28% | Test Loss: 0.3178 | Test Acc: 84.89%
# Epoch 365/500 | Train Loss: 0.3009 | Train Acc: 86.28% | Test Loss: 0.3176 | Test Acc: 84.89%
# Epoch 366/500 | Train Loss: 0.3007 | Train Acc: 86.28% | Test Loss: 0.3174 | Test Acc: 84.89%
# Epoch 367/500 | Train Loss: 0.3004 | Train Acc: 86.28% | Test Loss: 0.3172 | Test Acc: 84.89%
# Epoch 368/500 | Train Loss: 0.3002 | Train Acc: 86.28% | Test Loss: 0.3170 | Test Acc: 84.89%
# Epoch 369/500 | Train Loss: 0.3000 | Train Acc: 86.28% | Test Loss: 0.3168 | Test Acc: 84.89%
# Epoch 370/500 | Train Loss: 0.2998 | Train Acc: 86.32% | Test Loss: 0.3167 | Test Acc: 84.89%
# Epoch 371/500 | Train Loss: 0.2995 | Train Acc: 86.32% | Test Loss: 0.3165 | Test Acc: 84.89%
# Epoch 372/500 | Train Loss: 0.2993 | Train Acc: 86.32% | Test Loss: 0.3163 | Test Acc: 84.89%
# Epoch 373/500 | Train Loss: 0.2991 | Train Acc: 86.37% | Test Loss: 0.3161 | Test Acc: 84.89%
# Epoch 374/500 | Train Loss: 0.2989 | Train Acc: 86.37% | Test Loss: 0.3159 | Test Acc: 84.89%
# Epoch 375/500 | Train Loss: 0.2986 | Train Acc: 86.37% | Test Loss: 0.3157 | Test Acc: 84.89%
# Epoch 376/500 | Train Loss: 0.2984 | Train Acc: 86.37% | Test Loss: 0.3155 | Test Acc: 84.89%
# Epoch 377/500 | Train Loss: 0.2982 | Train Acc: 86.37% | Test Loss: 0.3154 | Test Acc: 84.89%
# Epoch 378/500 | Train Loss: 0.2980 | Train Acc: 86.41% | Test Loss: 0.3152 | Test Acc: 84.89%
# Epoch 379/500 | Train Loss: 0.2978 | Train Acc: 86.41% | Test Loss: 0.3150 | Test Acc: 84.89%
# Epoch 380/500 | Train Loss: 0.2976 | Train Acc: 86.41% | Test Loss: 0.3148 | Test Acc: 84.89%
# Epoch 381/500 | Train Loss: 0.2973 | Train Acc: 86.41% | Test Loss: 0.3146 | Test Acc: 84.89%
# Epoch 382/500 | Train Loss: 0.2971 | Train Acc: 86.45% | Test Loss: 0.3145 | Test Acc: 84.89%
# Epoch 383/500 | Train Loss: 0.2969 | Train Acc: 86.45% | Test Loss: 0.3143 | Test Acc: 84.89%
# Epoch 384/500 | Train Loss: 0.2967 | Train Acc: 86.45% | Test Loss: 0.3141 | Test Acc: 84.89%
# Epoch 385/500 | Train Loss: 0.2965 | Train Acc: 86.45% | Test Loss: 0.3139 | Test Acc: 84.89%
# Epoch 386/500 | Train Loss: 0.2963 | Train Acc: 86.45% | Test Loss: 0.3137 | Test Acc: 84.89%
# Epoch 387/500 | Train Loss: 0.2960 | Train Acc: 86.45% | Test Loss: 0.3136 | Test Acc: 84.89%
# Epoch 388/500 | Train Loss: 0.2958 | Train Acc: 86.45% | Test Loss: 0.3134 | Test Acc: 84.89%
# Epoch 389/500 | Train Loss: 0.2956 | Train Acc: 86.45% | Test Loss: 0.3132 | Test Acc: 84.89%
# Epoch 390/500 | Train Loss: 0.2954 | Train Acc: 86.45% | Test Loss: 0.3130 | Test Acc: 84.89%
# Epoch 391/500 | Train Loss: 0.2952 | Train Acc: 86.45% | Test Loss: 0.3129 | Test Acc: 84.89%
# Epoch 392/500 | Train Loss: 0.2950 | Train Acc: 86.45% | Test Loss: 0.3127 | Test Acc: 84.89%
# Epoch 393/500 | Train Loss: 0.2948 | Train Acc: 86.45% | Test Loss: 0.3125 | Test Acc: 84.89%
# Epoch 394/500 | Train Loss: 0.2946 | Train Acc: 86.45% | Test Loss: 0.3123 | Test Acc: 85.06%
# Epoch 395/500 | Train Loss: 0.2943 | Train Acc: 86.50% | Test Loss: 0.3122 | Test Acc: 85.06%
# Epoch 396/500 | Train Loss: 0.2941 | Train Acc: 86.50% | Test Loss: 0.3120 | Test Acc: 85.06%
# Epoch 397/500 | Train Loss: 0.2939 | Train Acc: 86.50% | Test Loss: 0.3118 | Test Acc: 85.06%
# Epoch 398/500 | Train Loss: 0.2937 | Train Acc: 86.50% | Test Loss: 0.3116 | Test Acc: 85.06%
# Epoch 399/500 | Train Loss: 0.2935 | Train Acc: 86.50% | Test Loss: 0.3115 | Test Acc: 85.06%
# Epoch 400/500 | Train Loss: 0.2933 | Train Acc: 86.50% | Test Loss: 0.3113 | Test Acc: 85.06%
# Epoch 401/500 | Train Loss: 0.2931 | Train Acc: 86.50% | Test Loss: 0.3111 | Test Acc: 85.06%
# Epoch 402/500 | Train Loss: 0.2929 | Train Acc: 86.50% | Test Loss: 0.3110 | Test Acc: 85.06%
# Epoch 403/500 | Train Loss: 0.2927 | Train Acc: 86.50% | Test Loss: 0.3108 | Test Acc: 85.06%
# Epoch 404/500 | Train Loss: 0.2925 | Train Acc: 86.50% | Test Loss: 0.3106 | Test Acc: 85.06%
# Epoch 405/500 | Train Loss: 0.2923 | Train Acc: 86.50% | Test Loss: 0.3105 | Test Acc: 85.06%
# Epoch 406/500 | Train Loss: 0.2921 | Train Acc: 86.54% | Test Loss: 0.3103 | Test Acc: 85.06%
# Epoch 407/500 | Train Loss: 0.2919 | Train Acc: 86.58% | Test Loss: 0.3101 | Test Acc: 85.06%
# Epoch 408/500 | Train Loss: 0.2917 | Train Acc: 86.58% | Test Loss: 0.3100 | Test Acc: 85.06%
# Epoch 409/500 | Train Loss: 0.2915 | Train Acc: 86.63% | Test Loss: 0.3098 | Test Acc: 85.06%
# Epoch 410/500 | Train Loss: 0.2913 | Train Acc: 86.63% | Test Loss: 0.3096 | Test Acc: 85.06%
# Epoch 411/500 | Train Loss: 0.2911 | Train Acc: 86.63% | Test Loss: 0.3095 | Test Acc: 85.06%
# Epoch 412/500 | Train Loss: 0.2909 | Train Acc: 86.72% | Test Loss: 0.3093 | Test Acc: 85.06%
# Epoch 413/500 | Train Loss: 0.2907 | Train Acc: 86.72% | Test Loss: 0.3091 | Test Acc: 85.06%
# Epoch 414/500 | Train Loss: 0.2905 | Train Acc: 86.72% | Test Loss: 0.3090 | Test Acc: 85.06%
# Epoch 415/500 | Train Loss: 0.2903 | Train Acc: 86.80% | Test Loss: 0.3088 | Test Acc: 85.24%
# Epoch 416/500 | Train Loss: 0.2901 | Train Acc: 86.80% | Test Loss: 0.3086 | Test Acc: 85.24%
# Epoch 417/500 | Train Loss: 0.2899 | Train Acc: 86.80% | Test Loss: 0.3085 | Test Acc: 85.24%
# Epoch 418/500 | Train Loss: 0.2897 | Train Acc: 86.80% | Test Loss: 0.3083 | Test Acc: 85.24%
# Epoch 419/500 | Train Loss: 0.2895 | Train Acc: 86.89% | Test Loss: 0.3081 | Test Acc: 85.41%
# Epoch 420/500 | Train Loss: 0.2893 | Train Acc: 86.89% | Test Loss: 0.3080 | Test Acc: 85.41%
# Epoch 421/500 | Train Loss: 0.2891 | Train Acc: 86.89% | Test Loss: 0.3078 | Test Acc: 85.41%
# Epoch 422/500 | Train Loss: 0.2889 | Train Acc: 86.94% | Test Loss: 0.3077 | Test Acc: 85.41%
# Epoch 423/500 | Train Loss: 0.2887 | Train Acc: 86.94% | Test Loss: 0.3075 | Test Acc: 85.41%
# Epoch 424/500 | Train Loss: 0.2885 | Train Acc: 86.98% | Test Loss: 0.3073 | Test Acc: 85.41%
# Epoch 425/500 | Train Loss: 0.2883 | Train Acc: 87.02% | Test Loss: 0.3072 | Test Acc: 85.41%
# Epoch 426/500 | Train Loss: 0.2881 | Train Acc: 87.07% | Test Loss: 0.3070 | Test Acc: 85.41%
# Epoch 427/500 | Train Loss: 0.2879 | Train Acc: 87.07% | Test Loss: 0.3069 | Test Acc: 85.59%
# Epoch 428/500 | Train Loss: 0.2877 | Train Acc: 87.11% | Test Loss: 0.3067 | Test Acc: 85.76%
# Epoch 429/500 | Train Loss: 0.2875 | Train Acc: 87.11% | Test Loss: 0.3066 | Test Acc: 85.76%
# Epoch 430/500 | Train Loss: 0.2873 | Train Acc: 87.15% | Test Loss: 0.3064 | Test Acc: 85.76%
# Epoch 431/500 | Train Loss: 0.2872 | Train Acc: 87.24% | Test Loss: 0.3062 | Test Acc: 85.76%
# Epoch 432/500 | Train Loss: 0.2870 | Train Acc: 87.29% | Test Loss: 0.3061 | Test Acc: 85.76%
# Epoch 433/500 | Train Loss: 0.2868 | Train Acc: 87.24% | Test Loss: 0.3059 | Test Acc: 85.76%
# Epoch 434/500 | Train Loss: 0.2866 | Train Acc: 87.24% | Test Loss: 0.3058 | Test Acc: 85.76%
# Epoch 435/500 | Train Loss: 0.2864 | Train Acc: 87.33% | Test Loss: 0.3056 | Test Acc: 85.76%
# Epoch 436/500 | Train Loss: 0.2862 | Train Acc: 87.33% | Test Loss: 0.3055 | Test Acc: 85.76%
# Epoch 437/500 | Train Loss: 0.2860 | Train Acc: 87.33% | Test Loss: 0.3053 | Test Acc: 85.76%
# Epoch 438/500 | Train Loss: 0.2858 | Train Acc: 87.42% | Test Loss: 0.3051 | Test Acc: 85.76%
# Epoch 439/500 | Train Loss: 0.2856 | Train Acc: 87.42% | Test Loss: 0.3050 | Test Acc: 85.76%
# Epoch 440/500 | Train Loss: 0.2855 | Train Acc: 87.46% | Test Loss: 0.3048 | Test Acc: 85.76%
# Epoch 441/500 | Train Loss: 0.2853 | Train Acc: 87.51% | Test Loss: 0.3047 | Test Acc: 85.76%
# Epoch 442/500 | Train Loss: 0.2851 | Train Acc: 87.55% | Test Loss: 0.3045 | Test Acc: 85.76%
# Epoch 443/500 | Train Loss: 0.2849 | Train Acc: 87.59% | Test Loss: 0.3044 | Test Acc: 86.12%
# Epoch 444/500 | Train Loss: 0.2847 | Train Acc: 87.68% | Test Loss: 0.3042 | Test Acc: 86.12%
# Epoch 445/500 | Train Loss: 0.2845 | Train Acc: 87.64% | Test Loss: 0.3041 | Test Acc: 86.29%
# Epoch 446/500 | Train Loss: 0.2844 | Train Acc: 87.64% | Test Loss: 0.3039 | Test Acc: 86.29%
# Epoch 447/500 | Train Loss: 0.2842 | Train Acc: 87.64% | Test Loss: 0.3038 | Test Acc: 86.47%
# Epoch 448/500 | Train Loss: 0.2840 | Train Acc: 87.72% | Test Loss: 0.3036 | Test Acc: 86.47%
# Epoch 449/500 | Train Loss: 0.2838 | Train Acc: 87.77% | Test Loss: 0.3035 | Test Acc: 86.47%
# Epoch 450/500 | Train Loss: 0.2836 | Train Acc: 87.86% | Test Loss: 0.3033 | Test Acc: 86.64%
# Epoch 451/500 | Train Loss: 0.2834 | Train Acc: 87.86% | Test Loss: 0.3032 | Test Acc: 86.64%
# Epoch 452/500 | Train Loss: 0.2833 | Train Acc: 87.94% | Test Loss: 0.3030 | Test Acc: 86.82%
# Epoch 453/500 | Train Loss: 0.2831 | Train Acc: 87.90% | Test Loss: 0.3029 | Test Acc: 86.82%
# Epoch 454/500 | Train Loss: 0.2829 | Train Acc: 88.03% | Test Loss: 0.3027 | Test Acc: 86.82%
# Epoch 455/500 | Train Loss: 0.2827 | Train Acc: 88.12% | Test Loss: 0.3026 | Test Acc: 86.82%
# Epoch 456/500 | Train Loss: 0.2826 | Train Acc: 88.16% | Test Loss: 0.3025 | Test Acc: 86.82%
# Epoch 457/500 | Train Loss: 0.2824 | Train Acc: 88.21% | Test Loss: 0.3023 | Test Acc: 86.64%
# Epoch 458/500 | Train Loss: 0.2822 | Train Acc: 88.25% | Test Loss: 0.3022 | Test Acc: 86.82%
# Epoch 459/500 | Train Loss: 0.2820 | Train Acc: 88.38% | Test Loss: 0.3020 | Test Acc: 86.82%
# Epoch 460/500 | Train Loss: 0.2819 | Train Acc: 88.38% | Test Loss: 0.3019 | Test Acc: 86.82%
# Epoch 461/500 | Train Loss: 0.2817 | Train Acc: 88.43% | Test Loss: 0.3017 | Test Acc: 86.99%
# Epoch 462/500 | Train Loss: 0.2815 | Train Acc: 88.43% | Test Loss: 0.3016 | Test Acc: 86.99%
# Epoch 463/500 | Train Loss: 0.2813 | Train Acc: 88.51% | Test Loss: 0.3014 | Test Acc: 86.99%
# Epoch 464/500 | Train Loss: 0.2812 | Train Acc: 88.60% | Test Loss: 0.3013 | Test Acc: 86.82%
# Epoch 465/500 | Train Loss: 0.2810 | Train Acc: 88.60% | Test Loss: 0.3012 | Test Acc: 86.82%
# Epoch 466/500 | Train Loss: 0.2808 | Train Acc: 88.65% | Test Loss: 0.3010 | Test Acc: 86.82%
# Epoch 467/500 | Train Loss: 0.2806 | Train Acc: 88.69% | Test Loss: 0.3009 | Test Acc: 86.82%
# Epoch 468/500 | Train Loss: 0.2805 | Train Acc: 88.69% | Test Loss: 0.3007 | Test Acc: 87.17%
# Epoch 469/500 | Train Loss: 0.2803 | Train Acc: 88.69% | Test Loss: 0.3006 | Test Acc: 86.99%
# Epoch 470/500 | Train Loss: 0.2801 | Train Acc: 88.78% | Test Loss: 0.3004 | Test Acc: 86.99%
# Epoch 471/500 | Train Loss: 0.2799 | Train Acc: 88.78% | Test Loss: 0.3003 | Test Acc: 86.99%
# Epoch 472/500 | Train Loss: 0.2798 | Train Acc: 88.82% | Test Loss: 0.3002 | Test Acc: 86.99%
# Epoch 473/500 | Train Loss: 0.2796 | Train Acc: 88.91% | Test Loss: 0.3000 | Test Acc: 86.99%
# Epoch 474/500 | Train Loss: 0.2794 | Train Acc: 88.95% | Test Loss: 0.2999 | Test Acc: 86.99%
# Epoch 475/500 | Train Loss: 0.2793 | Train Acc: 89.00% | Test Loss: 0.2998 | Test Acc: 87.17%
# Epoch 476/500 | Train Loss: 0.2791 | Train Acc: 89.00% | Test Loss: 0.2996 | Test Acc: 87.17%
# Epoch 477/500 | Train Loss: 0.2789 | Train Acc: 89.00% | Test Loss: 0.2995 | Test Acc: 87.17%
# Epoch 478/500 | Train Loss: 0.2788 | Train Acc: 89.00% | Test Loss: 0.2993 | Test Acc: 87.17%
# Epoch 479/500 | Train Loss: 0.2786 | Train Acc: 89.04% | Test Loss: 0.2992 | Test Acc: 87.17%
# Epoch 480/500 | Train Loss: 0.2784 | Train Acc: 89.00% | Test Loss: 0.2991 | Test Acc: 87.35%
# Epoch 481/500 | Train Loss: 0.2783 | Train Acc: 89.08% | Test Loss: 0.2989 | Test Acc: 87.35%
# Epoch 482/500 | Train Loss: 0.2781 | Train Acc: 89.17% | Test Loss: 0.2988 | Test Acc: 87.35%
# Epoch 483/500 | Train Loss: 0.2779 | Train Acc: 89.17% | Test Loss: 0.2987 | Test Acc: 87.35%
# Epoch 484/500 | Train Loss: 0.2778 | Train Acc: 89.17% | Test Loss: 0.2985 | Test Acc: 87.52%
# Epoch 485/500 | Train Loss: 0.2776 | Train Acc: 89.30% | Test Loss: 0.2984 | Test Acc: 87.52%
# Epoch 486/500 | Train Loss: 0.2774 | Train Acc: 89.35% | Test Loss: 0.2983 | Test Acc: 87.52%
# Epoch 487/500 | Train Loss: 0.2773 | Train Acc: 89.39% | Test Loss: 0.2981 | Test Acc: 87.52%
# Epoch 488/500 | Train Loss: 0.2771 | Train Acc: 89.39% | Test Loss: 0.2980 | Test Acc: 87.52%
# Epoch 489/500 | Train Loss: 0.2770 | Train Acc: 89.39% | Test Loss: 0.2979 | Test Acc: 87.52%
# Epoch 490/500 | Train Loss: 0.2768 | Train Acc: 89.39% | Test Loss: 0.2977 | Test Acc: 87.52%
# Epoch 491/500 | Train Loss: 0.2766 | Train Acc: 89.39% | Test Loss: 0.2976 | Test Acc: 87.35%
# Epoch 492/500 | Train Loss: 0.2765 | Train Acc: 89.39% | Test Loss: 0.2975 | Test Acc: 87.35%
# Epoch 493/500 | Train Loss: 0.2763 | Train Acc: 89.39% | Test Loss: 0.2973 | Test Acc: 87.35%
# Epoch 494/500 | Train Loss: 0.2762 | Train Acc: 89.39% | Test Loss: 0.2972 | Test Acc: 87.17%
# Epoch 495/500 | Train Loss: 0.2760 | Train Acc: 89.39% | Test Loss: 0.2971 | Test Acc: 87.17%
# Epoch 496/500 | Train Loss: 0.2758 | Train Acc: 89.39% | Test Loss: 0.2969 | Test Acc: 87.17%
# Epoch 497/500 | Train Loss: 0.2757 | Train Acc: 89.43% | Test Loss: 0.2968 | Test Acc: 87.17%
# Epoch 498/500 | Train Loss: 0.2755 | Train Acc: 89.43% | Test Loss: 0.2967 | Test Acc: 87.17%
# Epoch 499/500 | Train Loss: 0.2754 | Train Acc: 89.43% | Test Loss: 0.2965 | Test Acc: 87.17%
# Epoch 500/500 | Train Loss: 0.2752 | Train Acc: 89.43% | Test Loss: 0.2964 | Test Acc: 87.17%
# Model finished training and validation.

# %% [markdown]
# @function `evaluate_model_performance()`:
#
# * Generates a comprehensive visual report of the model's training history and final classification performance in a 3-row vertical layout.
#
# * **Loss Curve**: Visualizes the relationship between training and validation loss across epochs to detect overfitting or convergence issues.
#
# * **Accuracy Curve** : Tracks the percentage of correct predictions over time for both the training and test sets.
#
# * **Confusion Matrix** : Calculate the classification metrics (TP, TN, FP, FN) and displays them as a Seaborn heatmap for error analysis.
#
# * params
#     * `history`: A dictionary containing the logged lists of loss and accuracy values.
#     * `y_true` : The truth labels from the test dataset.
#     * `y_pred` : The binary predictions (0 or 1) generated by the model.
#     * `title` : string used as the main heading for the entire figure.

# %%
def evaluate_model_performance(history:dict, y_true:list, y_pred:list, title:str):
    # Create a figure within 3 rows
    fig, axes = plt.subplots(3, 1, figsize=(6, 20))
    fig.suptitle(f'Model Evaluation: {title}', fontsize=16, fontweight='bold')

    # --- 1. Loss Curve Plot ---
    train_loss = history['train_loss']
    val_loss = history['test_loss']
    epochs = range(1, len(train_loss) + 1)

    axes[0].plot(epochs, train_loss, label='Training Loss', color='blue', lw=1.5, marker='x', ms=4)
    axes[0].plot(epochs, val_loss, label='Validation Loss', color='orange', lw=1.5, marker='x', ms=4)
    axes[0].set_title('Loss Curve (Learning Curve)')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # --- 2. Accuracy Plot ---
    train_acc = history['train_acc']
    val_acc = history['test_acc']
    axes[1].plot(epochs, train_acc, label='Training Accuracy', color='blue', lw=1.5, marker='x', ms=4)
    axes[1].plot(epochs, val_acc, label='Validation Accuracy', color='orange', lw=1.5, marker='x', ms=4)
    axes[1].set_title('Accuracy Over Epochs')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    # --- 3. Confusion Matrix ---
    actual = np.array(y_true).flatten()
    predicted = np.array(y_pred).flatten()
    
    tp = np.sum((actual == 1) & (predicted == 1))
    tn = np.sum((actual == 0) & (predicted == 0))
    fp = np.sum((actual == 0) & (predicted == 1))
    fn = np.sum((actual == 1) & (predicted == 0))
    cm = np.array([[tn, fp], [fn, tp]])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Stay', 'Churn'], 
            yticklabels=['Stay', 'Churn'],
            ax=axes[2])
    axes[2].set_title('Confusion Matrix: Churn Prediction')
    axes[2].set_ylabel('Actual')
    axes[2].set_xlabel('Predicted')
    # Adjust layout to prevent overlap
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
    
evaluate_model_performance(history, y_test, y_hat, title='Model 1: Binary Cross Entropy')
