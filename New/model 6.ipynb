# %% [markdown]
# ## 6th Model : Softmax Activation Function
# - Network Architecture:
#     - 2 hidden layers
#     - RelU Activation on Hidden
#     - Softmax Activation on Output
#     - learning rate = 0.01
#     - epoch = 500

# %% [markdown]
# ## Steps:
# 1. Import Libraries
# 2. Read Data from `\Dataset` folder (Retrieved from UCI Repositories)
# 3. Clean Dataset (rename and format the column)
# 4. Data Preprocessing
# 5. Initialize the model
# 6. Train and test the data
# 7. Evaluate Performance using graph

# %% [markdown]
# ### 0. Install Library Requirements

# %%
# %pip install jupyter numpy pandas matplotlib seaborn tabulate imblearn

# %% [markdown]
# ### 1. Import Libraries
# Import necessary libraries:
# * `numpy`     : High performance array object
# * `pandas`    : Data analysis and manipulation tools
# * `matplotlib`: Data visualizations
# * `seaborn`   : Data visualizations framework based on **matplotlib**
# * `tabulate`  : Pretty-print tabular structure library
# * `imblearn`  : SMOTE class balance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
from imblearn.over_sampling import SMOTE
import seaborn as sns

# %% [markdown]
# #### 1.1 Helper Functions
# * Handle mathematical operation used in the `NeuralNetwork` Class

# %%
def sigmoid(x): return 1 /(1 + np.exp(-x))
def relu(x): return np.maximum(0,x)
def derivative_relu(relu_x): return (relu_x>0).astype(float)
def softmax(z):
        exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))  # Numerical stability
        return exp_z / np.sum(exp_z, axis=1, keepdims=True)
def categorical_cross_entropy(y_true, y_pred):
    epsilon = 1e-8
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
    return -np.mean(np.sum(y_true * np.log(y_pred), axis=1))

# %% [markdown]
# ### 2. Read and Display Dataset Information
# load the dataset and understand the data, and use the Interquartile Range (IQR) method to identify potential outliers in numerical columns.
# 2.1 Read dataset

# %%
def read_file(file_path: str):
    df = pd.read_csv(file_path)
    new_columns = [col.strip().replace('  ', ' ').replace(' ', '_').lower() for col in df.columns]
    df.columns = new_columns
    return df

path = r'..\Dataset\Customer Churn.csv'
df = read_file(path)
df.head(20)
# Out:
#     call_failure  complains  subscription_length  charge_amount  \
# 0              8          0                   38              0
# 1              0          0                   39              0
# 2             10          0                   37              0
# 3             10          0                   38              0
# 4              3          0                   38              0
# 5             11          0                   38              1
# 6              4          0                   38              0
# 7             13          0                   37              2
# 8              7          0                   38              0
# 9              7          0                   38              1
# 10             6          0                   38              0
# 11             9          0                   38              0
# 12            25          0                   38              3
# 13             4          0                   38              1
# 14             9          0                   37              0
# 15             3          0                   37              1
# 16             0          0                   37              0
# 17             2          0                   38              0
# 18             0          0                   37              0
# 19             3          0                   37              0
#
#     seconds_of_use  frequency_of_use  frequency_of_sms  \
# 0             4370                71                 5
# 1              318                 5                 7
# 2             2453                60               359
# 3             4198                66                 1
# 4             2393                58                 2
# 5             3775                82                32
# 6             2360                39               285
# 7             9115               121               144
# 8            13773               169                 0
# 9             4515                83                 2
# 10            5918                95                 7
# 11            2238                54                 8
# 12           15140               225                54
# 13            3095                27               483
# 14           15485               182               150
# 15            6500                86               186
# 16             875                14                 0
# 17             710                14                13
# 18               0                 0                 0
# 19            7508               127               384
#
#     distinct_called_numbers  age_group  tariff_plan  status  age  \
# 0                        17          3            1       1   30
# 1                         4          2            1       2   25
# 2                        24          3            1       1   30
# 3                        35          1            1       1   15
# 4                        33          1            1       1   15
# 5                        28          3            1       1   30
# 6                        18          3            1       1   30
# 7                        43          3            1       1   30
# 8                        44          3            1       1   30
# 9                        25          3            1       1   30
# 10                       12          3            1       1   30
# 11                       17          3            1       2   30
# 12                       32          3            1       1   30
# 13                        8          3            1       1   30
# 14                       30          2            1       1   25
# 15                       26          3            1       1   30
# 16                       11          2            1       2   25
# 17                        8          3            1       2   30
# 18                        0          2            1       2   25
# 19                       43          2            1       1   25
#
#     customer_value  churn
# 0          197.640      0
# 1           46.035      0
# 2         1536.520      0
# 3          240.020      0
# 4          145.805      0
# 5          282.280      0
# 6         1235.960      0
# 7          945.440      0
# 8          557.680      0
# 9          191.920      0
# 10         268.520      0
# 11         123.680      0
# 12         830.600      0
# 13        2056.880      0
# 14        1380.015      0
# 15        1007.440      0
# 16          40.005      1
# 17          80.960      0
# 18           0.000      1
# 19        2071.575      0

# %% [markdown]
# 2.2 Display dataset data types and null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_failure             3150 non-null   int64
#  1   complains                3150 non-null   int64
#  2   subscription_length      3150 non-null   int64
#  3   charge_amount            3150 non-null   int64
#  4   seconds_of_use           3150 non-null   int64
#  5   frequency_of_use         3150 non-null   int64
#  6   frequency_of_sms         3150 non-null   int64
#  7   distinct_called_numbers  3150 non-null   int64
#  8   age_group                3150 non-null   int64
#  9   tariff_plan              3150 non-null   int64
#  10  status                   3150 non-null   int64
#  11  age                      3150 non-null   int64
#  12  customer_value           3150 non-null   float64
#  13  churn                    3150 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 344.7 KB

# %% [markdown]
# 2.3 Display dataset shape and its statisical values

# %%
df.describe()
# Out:
#        call_failure    complains  subscription_length  charge_amount  \
# count   3150.000000  3150.000000          3150.000000    3150.000000
# mean       7.627937     0.076508            32.541905       0.942857
# std        7.263886     0.265851             8.573482       1.521072
# min        0.000000     0.000000             3.000000       0.000000
# 25%        1.000000     0.000000            30.000000       0.000000
# 50%        6.000000     0.000000            35.000000       0.000000
# 75%       12.000000     0.000000            38.000000       1.000000
# max       36.000000     1.000000            47.000000      10.000000
#
#        seconds_of_use  frequency_of_use  frequency_of_sms  \
# count     3150.000000       3150.000000       3150.000000
# mean      4472.459683         69.460635         73.174921
# std       4197.908687         57.413308        112.237560
# min          0.000000          0.000000          0.000000
# 25%       1391.250000         27.000000          6.000000
# 50%       2990.000000         54.000000         21.000000
# 75%       6478.250000         95.000000         87.000000
# max      17090.000000        255.000000        522.000000
#
#        distinct_called_numbers    age_group  tariff_plan       status  \
# count              3150.000000  3150.000000  3150.000000  3150.000000
# mean                 23.509841     2.826032     1.077778     1.248254
# std                  17.217337     0.892555     0.267864     0.432069
# min                   0.000000     1.000000     1.000000     1.000000
# 25%                  10.000000     2.000000     1.000000     1.000000
# 50%                  21.000000     3.000000     1.000000     1.000000
# 75%                  34.000000     3.000000     1.000000     1.000000
# max                  97.000000     5.000000     2.000000     2.000000
#
#                age  customer_value        churn
# count  3150.000000     3150.000000  3150.000000
# mean     30.998413      470.972916     0.157143
# std       8.831095      517.015433     0.363993
# min      15.000000        0.000000     0.000000
# 25%      25.000000      113.801250     0.000000
# 50%      30.000000      228.480000     0.000000
# 75%      30.000000      788.388750     0.000000
# max      55.000000     2165.280000     1.000000

# %% [markdown]
# 2.4. Detect Outliers

# %%
def detect_outliers_iqr(df, k=1.5):
    nums = df.select_dtypes(include='number')
    outlier_info = {}
    
    for c in nums.columns:
        #skip binary columns
        if(nums[c].nunique() <= 2):
            continue
        
        q1 = nums[c].quantile(0.25) #1st quartile
        q3 = nums[c].quantile(0.75) #3rd quartile
        iqr = q3 - q1
        lower = q1 - k * iqr
        upper = q3 + k * iqr
        mask = (nums[c] < lower) | (nums[c] > upper)
        outlier_info[c] = {
            'count': int(mask.sum()),
            'indices': nums.index[mask].tolist(),
            'lower': float(lower),
            'upper': float(upper)
        }
    return outlier_info

outliers = detect_outliers_iqr(df)
table_data = []
print('\nOutlier summary (IQR method):')
for col, info in outliers.items():
    if info['count'] > 0:
    # Calculate percentage
        perc = (info["count"] / len(df)) * 100
        
        # Add a list (row) to our table_data
        table_data.append([col, info["count"], f"{info['lower']:.3f}",
            f"{info['upper']:.3f}", f"{perc:.2f}%"])
headers = ["Column", "Outlier Count", "Lower Bound", "Upper Bound", "Percentage"]
print(tabulate(table_data, headers=headers))
# Out:
# Outlier summary (IQR method):
# Column                     Outlier Count    Lower Bound    Upper Bound  Percentage
# -----------------------  ---------------  -------------  -------------  ------------
# call_failure                          47         -15.5           28.5   1.49%
# subscription_length                  282          18             50     8.95%
# charge_amount                        370          -1.5            2.5   11.75%
# seconds_of_use                       200       -6239.25       14108.8   6.35%
# frequency_of_use                     129         -75            197     4.10%
# frequency_of_sms                     368        -115.5          208.5   11.68%
# distinct_called_numbers               77         -26             70     2.44%
# age_group                            170           0.5            4.5   5.40%
# age                                  688          17.5           37.5   21.84%
# customer_value                       116        -898.08        1800.27  3.68%

# %% [markdown]
# ### 3. Data Cleaning
# This process take step before handling with outliers and data preprocessing.
#
# 3.1 Remove Duplicate Row (if any)

# %%
df = df.drop_duplicates()
print(f'\n[Changes] Removed duplicate rows. New shape={df.shape}\n')
# Out:
# [Changes] Removed duplicate rows. New shape=(2850, 14)

# %% [markdown]
# 3.2 Remove Redundant Groups
#
# `age_group` and `age` columns both have the same values but in different types, numeric and nominal respectively.
# `age_group` column is dropped to prevent biases when learning

# %%
df = df.drop(columns=['age_group'])
print(f'\n[Changes] Dropped column: age_group due to redundancy. New shape={df.shape}\n\n')
# Out:
# [Changes] Dropped column: age_group due to redundancy. New shape=(2850, 13)

# %% [markdown]
# ### 4. Data Preprocessing
#
# The dataset will follows the exact steps to avoid any imbalance or data leakage during testing.

# %% [markdown]
# [Split] -> [Log] -> [Encode] -> [Fit] -> [Scale] -> [Balance]

# %% [markdown]
# #### 4.1 Split
#
# * Splitting the dataset into train, and test sets, and both input,X and output,Y
# * This function will reset the intialized index of X and Y dataset, and shuffle them before splitting to prevent **data leakage**
#
# @function `split_data()`:
# * params
#     * `X`, `y` as input and output
#     * `test_split` as testing split percentage ; default `0.2`
#     * `randomness` as random values for randomize dataset index before splitting ; default `None`
# * return
#     * `X_train` = Training set without `Churn`
#     * `Y_train` = `Churn` Training column
#     * `Y_train` = Testing set without `Churn`
#     * `Y_test` = `Churn` Testing column

# %%
def split_data(X, y, test_split=0.2, randomness=None):
    # Set seed for reproducibility
    if randomness is not None:
        np.random.seed(randomness)
    
    # reset X and Y current index
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    
    # Identify unique classes and their indices (0 and 1)
    unique_classes = np.unique(y)
    train_indices = []
    test_indices = []
    
    for cls in unique_classes:
        # Get indices of rows belonging to this class
        cls_indices = np.where(y == cls)[0]

        # Shuffle indices within this specific class
        np.random.shuffle(cls_indices)

        # Determine the split point
        total_count = len(cls_indices)
        test_count = int(total_count * test_split)
        
        # Split indices
        cls_test = cls_indices[:test_count]
        cls_train = cls_indices[test_count:]
        
        # Add to main lists
        test_indices.extend(cls_test)
        train_indices.extend(cls_train)
        
    # Shuffle the final combined indices so they aren't grouped by class
    np.random.shuffle(train_indices)
    np.random.shuffle(test_indices)
    
    # Use .iloc for DataFrames to select the rows
    X_train, X_test = X.iloc[train_indices], X.iloc[test_indices]
    y_train, y_test = y.iloc[train_indices], y.iloc[test_indices]
    return X_train, X_test, y_train, y_test

X = df.drop(columns=['churn'], axis=1)
Y = df['churn']
X_train,X_test,y_train,y_test = split_data(X,Y,test_split=0.2, randomness=42)
print(f'[Changes] Successfully split data into Training and Testing.')
# Out:
# [Changes] Successfully split data into Training and Testing.

# %% [markdown]
# #### 4.2 Log Transformation
#
# * This will treat the outliers found before, compressing all the values within the dataset to **reduce** the skewness of the data
# * This step is to prevent unfair patterns.
# * Use `numpy.log(1 + x)`
# * log transformation on seperated train and test set to prevent **data leakage**
#
# @function `log_transformation()`:
# * params
#     * `df_train`, `df_test` as training and testing dataset
#     * `cols_log` as list of column to be log transformed
# * return
#     * `df_train` = train dataset that have been log transformed
#     * `df_test` = test dataset that have been log transformed

# %%
def log_transformation(df_train, df_test, cols_log: list):
    for col in cols_log:
        df_train[col] = np.log1p(df_train[col])
        df_test[col] = np.log1p(df_test[col])
    print(f'[Changes] Applied log transformation to selected columns.')
    return df_train, df_test

cols_to_log = [
    'seconds_of_use',
    'frequency_of_use',
    'frequency_of_sms',
    'distinct_called_numbers',
    'call_failure',
    'customer_value',
    'charge_amount'
]
X_train, X_test = log_transformation(X_train,X_test,cols_to_log)
# Out:
# [Changes] Applied log transformation to selected columns.

# %% [markdown]
# #### 4.3 One-Hot Encoding
#
# * Convert categorical column into multiple, numeric dummy columns that values between `0` and `1`.
# * Example: `plan` have 3 categories  = `[cat1, cat2, cat3]`. It will split into dummy columns for each category, `plan_cat1`, `plan_cat2`, `plan_cat3`
# * use drop first column attribute to prevent **multicollinearity**
#
# @function `get_train_category()`:
# * params
#     * `df` as dataset
#     * `col_name` retrieve category from this column
# * return
#     * `list` = list of column name
#
#
# @function `one_hot_encoding()`:
# * params
#     * `df` as dataset
#     * `col_name` as column name that will apply one-hot encoding
#     * `categories` as category inside `col_name`
#     * `drop_first` drop first column to simplify the dummy column
# * return
#     * `converted_pd` = return the dataframe with the added dummy columns

# %%
def get_train_categories(df, col_name):
    return sorted(list(set(df[col_name].tolist())))

def one_hot_encoding(df, col_name:str, categories, drop_first = True):
    data = df[col_name].tolist()
    
    active_cats = categories[1:] if drop_first and len(categories) > 1 else categories
    
    encoded_mtx = []
    for item in data:
        row = [0] * len(active_cats)
        if item in active_cats:
            index = active_cats.index(item)
            row[index] = 1
        encoded_mtx.append(row)
    
    #rename column for one hot encoded column
    new_cols = [f'{col_name}_{cat}' for cat in active_cats]
    #convert back to dataframe
    converted_pd  = pd.DataFrame(encoded_mtx, columns=new_cols,index=df.index)
    return converted_pd

train_encoded_parts = []
test_encoded_parts = []

categorical = ['complains', 'tariff_plan', 'status']
for col in categorical:
    train_categories = get_train_categories(X_train, col)
    train_encoded_parts.append(one_hot_encoding(X_train, col, train_categories, drop_first=True))        
    test_encoded_parts.append(one_hot_encoding(X_test, col, train_categories, drop_first=True))
print(f'[Changes] Applied one hot encoding to categorical columns')

#drop old column and join new columns
X_train = X_train.drop(columns=categorical).join(train_encoded_parts)
X_test = X_test.drop(columns=categorical).join(test_encoded_parts)
# Out:
# [Changes] Applied one hot encoding to categorical columns

# %% [markdown]
# #### 4.4 Scaling Feature
#
# * Transforms features to fit within a specific range, usually `0`, by subtracting the minimum value and dividing by the range `(max - min)`
# * Using `min()` and `max()` function to retrieve the minimum and maximum value in a column
# * Scales the transformation on training data, and transform on train and test dataset to prevent data leakage
#
# @function `get_scaling_params()`:
# * params
#     * `df_train` as training input dataset
# * return
#     * `param_dict` = a dictionary contains the minimum and maximum value for every key column
#
# @function `min_max_transform()`:
# * params
#     * `df` as input dataset
#     * `params` as dicitionary containing min and max value for each column
# * return
#     * `df_scaled` = scaled dataset

# %%
def get_scaling_params(df_train):
    param_dict = {}
    for col in df_train.columns:   
        min_val = min(df_train[col])
        max_val = max(df_train[col])
        param_dict[col] = (min_val, max_val - min_val)
    return param_dict

#eg: min_max_transform(X_TEST, train_min_val, train_data_range)
def min_max_transform(df, params: dict):
    df_scaled = df.copy()

    for col, (min_v, data_range) in params.items():
        if data_range == 0:
            df_scaled[col] = 0.0 #base case float number
        else:
            df_scaled[col] = (df[col] - min_v) / data_range
            
    return df_scaled

X_train_scale_params = get_scaling_params(X_train)
X_train_scaled = min_max_transform(X_train, X_train_scale_params)
X_test_scaled = min_max_transform(X_test, X_train_scale_params)
print(f'[Changes] Applied Min Max Scaler on numerical columns')
# Out:
# [Changes] Applied Min Max Scaler on numerical columns

# %% [markdown]
# #### 4.5 Class Balancing
#
# * The dataset contains around 80% `0` (Not Churn) and 20% `1` (Churn), causing imbalance and can cause the model to become biased, favor the majority class, and perform poorly on the crucial minority class.
# * `SMOTE` is a **oversampling** technique used to create synthetic data using its algorithm to balance the class.
# * Only apply to training data only to prevent data leakage

# %%
# smote = SMOTE(sampling_strategy=0.8, random_state=42)
# X_train_final, y_train_final = smote.fit_resample(X_train_scaled, y_train)
# print(f"Before SMOTE - Class Distribution: {y_train.value_counts()}")
# print(f"After SMOTE - Class Distribution: {pd.Series(y_train_final).value_counts()}")
# print(f"Final training set size: {len(X_train_final)}")

# %% [markdown]
# ### 5. Initialize the Model
#
# #### 5.1 Intialize Variables
# * `EPOCHS`      : Iteration counts
# * `BATCH_SIZE`  : Hyperparameter of size of batch for smaller subsets
# * `PATIENCE`    : Hyperparameter stopping condition that wait for an improvement
# * `input_dim` = input layer size (nodes)

# %%
EPOCHS = 500
BATCH_SIZE = 32
PATIENCE = 100

input_dim = X_train_scaled.shape[1]

# %% [markdown]
# @Class `NeuralNetwork`
# * A multi-layer perceptron (Backpropagation Neural Network) designed for binary classification.
# * He initialization for weight stability, mini-batch gradient descent, and early stopping based on patience or error thresholds.
#
# @function `feedforward()`:
# * Feed the data forward, [Input] -> w1 -> [Hidden] -> w2 -> [Output]
# * Input to hidden layer will use **ReLU** activation function to handle nonlinear
# * Hidden layer to output layer will use **Sigmoid** activation function to **0 - 1** output
#
# @function `backpropagation()`:
# * Calculates the gradients of the loss function with respect to each weight and bias in the network.
# * Uses Gradient Clipping (max value of 5.0) to prevent exploding gradients and stability.
# * Updates weight1, weight2, bias1, and bias2 using the calculated deltas and the learning rate (`alpha`).
#
# @function `train()`
# * Manages the entire learning process over a set number of EPOCHS using Mini-batch Gradient Descent.
# * Shuffles the training data every epoch to improve generalization and prevent the model from learning the order of the data.
# * Stopping Condition:
#     * `max_error`
#     * `patience`
#
# @function `calculate_accuracy()`
# * Computes the percentage of correct predictions by comparing predicted probabilities against true labels
# * 0.5 threshold to convert sigmoid probabilities into binary classes (0 or 1).
#
# @function `predict()`
# * Performs a final feedforward pass on unseen data to generate class predictions.
# * Flattens the final output and applies a boolean threshold (0.5) to return integer class labels.

# %%
class NeuralNetwork:
    def __init__(self, input_dimension, hidden1_nodes=16, hidden2_nodes=8, alpha=0.01):
        self.alpha = alpha        
        self.weight1 = np.random.randn(input_dimension, hidden1_nodes) * np.sqrt(2/input_dimension)
        self.weight2 = np.random.randn(hidden1_nodes, hidden2_nodes) * np.sqrt(2/hidden1_nodes)
        self.weight3 = np.random.randn(hidden2_nodes, 2) * np.sqrt(2/hidden2_nodes)
        self.bias1 = np.zeros((1, hidden1_nodes))
        self.bias2 = np.zeros((1, hidden2_nodes))
        self.bias3 = np.zeros((1, 2))  # ← Bias for 2 classes
        
        self.train_loss, self.test_loss, self.train_acc, self.test_acc = [], [], [], []
        self.history = {
            'train_loss': self.train_loss,
            'test_loss': self.test_loss,
            'train_acc': self.train_acc,
            'test_acc': self.test_acc
        }    
        
    def feedforward(self,X):
        self.hidden1_Z = X @ self.weight1 + self.bias1
        self.hidden1_A = relu(self.hidden1_Z)
        self.hidden2_Z = self.hidden1_A @ self.weight2 + self.bias2
        self.hidden2_A = relu(self.hidden2_Z)
        self.output_Z = self.hidden2_A @ self.weight3 + self.bias3
        self.output_A = softmax(self.output_Z)  # Softmax instead of Sigmoid
        
        return self.output_A
    
    def backpropagation(self, X, y, output):
        size = y.shape[0]
        d_output = output - y
        d_weight3 = self.hidden2_A.T @ d_output / size  
        d_bias3 = np.sum(d_output, axis=0, keepdims=True) / size
        
        d_hidden2_A = d_output @ self.weight3.T
        d_hidden2_Z = d_hidden2_A * derivative_relu(self.hidden2_Z)
        d_weight2 = self.hidden1_A.T @ d_hidden2_Z / size
        d_bias2 = np.sum(d_hidden2_Z, axis=0, keepdims=True) / size
        
        d_hidden1_A = d_hidden2_Z @ self.weight2.T
        d_hidden1_Z = d_hidden1_A * derivative_relu(self.hidden1_Z)
        d_weight1 = X.T @ d_hidden1_Z / size
        d_bias1 = np.sum(d_hidden1_Z, axis=0, keepdims=True) / size
        
        # Update weights
        self.weight3 -= self.alpha * d_weight3
        self.bias3 -= self.alpha * d_bias3
        self.weight2 -= self.alpha * d_weight2
        self.bias2 -= self.alpha * d_bias2
        self.weight1 -= self.alpha * d_weight1
        self.bias1 -= self.alpha * d_bias1

    def calculate_accuracy(self, y_true, y_pred_prob):
        # Threshold at 0.5 for binary classification
        predictions = (y_pred_prob > 0.5).astype(int)
        correct = np.sum(predictions == y_true)
        return correct / len(y_true)
    
    def train(self, X_train, y_train, X_test, y_test):
        epochs = EPOCHS
        batch_size = BATCH_SIZE
        max_error = 0.01
        best_loss = float('inf')
        patience_count = 0
        patience = PATIENCE
        
        X_tr = X_train.values if isinstance(X_train, pd.DataFrame) else X_train
        X_te = X_test.values if isinstance(X_test, pd.DataFrame) else X_test
        
        y_train_arr = np.array(y_train).flatten()
        y_test_arr = np.array(y_test).flatten()
        
        y_tr = np.zeros((len(y_train_arr), 2))
        y_tr[np.arange(len(y_train_arr)), y_train_arr] = 1
        
        y_te = np.zeros((len(y_test_arr), 2))
        y_te[np.arange(len(y_test_arr)), y_test_arr] = 1
        
        n_samples = X_tr.shape[0]
        
        for epoch in range(epochs):
            # Shuffle data each epoch
            indices = np.random.permutation(n_samples)
            X_tr_shuffled = X_tr[indices]
            y_tr_shuffled = y_tr[indices]
            
            # Mini-batch training
            for i in range(0, n_samples, batch_size):
                batch_X = X_tr_shuffled[i:i+batch_size]
                batch_y = y_tr_shuffled[i:i+batch_size]
                
                output = self.feedforward(batch_X)
                self.backpropagation(batch_X, batch_y, output)
            
            # Calculate metrics on full dataset
            output_full = self.feedforward(X_tr)
            train_loss = categorical_cross_entropy(y_tr, output_full)
            train_pred = np.argmax(output_full, axis=1)
            train_acc = np.mean(train_pred == y_train_arr) * 100
            
            output_test = self.feedforward(X_te)
            test_loss = categorical_cross_entropy(y_te, output_test)
            test_pred = np.argmax(output_test, axis=1)
            test_acc = np.mean(test_pred == y_test_arr) * 100
            
            self.train_loss.append(train_loss)
            self.test_loss.append(test_loss)
            self.train_acc.append(train_acc)
            self.test_acc.append(test_acc)
            
            print(f'Epoch {epoch + 1}/{epochs} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%')
            
            if test_loss < best_loss:
                best_loss = test_loss
                patience_count = 0
            else:
                patience_count += 1
            
            if patience_count >= patience:
                print(f'[Training Stopped] Patience {patience} reached')
                break
            
            if train_loss <= max_error:
                print(f'[Training Stopped] Max error {max_error} reached')
                break
        
        return self.history
    
    def predict(self, X):
        X_vals = X.values if isinstance(X, pd.DataFrame) else X
        
        # Forward pass
        h1_Z = X_vals @ self.weight1 + self.bias1
        h1_A = relu(h1_Z)
        
        h2_Z = h1_A @ self.weight2 + self.bias2
        h2_A = relu(h2_Z)
        
        o_Z = h2_A @ self.weight3 + self.bias3
        probs = softmax(o_Z)
        
        # Return class with highest probability
        return np.argmax(probs, axis=1)

# %% [markdown]
# 5.2 Initialize, Train and Predict
#
# * Input Layer : 12 nodes
# * Hidden Layer : 8 nodes
# * Learning Rate : 0.01
# * Epochs : 500
# * Batch Size : 32

# %%
nn = NeuralNetwork(input_dimension= input_dim, alpha=0.01)
history = nn.train(X_train_scaled, y_train, X_test_scaled, y_test)    
y_hat = nn.predict(X_test_scaled)

print('Model finished training and validation.')
# Out:
# Epoch 1/500 | Train Loss: 0.4237 | Train Acc: 84.35% | Test Loss: 0.4210 | Test Acc: 84.36%
# Epoch 2/500 | Train Loss: 0.3555 | Train Acc: 84.92% | Test Loss: 0.3640 | Test Acc: 85.24%
# Epoch 3/500 | Train Loss: 0.3117 | Train Acc: 86.41% | Test Loss: 0.3288 | Test Acc: 86.12%
# Epoch 4/500 | Train Loss: 0.2822 | Train Acc: 88.69% | Test Loss: 0.3032 | Test Acc: 86.99%
# Epoch 5/500 | Train Loss: 0.2640 | Train Acc: 89.96% | Test Loss: 0.2874 | Test Acc: 87.70%
# Epoch 6/500 | Train Loss: 0.2542 | Train Acc: 90.27% | Test Loss: 0.2804 | Test Acc: 87.87%
# Epoch 7/500 | Train Loss: 0.2472 | Train Acc: 90.14% | Test Loss: 0.2752 | Test Acc: 88.22%
# Epoch 8/500 | Train Loss: 0.2406 | Train Acc: 90.14% | Test Loss: 0.2701 | Test Acc: 88.22%
# Epoch 9/500 | Train Loss: 0.2388 | Train Acc: 90.27% | Test Loss: 0.2693 | Test Acc: 87.70%
# Epoch 10/500 | Train Loss: 0.2357 | Train Acc: 90.09% | Test Loss: 0.2671 | Test Acc: 88.05%
# Epoch 11/500 | Train Loss: 0.2333 | Train Acc: 89.83% | Test Loss: 0.2655 | Test Acc: 87.87%
# Epoch 12/500 | Train Loss: 0.2319 | Train Acc: 90.00% | Test Loss: 0.2647 | Test Acc: 87.87%
# Epoch 13/500 | Train Loss: 0.2308 | Train Acc: 89.92% | Test Loss: 0.2641 | Test Acc: 88.22%
# Epoch 14/500 | Train Loss: 0.2301 | Train Acc: 90.31% | Test Loss: 0.2635 | Test Acc: 88.40%
# Epoch 15/500 | Train Loss: 0.2292 | Train Acc: 90.44% | Test Loss: 0.2630 | Test Acc: 88.05%
# Epoch 16/500 | Train Loss: 0.2285 | Train Acc: 90.22% | Test Loss: 0.2628 | Test Acc: 88.40%
# Epoch 17/500 | Train Loss: 0.2289 | Train Acc: 90.00% | Test Loss: 0.2636 | Test Acc: 88.22%
# Epoch 18/500 | Train Loss: 0.2274 | Train Acc: 90.40% | Test Loss: 0.2615 | Test Acc: 87.87%
# Epoch 19/500 | Train Loss: 0.2278 | Train Acc: 90.18% | Test Loss: 0.2616 | Test Acc: 87.70%
# Epoch 20/500 | Train Loss: 0.2266 | Train Acc: 90.31% | Test Loss: 0.2613 | Test Acc: 88.40%
# Epoch 21/500 | Train Loss: 0.2261 | Train Acc: 90.40% | Test Loss: 0.2606 | Test Acc: 88.05%
# Epoch 22/500 | Train Loss: 0.2262 | Train Acc: 90.14% | Test Loss: 0.2605 | Test Acc: 87.70%
# Epoch 23/500 | Train Loss: 0.2255 | Train Acc: 90.36% | Test Loss: 0.2605 | Test Acc: 88.40%
# Epoch 24/500 | Train Loss: 0.2251 | Train Acc: 90.44% | Test Loss: 0.2598 | Test Acc: 88.05%
# Epoch 25/500 | Train Loss: 0.2262 | Train Acc: 89.96% | Test Loss: 0.2601 | Test Acc: 87.87%
# Epoch 26/500 | Train Loss: 0.2264 | Train Acc: 90.27% | Test Loss: 0.2618 | Test Acc: 88.22%
# Epoch 27/500 | Train Loss: 0.2257 | Train Acc: 89.96% | Test Loss: 0.2596 | Test Acc: 87.87%
# Epoch 28/500 | Train Loss: 0.2251 | Train Acc: 89.96% | Test Loss: 0.2590 | Test Acc: 87.87%
# Epoch 29/500 | Train Loss: 0.2250 | Train Acc: 89.83% | Test Loss: 0.2589 | Test Acc: 87.87%
# Epoch 30/500 | Train Loss: 0.2238 | Train Acc: 90.05% | Test Loss: 0.2581 | Test Acc: 87.70%
# Epoch 31/500 | Train Loss: 0.2234 | Train Acc: 90.36% | Test Loss: 0.2585 | Test Acc: 88.58%
# Epoch 32/500 | Train Loss: 0.2248 | Train Acc: 89.87% | Test Loss: 0.2585 | Test Acc: 87.70%
# Epoch 33/500 | Train Loss: 0.2229 | Train Acc: 90.36% | Test Loss: 0.2579 | Test Acc: 88.58%
# Epoch 34/500 | Train Loss: 0.2227 | Train Acc: 90.14% | Test Loss: 0.2569 | Test Acc: 87.70%
# Epoch 35/500 | Train Loss: 0.2221 | Train Acc: 90.62% | Test Loss: 0.2567 | Test Acc: 88.05%
# Epoch 36/500 | Train Loss: 0.2224 | Train Acc: 90.44% | Test Loss: 0.2574 | Test Acc: 88.75%
# Epoch 37/500 | Train Loss: 0.2217 | Train Acc: 90.62% | Test Loss: 0.2563 | Test Acc: 88.22%
# Epoch 38/500 | Train Loss: 0.2218 | Train Acc: 90.40% | Test Loss: 0.2568 | Test Acc: 88.58%
# Epoch 39/500 | Train Loss: 0.2224 | Train Acc: 89.92% | Test Loss: 0.2561 | Test Acc: 87.87%
# Epoch 40/500 | Train Loss: 0.2213 | Train Acc: 90.27% | Test Loss: 0.2553 | Test Acc: 87.87%
# Epoch 41/500 | Train Loss: 0.2210 | Train Acc: 90.57% | Test Loss: 0.2557 | Test Acc: 88.40%
# Epoch 42/500 | Train Loss: 0.2232 | Train Acc: 90.40% | Test Loss: 0.2585 | Test Acc: 88.40%
# Epoch 43/500 | Train Loss: 0.2204 | Train Acc: 90.40% | Test Loss: 0.2544 | Test Acc: 88.05%
# Epoch 44/500 | Train Loss: 0.2207 | Train Acc: 90.49% | Test Loss: 0.2553 | Test Acc: 88.58%
# Epoch 45/500 | Train Loss: 0.2207 | Train Acc: 90.09% | Test Loss: 0.2540 | Test Acc: 88.40%
# Epoch 46/500 | Train Loss: 0.2200 | Train Acc: 90.31% | Test Loss: 0.2536 | Test Acc: 88.22%
# Epoch 47/500 | Train Loss: 0.2207 | Train Acc: 89.96% | Test Loss: 0.2539 | Test Acc: 88.40%
# Epoch 48/500 | Train Loss: 0.2194 | Train Acc: 90.49% | Test Loss: 0.2535 | Test Acc: 88.40%
# Epoch 49/500 | Train Loss: 0.2197 | Train Acc: 90.57% | Test Loss: 0.2543 | Test Acc: 88.58%
# Epoch 50/500 | Train Loss: 0.2190 | Train Acc: 90.40% | Test Loss: 0.2529 | Test Acc: 88.22%
# Epoch 51/500 | Train Loss: 0.2190 | Train Acc: 90.57% | Test Loss: 0.2533 | Test Acc: 88.58%
# Epoch 52/500 | Train Loss: 0.2190 | Train Acc: 90.57% | Test Loss: 0.2534 | Test Acc: 88.58%
# Epoch 53/500 | Train Loss: 0.2184 | Train Acc: 90.53% | Test Loss: 0.2522 | Test Acc: 88.58%
# Epoch 54/500 | Train Loss: 0.2183 | Train Acc: 90.40% | Test Loss: 0.2518 | Test Acc: 88.22%
# Epoch 55/500 | Train Loss: 0.2183 | Train Acc: 90.62% | Test Loss: 0.2523 | Test Acc: 88.58%
# Epoch 56/500 | Train Loss: 0.2180 | Train Acc: 90.40% | Test Loss: 0.2514 | Test Acc: 88.22%
# Epoch 57/500 | Train Loss: 0.2178 | Train Acc: 90.36% | Test Loss: 0.2512 | Test Acc: 88.22%
# Epoch 58/500 | Train Loss: 0.2176 | Train Acc: 90.53% | Test Loss: 0.2513 | Test Acc: 88.58%
# Epoch 59/500 | Train Loss: 0.2175 | Train Acc: 90.36% | Test Loss: 0.2507 | Test Acc: 88.22%
# Epoch 60/500 | Train Loss: 0.2172 | Train Acc: 90.44% | Test Loss: 0.2506 | Test Acc: 88.40%
# Epoch 61/500 | Train Loss: 0.2209 | Train Acc: 90.49% | Test Loss: 0.2559 | Test Acc: 88.93%
# Epoch 62/500 | Train Loss: 0.2182 | Train Acc: 90.57% | Test Loss: 0.2526 | Test Acc: 88.93%
# Epoch 63/500 | Train Loss: 0.2177 | Train Acc: 90.66% | Test Loss: 0.2521 | Test Acc: 88.75%
# Epoch 64/500 | Train Loss: 0.2169 | Train Acc: 90.57% | Test Loss: 0.2508 | Test Acc: 88.58%
# Epoch 65/500 | Train Loss: 0.2166 | Train Acc: 90.36% | Test Loss: 0.2496 | Test Acc: 88.22%
# Epoch 66/500 | Train Loss: 0.2182 | Train Acc: 89.87% | Test Loss: 0.2505 | Test Acc: 87.70%
# Epoch 67/500 | Train Loss: 0.2175 | Train Acc: 90.62% | Test Loss: 0.2518 | Test Acc: 88.93%
# Epoch 68/500 | Train Loss: 0.2171 | Train Acc: 90.05% | Test Loss: 0.2495 | Test Acc: 88.22%
# Epoch 69/500 | Train Loss: 0.2157 | Train Acc: 90.57% | Test Loss: 0.2490 | Test Acc: 88.40%
# Epoch 70/500 | Train Loss: 0.2178 | Train Acc: 89.87% | Test Loss: 0.2499 | Test Acc: 87.52%
# Epoch 71/500 | Train Loss: 0.2158 | Train Acc: 90.62% | Test Loss: 0.2495 | Test Acc: 88.58%
# Epoch 72/500 | Train Loss: 0.2153 | Train Acc: 90.53% | Test Loss: 0.2486 | Test Acc: 88.40%
# Epoch 73/500 | Train Loss: 0.2155 | Train Acc: 90.62% | Test Loss: 0.2493 | Test Acc: 88.58%
# Epoch 74/500 | Train Loss: 0.2171 | Train Acc: 89.92% | Test Loss: 0.2492 | Test Acc: 87.52%
# Epoch 75/500 | Train Loss: 0.2150 | Train Acc: 90.57% | Test Loss: 0.2485 | Test Acc: 88.58%
# Epoch 76/500 | Train Loss: 0.2147 | Train Acc: 90.53% | Test Loss: 0.2479 | Test Acc: 88.40%
# Epoch 77/500 | Train Loss: 0.2145 | Train Acc: 90.44% | Test Loss: 0.2472 | Test Acc: 88.40%
# Epoch 78/500 | Train Loss: 0.2144 | Train Acc: 90.57% | Test Loss: 0.2476 | Test Acc: 88.40%
# Epoch 79/500 | Train Loss: 0.2145 | Train Acc: 90.40% | Test Loss: 0.2469 | Test Acc: 88.22%
# Epoch 80/500 | Train Loss: 0.2139 | Train Acc: 90.44% | Test Loss: 0.2466 | Test Acc: 88.40%
# Epoch 81/500 | Train Loss: 0.2138 | Train Acc: 90.40% | Test Loss: 0.2463 | Test Acc: 88.58%
# Epoch 82/500 | Train Loss: 0.2168 | Train Acc: 89.87% | Test Loss: 0.2486 | Test Acc: 87.70%
# Epoch 83/500 | Train Loss: 0.2140 | Train Acc: 90.22% | Test Loss: 0.2461 | Test Acc: 87.70%
# Epoch 84/500 | Train Loss: 0.2133 | Train Acc: 90.49% | Test Loss: 0.2460 | Test Acc: 88.40%
# Epoch 85/500 | Train Loss: 0.2131 | Train Acc: 90.44% | Test Loss: 0.2455 | Test Acc: 88.40%
# Epoch 86/500 | Train Loss: 0.2129 | Train Acc: 90.44% | Test Loss: 0.2453 | Test Acc: 88.58%
# Epoch 87/500 | Train Loss: 0.2133 | Train Acc: 90.31% | Test Loss: 0.2453 | Test Acc: 87.87%
# Epoch 88/500 | Train Loss: 0.2136 | Train Acc: 89.96% | Test Loss: 0.2456 | Test Acc: 87.52%
# Epoch 89/500 | Train Loss: 0.2124 | Train Acc: 90.53% | Test Loss: 0.2449 | Test Acc: 88.40%
# Epoch 90/500 | Train Loss: 0.2123 | Train Acc: 90.36% | Test Loss: 0.2443 | Test Acc: 88.40%
# Epoch 91/500 | Train Loss: 0.2121 | Train Acc: 90.44% | Test Loss: 0.2443 | Test Acc: 88.40%
# Epoch 92/500 | Train Loss: 0.2120 | Train Acc: 90.36% | Test Loss: 0.2440 | Test Acc: 88.40%
# Epoch 93/500 | Train Loss: 0.2118 | Train Acc: 90.49% | Test Loss: 0.2437 | Test Acc: 88.40%
# Epoch 94/500 | Train Loss: 0.2174 | Train Acc: 89.74% | Test Loss: 0.2484 | Test Acc: 87.35%
# Epoch 95/500 | Train Loss: 0.2114 | Train Acc: 90.40% | Test Loss: 0.2432 | Test Acc: 88.05%
# Epoch 96/500 | Train Loss: 0.2125 | Train Acc: 90.05% | Test Loss: 0.2440 | Test Acc: 87.52%
# Epoch 97/500 | Train Loss: 0.2115 | Train Acc: 90.62% | Test Loss: 0.2438 | Test Acc: 88.58%
# Epoch 98/500 | Train Loss: 0.2112 | Train Acc: 90.09% | Test Loss: 0.2430 | Test Acc: 87.70%
# Epoch 99/500 | Train Loss: 0.2118 | Train Acc: 90.14% | Test Loss: 0.2434 | Test Acc: 87.52%
# Epoch 100/500 | Train Loss: 0.2111 | Train Acc: 90.66% | Test Loss: 0.2435 | Test Acc: 88.58%
# Epoch 101/500 | Train Loss: 0.2106 | Train Acc: 90.53% | Test Loss: 0.2429 | Test Acc: 88.40%
# Epoch 102/500 | Train Loss: 0.2154 | Train Acc: 89.83% | Test Loss: 0.2461 | Test Acc: 87.52%
# Epoch 103/500 | Train Loss: 0.2104 | Train Acc: 90.53% | Test Loss: 0.2427 | Test Acc: 88.40%
# Epoch 104/500 | Train Loss: 0.2098 | Train Acc: 90.53% | Test Loss: 0.2417 | Test Acc: 87.87%
# Epoch 105/500 | Train Loss: 0.2105 | Train Acc: 90.75% | Test Loss: 0.2429 | Test Acc: 88.58%
# Epoch 106/500 | Train Loss: 0.2114 | Train Acc: 90.09% | Test Loss: 0.2427 | Test Acc: 87.70%
# Epoch 107/500 | Train Loss: 0.2097 | Train Acc: 90.27% | Test Loss: 0.2413 | Test Acc: 87.52%
# Epoch 108/500 | Train Loss: 0.2091 | Train Acc: 90.40% | Test Loss: 0.2412 | Test Acc: 88.40%
# Epoch 109/500 | Train Loss: 0.2090 | Train Acc: 90.44% | Test Loss: 0.2410 | Test Acc: 88.40%
# Epoch 110/500 | Train Loss: 0.2090 | Train Acc: 90.49% | Test Loss: 0.2412 | Test Acc: 88.75%
# Epoch 111/500 | Train Loss: 0.2099 | Train Acc: 90.84% | Test Loss: 0.2426 | Test Acc: 88.93%
# Epoch 112/500 | Train Loss: 0.2096 | Train Acc: 90.84% | Test Loss: 0.2423 | Test Acc: 89.10%
# Epoch 113/500 | Train Loss: 0.2091 | Train Acc: 90.66% | Test Loss: 0.2416 | Test Acc: 89.10%
# Epoch 114/500 | Train Loss: 0.2082 | Train Acc: 90.53% | Test Loss: 0.2401 | Test Acc: 88.40%
# Epoch 115/500 | Train Loss: 0.2081 | Train Acc: 90.57% | Test Loss: 0.2400 | Test Acc: 88.22%
# Epoch 116/500 | Train Loss: 0.2081 | Train Acc: 90.53% | Test Loss: 0.2403 | Test Acc: 88.75%
# Epoch 117/500 | Train Loss: 0.2077 | Train Acc: 90.53% | Test Loss: 0.2398 | Test Acc: 88.40%
# Epoch 118/500 | Train Loss: 0.2080 | Train Acc: 90.40% | Test Loss: 0.2397 | Test Acc: 87.87%
# Epoch 119/500 | Train Loss: 0.2109 | Train Acc: 90.14% | Test Loss: 0.2417 | Test Acc: 87.70%
# Epoch 120/500 | Train Loss: 0.2074 | Train Acc: 90.53% | Test Loss: 0.2392 | Test Acc: 88.40%
# Epoch 121/500 | Train Loss: 0.2071 | Train Acc: 90.44% | Test Loss: 0.2395 | Test Acc: 88.75%
# Epoch 122/500 | Train Loss: 0.2078 | Train Acc: 90.27% | Test Loss: 0.2395 | Test Acc: 88.22%
# Epoch 123/500 | Train Loss: 0.2080 | Train Acc: 90.22% | Test Loss: 0.2397 | Test Acc: 88.22%
# Epoch 124/500 | Train Loss: 0.2076 | Train Acc: 90.88% | Test Loss: 0.2405 | Test Acc: 89.63%
# Epoch 125/500 | Train Loss: 0.2066 | Train Acc: 90.57% | Test Loss: 0.2387 | Test Acc: 88.22%
# Epoch 126/500 | Train Loss: 0.2091 | Train Acc: 90.18% | Test Loss: 0.2404 | Test Acc: 87.87%
# Epoch 127/500 | Train Loss: 0.2063 | Train Acc: 90.62% | Test Loss: 0.2390 | Test Acc: 88.58%
# Epoch 128/500 | Train Loss: 0.2069 | Train Acc: 90.79% | Test Loss: 0.2401 | Test Acc: 89.46%
# Epoch 129/500 | Train Loss: 0.2062 | Train Acc: 90.75% | Test Loss: 0.2391 | Test Acc: 89.10%
# Epoch 130/500 | Train Loss: 0.2076 | Train Acc: 90.84% | Test Loss: 0.2410 | Test Acc: 89.63%
# Epoch 131/500 | Train Loss: 0.2095 | Train Acc: 90.75% | Test Loss: 0.2433 | Test Acc: 89.98%
# Epoch 132/500 | Train Loss: 0.2113 | Train Acc: 90.75% | Test Loss: 0.2457 | Test Acc: 90.33%
# Epoch 133/500 | Train Loss: 0.2060 | Train Acc: 90.75% | Test Loss: 0.2394 | Test Acc: 89.46%
# Epoch 134/500 | Train Loss: 0.2060 | Train Acc: 90.75% | Test Loss: 0.2394 | Test Acc: 89.63%
# Epoch 135/500 | Train Loss: 0.2054 | Train Acc: 90.79% | Test Loss: 0.2386 | Test Acc: 88.93%
# Epoch 136/500 | Train Loss: 0.2051 | Train Acc: 90.53% | Test Loss: 0.2380 | Test Acc: 88.58%
# Epoch 137/500 | Train Loss: 0.2099 | Train Acc: 90.40% | Test Loss: 0.2410 | Test Acc: 88.05%
# Epoch 138/500 | Train Loss: 0.2054 | Train Acc: 90.71% | Test Loss: 0.2387 | Test Acc: 89.63%
# Epoch 139/500 | Train Loss: 0.2057 | Train Acc: 90.40% | Test Loss: 0.2378 | Test Acc: 88.58%
# Epoch 140/500 | Train Loss: 0.2053 | Train Acc: 90.75% | Test Loss: 0.2388 | Test Acc: 89.63%
# Epoch 141/500 | Train Loss: 0.2046 | Train Acc: 90.53% | Test Loss: 0.2370 | Test Acc: 88.58%
# Epoch 142/500 | Train Loss: 0.2043 | Train Acc: 90.62% | Test Loss: 0.2370 | Test Acc: 88.40%
# Epoch 143/500 | Train Loss: 0.2041 | Train Acc: 90.62% | Test Loss: 0.2370 | Test Acc: 88.58%
# Epoch 144/500 | Train Loss: 0.2082 | Train Acc: 90.97% | Test Loss: 0.2423 | Test Acc: 90.16%
# Epoch 145/500 | Train Loss: 0.2039 | Train Acc: 90.75% | Test Loss: 0.2367 | Test Acc: 89.46%
# Epoch 146/500 | Train Loss: 0.2038 | Train Acc: 90.79% | Test Loss: 0.2369 | Test Acc: 89.10%
# Epoch 147/500 | Train Loss: 0.2042 | Train Acc: 90.44% | Test Loss: 0.2365 | Test Acc: 88.75%
# Epoch 148/500 | Train Loss: 0.2038 | Train Acc: 90.79% | Test Loss: 0.2372 | Test Acc: 89.81%
# Epoch 149/500 | Train Loss: 0.2033 | Train Acc: 90.66% | Test Loss: 0.2363 | Test Acc: 88.58%
# Epoch 150/500 | Train Loss: 0.2032 | Train Acc: 90.75% | Test Loss: 0.2363 | Test Acc: 89.63%
# Epoch 151/500 | Train Loss: 0.2032 | Train Acc: 90.71% | Test Loss: 0.2356 | Test Acc: 88.58%
# Epoch 152/500 | Train Loss: 0.2044 | Train Acc: 90.97% | Test Loss: 0.2377 | Test Acc: 89.98%
# Epoch 153/500 | Train Loss: 0.2033 | Train Acc: 90.62% | Test Loss: 0.2350 | Test Acc: 88.93%
# Epoch 154/500 | Train Loss: 0.2031 | Train Acc: 90.62% | Test Loss: 0.2351 | Test Acc: 88.93%
# Epoch 155/500 | Train Loss: 0.2043 | Train Acc: 91.10% | Test Loss: 0.2381 | Test Acc: 89.81%
# Epoch 156/500 | Train Loss: 0.2027 | Train Acc: 90.62% | Test Loss: 0.2348 | Test Acc: 88.93%
# Epoch 157/500 | Train Loss: 0.2024 | Train Acc: 90.36% | Test Loss: 0.2343 | Test Acc: 89.10%
# Epoch 158/500 | Train Loss: 0.2023 | Train Acc: 90.62% | Test Loss: 0.2346 | Test Acc: 89.63%
# Epoch 159/500 | Train Loss: 0.2027 | Train Acc: 91.10% | Test Loss: 0.2357 | Test Acc: 89.63%
# Epoch 160/500 | Train Loss: 0.2020 | Train Acc: 90.57% | Test Loss: 0.2335 | Test Acc: 89.63%
# Epoch 161/500 | Train Loss: 0.2019 | Train Acc: 90.79% | Test Loss: 0.2339 | Test Acc: 89.63%
# Epoch 162/500 | Train Loss: 0.2027 | Train Acc: 91.14% | Test Loss: 0.2356 | Test Acc: 89.81%
# Epoch 163/500 | Train Loss: 0.2020 | Train Acc: 90.36% | Test Loss: 0.2333 | Test Acc: 89.10%
# Epoch 164/500 | Train Loss: 0.2020 | Train Acc: 91.14% | Test Loss: 0.2347 | Test Acc: 89.98%
# Epoch 165/500 | Train Loss: 0.2018 | Train Acc: 90.31% | Test Loss: 0.2328 | Test Acc: 89.46%
# Epoch 166/500 | Train Loss: 0.2013 | Train Acc: 90.49% | Test Loss: 0.2331 | Test Acc: 89.28%
# Epoch 167/500 | Train Loss: 0.2011 | Train Acc: 90.66% | Test Loss: 0.2327 | Test Acc: 89.46%
# Epoch 168/500 | Train Loss: 0.2009 | Train Acc: 91.01% | Test Loss: 0.2325 | Test Acc: 89.81%
# Epoch 169/500 | Train Loss: 0.2007 | Train Acc: 90.88% | Test Loss: 0.2321 | Test Acc: 89.81%
# Epoch 170/500 | Train Loss: 0.2014 | Train Acc: 90.75% | Test Loss: 0.2318 | Test Acc: 89.63%
# Epoch 171/500 | Train Loss: 0.2025 | Train Acc: 91.19% | Test Loss: 0.2352 | Test Acc: 90.16%
# Epoch 172/500 | Train Loss: 0.2005 | Train Acc: 91.19% | Test Loss: 0.2327 | Test Acc: 89.98%
# Epoch 173/500 | Train Loss: 0.2006 | Train Acc: 91.32% | Test Loss: 0.2331 | Test Acc: 90.51%
# Epoch 174/500 | Train Loss: 0.2002 | Train Acc: 91.28% | Test Loss: 0.2327 | Test Acc: 89.81%
# Epoch 175/500 | Train Loss: 0.2019 | Train Acc: 91.28% | Test Loss: 0.2351 | Test Acc: 90.33%
# Epoch 176/500 | Train Loss: 0.1998 | Train Acc: 90.97% | Test Loss: 0.2314 | Test Acc: 89.81%
# Epoch 177/500 | Train Loss: 0.2002 | Train Acc: 91.36% | Test Loss: 0.2328 | Test Acc: 90.51%
# Epoch 178/500 | Train Loss: 0.1998 | Train Acc: 91.36% | Test Loss: 0.2319 | Test Acc: 90.33%
# Epoch 179/500 | Train Loss: 0.1996 | Train Acc: 91.01% | Test Loss: 0.2305 | Test Acc: 89.46%
# Epoch 180/500 | Train Loss: 0.1993 | Train Acc: 91.28% | Test Loss: 0.2312 | Test Acc: 89.98%
# Epoch 181/500 | Train Loss: 0.1992 | Train Acc: 91.28% | Test Loss: 0.2310 | Test Acc: 89.63%
# Epoch 182/500 | Train Loss: 0.1992 | Train Acc: 91.28% | Test Loss: 0.2316 | Test Acc: 89.63%
# Epoch 183/500 | Train Loss: 0.1992 | Train Acc: 91.36% | Test Loss: 0.2310 | Test Acc: 90.51%
# Epoch 184/500 | Train Loss: 0.1988 | Train Acc: 91.36% | Test Loss: 0.2301 | Test Acc: 89.98%
# Epoch 185/500 | Train Loss: 0.2006 | Train Acc: 91.41% | Test Loss: 0.2334 | Test Acc: 90.51%
# Epoch 186/500 | Train Loss: 0.2008 | Train Acc: 91.36% | Test Loss: 0.2336 | Test Acc: 90.69%
# Epoch 187/500 | Train Loss: 0.1992 | Train Acc: 91.36% | Test Loss: 0.2294 | Test Acc: 88.93%
# Epoch 188/500 | Train Loss: 0.1994 | Train Acc: 91.06% | Test Loss: 0.2298 | Test Acc: 89.10%
# Epoch 189/500 | Train Loss: 0.1993 | Train Acc: 91.10% | Test Loss: 0.2302 | Test Acc: 88.93%
# Epoch 190/500 | Train Loss: 0.1982 | Train Acc: 91.28% | Test Loss: 0.2296 | Test Acc: 90.33%
# Epoch 191/500 | Train Loss: 0.1980 | Train Acc: 91.41% | Test Loss: 0.2299 | Test Acc: 90.16%
# Epoch 192/500 | Train Loss: 0.1980 | Train Acc: 91.45% | Test Loss: 0.2289 | Test Acc: 89.98%
# Epoch 193/500 | Train Loss: 0.2007 | Train Acc: 91.32% | Test Loss: 0.2342 | Test Acc: 90.86%
# Epoch 194/500 | Train Loss: 0.1977 | Train Acc: 91.45% | Test Loss: 0.2292 | Test Acc: 89.98%
# Epoch 195/500 | Train Loss: 0.2003 | Train Acc: 91.45% | Test Loss: 0.2298 | Test Acc: 88.93%
# Epoch 196/500 | Train Loss: 0.1985 | Train Acc: 91.54% | Test Loss: 0.2286 | Test Acc: 89.28%
# Epoch 197/500 | Train Loss: 0.1973 | Train Acc: 91.63% | Test Loss: 0.2282 | Test Acc: 90.16%
# Epoch 198/500 | Train Loss: 0.1973 | Train Acc: 91.54% | Test Loss: 0.2277 | Test Acc: 89.98%
# Epoch 199/500 | Train Loss: 0.1970 | Train Acc: 91.41% | Test Loss: 0.2277 | Test Acc: 90.33%
# Epoch 200/500 | Train Loss: 0.1971 | Train Acc: 91.45% | Test Loss: 0.2281 | Test Acc: 90.69%
# Epoch 201/500 | Train Loss: 0.1974 | Train Acc: 91.58% | Test Loss: 0.2267 | Test Acc: 89.81%
# Epoch 202/500 | Train Loss: 0.2006 | Train Acc: 91.58% | Test Loss: 0.2327 | Test Acc: 90.51%
# Epoch 203/500 | Train Loss: 0.1967 | Train Acc: 91.54% | Test Loss: 0.2276 | Test Acc: 90.86%
# Epoch 204/500 | Train Loss: 0.1969 | Train Acc: 91.76% | Test Loss: 0.2275 | Test Acc: 89.63%
# Epoch 205/500 | Train Loss: 0.1964 | Train Acc: 91.54% | Test Loss: 0.2277 | Test Acc: 90.69%
# Epoch 206/500 | Train Loss: 0.1961 | Train Acc: 91.58% | Test Loss: 0.2269 | Test Acc: 89.98%
# Epoch 207/500 | Train Loss: 0.1962 | Train Acc: 91.71% | Test Loss: 0.2270 | Test Acc: 89.81%
# Epoch 208/500 | Train Loss: 0.1966 | Train Acc: 91.76% | Test Loss: 0.2272 | Test Acc: 90.16%
# Epoch 209/500 | Train Loss: 0.1960 | Train Acc: 91.49% | Test Loss: 0.2276 | Test Acc: 90.51%
# Epoch 210/500 | Train Loss: 0.1968 | Train Acc: 91.67% | Test Loss: 0.2284 | Test Acc: 91.04%
# Epoch 211/500 | Train Loss: 0.1955 | Train Acc: 91.58% | Test Loss: 0.2266 | Test Acc: 90.51%
# Epoch 212/500 | Train Loss: 0.1953 | Train Acc: 91.71% | Test Loss: 0.2261 | Test Acc: 90.16%
# Epoch 213/500 | Train Loss: 0.1970 | Train Acc: 91.67% | Test Loss: 0.2294 | Test Acc: 91.04%
# Epoch 214/500 | Train Loss: 0.1951 | Train Acc: 91.67% | Test Loss: 0.2263 | Test Acc: 89.98%
# Epoch 215/500 | Train Loss: 0.1953 | Train Acc: 91.49% | Test Loss: 0.2279 | Test Acc: 90.16%
# Epoch 216/500 | Train Loss: 0.1959 | Train Acc: 91.67% | Test Loss: 0.2280 | Test Acc: 90.86%
# Epoch 217/500 | Train Loss: 0.1951 | Train Acc: 91.89% | Test Loss: 0.2252 | Test Acc: 90.16%
# Epoch 218/500 | Train Loss: 0.1952 | Train Acc: 91.71% | Test Loss: 0.2268 | Test Acc: 90.86%
# Epoch 219/500 | Train Loss: 0.1945 | Train Acc: 91.71% | Test Loss: 0.2263 | Test Acc: 90.16%
# Epoch 220/500 | Train Loss: 0.1944 | Train Acc: 91.76% | Test Loss: 0.2259 | Test Acc: 90.33%
# Epoch 221/500 | Train Loss: 0.1945 | Train Acc: 91.71% | Test Loss: 0.2265 | Test Acc: 90.33%
# Epoch 222/500 | Train Loss: 0.1948 | Train Acc: 91.71% | Test Loss: 0.2272 | Test Acc: 90.51%
# Epoch 223/500 | Train Loss: 0.1940 | Train Acc: 91.80% | Test Loss: 0.2256 | Test Acc: 90.16%
# Epoch 224/500 | Train Loss: 0.1959 | Train Acc: 92.11% | Test Loss: 0.2260 | Test Acc: 90.16%
# Epoch 225/500 | Train Loss: 0.1949 | Train Acc: 92.02% | Test Loss: 0.2251 | Test Acc: 89.81%
# Epoch 226/500 | Train Loss: 0.1940 | Train Acc: 91.93% | Test Loss: 0.2250 | Test Acc: 89.98%
# Epoch 227/500 | Train Loss: 0.1936 | Train Acc: 91.89% | Test Loss: 0.2248 | Test Acc: 90.16%
# Epoch 228/500 | Train Loss: 0.1934 | Train Acc: 91.80% | Test Loss: 0.2248 | Test Acc: 90.16%
# Epoch 229/500 | Train Loss: 0.1955 | Train Acc: 91.98% | Test Loss: 0.2260 | Test Acc: 89.81%
# Epoch 230/500 | Train Loss: 0.1932 | Train Acc: 91.93% | Test Loss: 0.2255 | Test Acc: 89.81%
# Epoch 231/500 | Train Loss: 0.1933 | Train Acc: 91.93% | Test Loss: 0.2239 | Test Acc: 90.16%
# Epoch 232/500 | Train Loss: 0.1941 | Train Acc: 91.76% | Test Loss: 0.2269 | Test Acc: 90.51%
# Epoch 233/500 | Train Loss: 0.1928 | Train Acc: 91.89% | Test Loss: 0.2244 | Test Acc: 89.98%
# Epoch 234/500 | Train Loss: 0.1927 | Train Acc: 91.85% | Test Loss: 0.2246 | Test Acc: 89.98%
# Epoch 235/500 | Train Loss: 0.1934 | Train Acc: 91.76% | Test Loss: 0.2265 | Test Acc: 90.33%
# Epoch 236/500 | Train Loss: 0.1926 | Train Acc: 91.93% | Test Loss: 0.2250 | Test Acc: 90.16%
# Epoch 237/500 | Train Loss: 0.1953 | Train Acc: 92.02% | Test Loss: 0.2254 | Test Acc: 90.16%
# Epoch 238/500 | Train Loss: 0.1930 | Train Acc: 92.24% | Test Loss: 0.2245 | Test Acc: 90.16%
# Epoch 239/500 | Train Loss: 0.1926 | Train Acc: 92.15% | Test Loss: 0.2240 | Test Acc: 90.33%
# Epoch 240/500 | Train Loss: 0.1928 | Train Acc: 91.89% | Test Loss: 0.2256 | Test Acc: 90.69%
# Epoch 241/500 | Train Loss: 0.1929 | Train Acc: 91.98% | Test Loss: 0.2257 | Test Acc: 90.86%
# Epoch 242/500 | Train Loss: 0.1935 | Train Acc: 92.20% | Test Loss: 0.2242 | Test Acc: 90.16%
# Epoch 243/500 | Train Loss: 0.1934 | Train Acc: 92.20% | Test Loss: 0.2240 | Test Acc: 89.81%
# Epoch 244/500 | Train Loss: 0.2025 | Train Acc: 91.01% | Test Loss: 0.2323 | Test Acc: 89.81%
# Epoch 245/500 | Train Loss: 0.1921 | Train Acc: 92.28% | Test Loss: 0.2236 | Test Acc: 90.33%
# Epoch 246/500 | Train Loss: 0.1915 | Train Acc: 92.06% | Test Loss: 0.2239 | Test Acc: 89.98%
# Epoch 247/500 | Train Loss: 0.1917 | Train Acc: 91.98% | Test Loss: 0.2251 | Test Acc: 90.33%
# Epoch 248/500 | Train Loss: 0.1914 | Train Acc: 92.11% | Test Loss: 0.2247 | Test Acc: 89.98%
# Epoch 249/500 | Train Loss: 0.1951 | Train Acc: 92.15% | Test Loss: 0.2292 | Test Acc: 90.69%
# Epoch 250/500 | Train Loss: 0.1918 | Train Acc: 92.46% | Test Loss: 0.2231 | Test Acc: 90.16%
# Epoch 251/500 | Train Loss: 0.1928 | Train Acc: 92.11% | Test Loss: 0.2259 | Test Acc: 90.86%
# Epoch 252/500 | Train Loss: 0.2024 | Train Acc: 91.10% | Test Loss: 0.2325 | Test Acc: 89.10%
# Epoch 253/500 | Train Loss: 0.1919 | Train Acc: 92.20% | Test Loss: 0.2237 | Test Acc: 90.16%
# Epoch 254/500 | Train Loss: 0.1911 | Train Acc: 92.15% | Test Loss: 0.2241 | Test Acc: 90.33%
# Epoch 255/500 | Train Loss: 0.1923 | Train Acc: 92.33% | Test Loss: 0.2232 | Test Acc: 90.16%
# Epoch 256/500 | Train Loss: 0.1907 | Train Acc: 92.46% | Test Loss: 0.2221 | Test Acc: 90.69%
# Epoch 257/500 | Train Loss: 0.1904 | Train Acc: 92.33% | Test Loss: 0.2226 | Test Acc: 90.33%
# Epoch 258/500 | Train Loss: 0.1903 | Train Acc: 92.37% | Test Loss: 0.2218 | Test Acc: 90.33%
# Epoch 259/500 | Train Loss: 0.1903 | Train Acc: 92.59% | Test Loss: 0.2217 | Test Acc: 90.69%
# Epoch 260/500 | Train Loss: 0.1903 | Train Acc: 92.37% | Test Loss: 0.2225 | Test Acc: 90.69%
# Epoch 261/500 | Train Loss: 0.1906 | Train Acc: 92.24% | Test Loss: 0.2226 | Test Acc: 90.33%
# Epoch 262/500 | Train Loss: 0.1928 | Train Acc: 92.11% | Test Loss: 0.2278 | Test Acc: 90.51%
# Epoch 263/500 | Train Loss: 0.1896 | Train Acc: 92.46% | Test Loss: 0.2226 | Test Acc: 90.69%
# Epoch 264/500 | Train Loss: 0.1897 | Train Acc: 92.42% | Test Loss: 0.2232 | Test Acc: 90.69%
# Epoch 265/500 | Train Loss: 0.1908 | Train Acc: 92.63% | Test Loss: 0.2228 | Test Acc: 90.16%
# Epoch 266/500 | Train Loss: 0.1893 | Train Acc: 92.55% | Test Loss: 0.2222 | Test Acc: 90.69%
# Epoch 267/500 | Train Loss: 0.1893 | Train Acc: 92.46% | Test Loss: 0.2223 | Test Acc: 90.51%
# Epoch 268/500 | Train Loss: 0.1981 | Train Acc: 91.89% | Test Loss: 0.2275 | Test Acc: 89.81%
# Epoch 269/500 | Train Loss: 0.1898 | Train Acc: 92.37% | Test Loss: 0.2225 | Test Acc: 90.51%
# Epoch 270/500 | Train Loss: 0.1918 | Train Acc: 92.59% | Test Loss: 0.2228 | Test Acc: 90.33%
# Epoch 271/500 | Train Loss: 0.1894 | Train Acc: 92.63% | Test Loss: 0.2214 | Test Acc: 90.86%
# Epoch 272/500 | Train Loss: 0.1896 | Train Acc: 92.68% | Test Loss: 0.2222 | Test Acc: 90.33%
# Epoch 273/500 | Train Loss: 0.1901 | Train Acc: 92.72% | Test Loss: 0.2226 | Test Acc: 89.98%
# Epoch 274/500 | Train Loss: 0.2052 | Train Acc: 90.97% | Test Loss: 0.2347 | Test Acc: 88.75%
# Epoch 275/500 | Train Loss: 0.1895 | Train Acc: 92.37% | Test Loss: 0.2239 | Test Acc: 90.33%
# Epoch 276/500 | Train Loss: 0.1885 | Train Acc: 92.72% | Test Loss: 0.2212 | Test Acc: 91.04%
# Epoch 277/500 | Train Loss: 0.1906 | Train Acc: 92.72% | Test Loss: 0.2214 | Test Acc: 90.51%
# Epoch 278/500 | Train Loss: 0.1985 | Train Acc: 91.63% | Test Loss: 0.2274 | Test Acc: 90.16%
# Epoch 279/500 | Train Loss: 0.1897 | Train Acc: 92.28% | Test Loss: 0.2235 | Test Acc: 90.51%
# Epoch 280/500 | Train Loss: 0.1880 | Train Acc: 92.85% | Test Loss: 0.2205 | Test Acc: 91.04%
# Epoch 281/500 | Train Loss: 0.1879 | Train Acc: 92.63% | Test Loss: 0.2208 | Test Acc: 90.33%
# Epoch 282/500 | Train Loss: 0.1890 | Train Acc: 92.46% | Test Loss: 0.2223 | Test Acc: 90.51%
# Epoch 283/500 | Train Loss: 0.1907 | Train Acc: 92.24% | Test Loss: 0.2247 | Test Acc: 90.69%
# Epoch 284/500 | Train Loss: 0.1878 | Train Acc: 92.77% | Test Loss: 0.2209 | Test Acc: 90.86%
# Epoch 285/500 | Train Loss: 0.1886 | Train Acc: 93.03% | Test Loss: 0.2210 | Test Acc: 90.51%
# Epoch 286/500 | Train Loss: 0.1873 | Train Acc: 92.77% | Test Loss: 0.2207 | Test Acc: 91.04%
# Epoch 287/500 | Train Loss: 0.1900 | Train Acc: 92.37% | Test Loss: 0.2236 | Test Acc: 90.69%
# Epoch 288/500 | Train Loss: 0.1870 | Train Acc: 92.94% | Test Loss: 0.2194 | Test Acc: 91.04%
# Epoch 289/500 | Train Loss: 0.1907 | Train Acc: 92.90% | Test Loss: 0.2213 | Test Acc: 90.69%
# Epoch 290/500 | Train Loss: 0.1869 | Train Acc: 92.77% | Test Loss: 0.2198 | Test Acc: 90.51%
# Epoch 291/500 | Train Loss: 0.1874 | Train Acc: 93.03% | Test Loss: 0.2190 | Test Acc: 91.21%
# Epoch 292/500 | Train Loss: 0.1874 | Train Acc: 93.03% | Test Loss: 0.2203 | Test Acc: 91.04%
# Epoch 293/500 | Train Loss: 0.1867 | Train Acc: 92.99% | Test Loss: 0.2201 | Test Acc: 91.04%
# Epoch 294/500 | Train Loss: 0.1873 | Train Acc: 93.07% | Test Loss: 0.2206 | Test Acc: 90.86%
# Epoch 295/500 | Train Loss: 0.1876 | Train Acc: 92.50% | Test Loss: 0.2221 | Test Acc: 90.16%
# Epoch 296/500 | Train Loss: 0.1861 | Train Acc: 92.99% | Test Loss: 0.2194 | Test Acc: 91.04%
# Epoch 297/500 | Train Loss: 0.1869 | Train Acc: 92.59% | Test Loss: 0.2209 | Test Acc: 90.51%
# Epoch 298/500 | Train Loss: 0.1862 | Train Acc: 93.07% | Test Loss: 0.2193 | Test Acc: 91.04%
# Epoch 299/500 | Train Loss: 0.1866 | Train Acc: 92.72% | Test Loss: 0.2209 | Test Acc: 90.51%
# Epoch 300/500 | Train Loss: 0.1860 | Train Acc: 92.94% | Test Loss: 0.2197 | Test Acc: 90.69%
# Epoch 301/500 | Train Loss: 0.1879 | Train Acc: 92.46% | Test Loss: 0.2225 | Test Acc: 90.16%
# Epoch 302/500 | Train Loss: 0.1856 | Train Acc: 92.90% | Test Loss: 0.2185 | Test Acc: 91.04%
# Epoch 303/500 | Train Loss: 0.1856 | Train Acc: 93.03% | Test Loss: 0.2178 | Test Acc: 91.04%
# Epoch 304/500 | Train Loss: 0.1862 | Train Acc: 93.20% | Test Loss: 0.2182 | Test Acc: 91.04%
# Epoch 305/500 | Train Loss: 0.1864 | Train Acc: 93.25% | Test Loss: 0.2186 | Test Acc: 90.86%
# Epoch 306/500 | Train Loss: 0.1881 | Train Acc: 92.42% | Test Loss: 0.2230 | Test Acc: 90.69%
# Epoch 307/500 | Train Loss: 0.1855 | Train Acc: 92.94% | Test Loss: 0.2201 | Test Acc: 91.04%
# Epoch 308/500 | Train Loss: 0.1901 | Train Acc: 92.42% | Test Loss: 0.2266 | Test Acc: 90.51%
# Epoch 309/500 | Train Loss: 0.1855 | Train Acc: 92.77% | Test Loss: 0.2192 | Test Acc: 90.33%
# Epoch 310/500 | Train Loss: 0.1847 | Train Acc: 93.07% | Test Loss: 0.2180 | Test Acc: 90.86%
# Epoch 311/500 | Train Loss: 0.1866 | Train Acc: 92.59% | Test Loss: 0.2213 | Test Acc: 90.33%
# Epoch 312/500 | Train Loss: 0.1887 | Train Acc: 92.85% | Test Loss: 0.2190 | Test Acc: 91.21%
# Epoch 313/500 | Train Loss: 0.1869 | Train Acc: 92.46% | Test Loss: 0.2216 | Test Acc: 90.33%
# Epoch 314/500 | Train Loss: 0.1843 | Train Acc: 93.20% | Test Loss: 0.2181 | Test Acc: 91.04%
# Epoch 315/500 | Train Loss: 0.1857 | Train Acc: 93.38% | Test Loss: 0.2181 | Test Acc: 90.86%
# Epoch 316/500 | Train Loss: 0.1843 | Train Acc: 93.12% | Test Loss: 0.2166 | Test Acc: 90.51%
# Epoch 317/500 | Train Loss: 0.1852 | Train Acc: 92.68% | Test Loss: 0.2195 | Test Acc: 90.33%
# Epoch 318/500 | Train Loss: 0.1861 | Train Acc: 93.38% | Test Loss: 0.2178 | Test Acc: 91.04%
# Epoch 319/500 | Train Loss: 0.1844 | Train Acc: 92.99% | Test Loss: 0.2184 | Test Acc: 90.51%
# Epoch 320/500 | Train Loss: 0.1892 | Train Acc: 92.37% | Test Loss: 0.2262 | Test Acc: 90.33%
# Epoch 321/500 | Train Loss: 0.1864 | Train Acc: 93.07% | Test Loss: 0.2187 | Test Acc: 91.21%
# Epoch 322/500 | Train Loss: 0.1849 | Train Acc: 93.38% | Test Loss: 0.2171 | Test Acc: 91.04%
# Epoch 323/500 | Train Loss: 0.1854 | Train Acc: 93.42% | Test Loss: 0.2176 | Test Acc: 91.04%
# Epoch 324/500 | Train Loss: 0.1852 | Train Acc: 93.25% | Test Loss: 0.2161 | Test Acc: 90.86%
# Epoch 325/500 | Train Loss: 0.1893 | Train Acc: 92.33% | Test Loss: 0.2257 | Test Acc: 90.51%
# Epoch 326/500 | Train Loss: 0.1842 | Train Acc: 92.85% | Test Loss: 0.2200 | Test Acc: 90.33%
# Epoch 327/500 | Train Loss: 0.1830 | Train Acc: 93.25% | Test Loss: 0.2165 | Test Acc: 91.04%
# Epoch 328/500 | Train Loss: 0.1836 | Train Acc: 93.42% | Test Loss: 0.2164 | Test Acc: 91.04%
# Epoch 329/500 | Train Loss: 0.1829 | Train Acc: 93.16% | Test Loss: 0.2168 | Test Acc: 90.69%
# Epoch 330/500 | Train Loss: 0.1832 | Train Acc: 93.07% | Test Loss: 0.2180 | Test Acc: 90.51%
# Epoch 331/500 | Train Loss: 0.1827 | Train Acc: 93.34% | Test Loss: 0.2164 | Test Acc: 90.86%
# Epoch 332/500 | Train Loss: 0.1825 | Train Acc: 93.34% | Test Loss: 0.2167 | Test Acc: 90.69%
# Epoch 333/500 | Train Loss: 0.1834 | Train Acc: 93.51% | Test Loss: 0.2164 | Test Acc: 91.04%
# Epoch 334/500 | Train Loss: 0.1823 | Train Acc: 93.29% | Test Loss: 0.2168 | Test Acc: 91.04%
# Epoch 335/500 | Train Loss: 0.1849 | Train Acc: 93.16% | Test Loss: 0.2178 | Test Acc: 91.39%
# Epoch 336/500 | Train Loss: 0.1834 | Train Acc: 93.56% | Test Loss: 0.2165 | Test Acc: 91.04%
# Epoch 337/500 | Train Loss: 0.1849 | Train Acc: 92.59% | Test Loss: 0.2217 | Test Acc: 90.51%
# Epoch 338/500 | Train Loss: 0.1821 | Train Acc: 93.16% | Test Loss: 0.2176 | Test Acc: 90.86%
# Epoch 339/500 | Train Loss: 0.1832 | Train Acc: 92.81% | Test Loss: 0.2196 | Test Acc: 90.33%
# Epoch 340/500 | Train Loss: 0.1833 | Train Acc: 93.60% | Test Loss: 0.2159 | Test Acc: 91.21%
# Epoch 341/500 | Train Loss: 0.1835 | Train Acc: 92.59% | Test Loss: 0.2204 | Test Acc: 90.33%
# Epoch 342/500 | Train Loss: 0.1825 | Train Acc: 93.60% | Test Loss: 0.2159 | Test Acc: 91.21%
# Epoch 343/500 | Train Loss: 0.1820 | Train Acc: 93.56% | Test Loss: 0.2158 | Test Acc: 91.04%
# Epoch 344/500 | Train Loss: 0.1813 | Train Acc: 93.29% | Test Loss: 0.2164 | Test Acc: 90.86%
# Epoch 345/500 | Train Loss: 0.1831 | Train Acc: 93.64% | Test Loss: 0.2159 | Test Acc: 91.21%
# Epoch 346/500 | Train Loss: 0.1819 | Train Acc: 92.94% | Test Loss: 0.2182 | Test Acc: 90.51%
# Epoch 347/500 | Train Loss: 0.1827 | Train Acc: 93.56% | Test Loss: 0.2145 | Test Acc: 91.21%
# Epoch 348/500 | Train Loss: 0.1820 | Train Acc: 93.03% | Test Loss: 0.2184 | Test Acc: 90.51%
# Epoch 349/500 | Train Loss: 0.1808 | Train Acc: 93.42% | Test Loss: 0.2153 | Test Acc: 90.86%
# Epoch 350/500 | Train Loss: 0.1806 | Train Acc: 93.25% | Test Loss: 0.2166 | Test Acc: 90.86%
# Epoch 351/500 | Train Loss: 0.1829 | Train Acc: 93.64% | Test Loss: 0.2163 | Test Acc: 91.39%
# Epoch 352/500 | Train Loss: 0.1825 | Train Acc: 92.72% | Test Loss: 0.2198 | Test Acc: 90.33%
# Epoch 353/500 | Train Loss: 0.1815 | Train Acc: 93.82% | Test Loss: 0.2165 | Test Acc: 91.21%
# Epoch 354/500 | Train Loss: 0.1803 | Train Acc: 93.47% | Test Loss: 0.2164 | Test Acc: 90.86%
# Epoch 355/500 | Train Loss: 0.1814 | Train Acc: 93.12% | Test Loss: 0.2190 | Test Acc: 90.69%
# Epoch 356/500 | Train Loss: 0.1800 | Train Acc: 93.25% | Test Loss: 0.2158 | Test Acc: 90.86%
# Epoch 357/500 | Train Loss: 0.1799 | Train Acc: 93.47% | Test Loss: 0.2146 | Test Acc: 90.86%
# Epoch 358/500 | Train Loss: 0.1805 | Train Acc: 93.69% | Test Loss: 0.2146 | Test Acc: 91.04%
# Epoch 359/500 | Train Loss: 0.1797 | Train Acc: 93.20% | Test Loss: 0.2158 | Test Acc: 90.51%
# Epoch 360/500 | Train Loss: 0.1815 | Train Acc: 92.81% | Test Loss: 0.2201 | Test Acc: 89.98%
# Epoch 361/500 | Train Loss: 0.1853 | Train Acc: 92.59% | Test Loss: 0.2234 | Test Acc: 90.33%
# Epoch 362/500 | Train Loss: 0.1800 | Train Acc: 93.60% | Test Loss: 0.2133 | Test Acc: 91.04%
# Epoch 363/500 | Train Loss: 0.1806 | Train Acc: 93.20% | Test Loss: 0.2188 | Test Acc: 90.86%
# Epoch 364/500 | Train Loss: 0.1863 | Train Acc: 92.85% | Test Loss: 0.2187 | Test Acc: 91.04%
# Epoch 365/500 | Train Loss: 0.1805 | Train Acc: 93.07% | Test Loss: 0.2184 | Test Acc: 90.33%
# Epoch 366/500 | Train Loss: 0.1790 | Train Acc: 93.20% | Test Loss: 0.2148 | Test Acc: 90.51%
# Epoch 367/500 | Train Loss: 0.1789 | Train Acc: 93.47% | Test Loss: 0.2151 | Test Acc: 90.51%
# Epoch 368/500 | Train Loss: 0.1839 | Train Acc: 92.72% | Test Loss: 0.2235 | Test Acc: 89.98%
# Epoch 369/500 | Train Loss: 0.1801 | Train Acc: 92.90% | Test Loss: 0.2176 | Test Acc: 90.33%
# Epoch 370/500 | Train Loss: 0.1786 | Train Acc: 93.56% | Test Loss: 0.2141 | Test Acc: 91.39%
# Epoch 371/500 | Train Loss: 0.1802 | Train Acc: 93.91% | Test Loss: 0.2150 | Test Acc: 91.39%
# Epoch 372/500 | Train Loss: 0.1784 | Train Acc: 93.60% | Test Loss: 0.2139 | Test Acc: 90.69%
# Epoch 373/500 | Train Loss: 0.1784 | Train Acc: 93.73% | Test Loss: 0.2142 | Test Acc: 90.69%
# Epoch 374/500 | Train Loss: 0.1804 | Train Acc: 92.94% | Test Loss: 0.2192 | Test Acc: 89.98%
# Epoch 375/500 | Train Loss: 0.1794 | Train Acc: 93.95% | Test Loss: 0.2160 | Test Acc: 91.21%
# Epoch 376/500 | Train Loss: 0.1783 | Train Acc: 93.25% | Test Loss: 0.2165 | Test Acc: 90.51%
# Epoch 377/500 | Train Loss: 0.1862 | Train Acc: 92.77% | Test Loss: 0.2190 | Test Acc: 90.86%
# Epoch 378/500 | Train Loss: 0.1889 | Train Acc: 92.46% | Test Loss: 0.2292 | Test Acc: 90.16%
# Epoch 379/500 | Train Loss: 0.1778 | Train Acc: 93.25% | Test Loss: 0.2142 | Test Acc: 90.51%
# Epoch 380/500 | Train Loss: 0.1792 | Train Acc: 93.03% | Test Loss: 0.2154 | Test Acc: 89.98%
# Epoch 381/500 | Train Loss: 0.1776 | Train Acc: 93.38% | Test Loss: 0.2138 | Test Acc: 90.51%
# Epoch 382/500 | Train Loss: 0.1819 | Train Acc: 93.12% | Test Loss: 0.2162 | Test Acc: 91.56%
# Epoch 383/500 | Train Loss: 0.1817 | Train Acc: 93.16% | Test Loss: 0.2141 | Test Acc: 91.21%
# Epoch 384/500 | Train Loss: 0.1778 | Train Acc: 93.64% | Test Loss: 0.2133 | Test Acc: 91.39%
# Epoch 385/500 | Train Loss: 0.1779 | Train Acc: 93.82% | Test Loss: 0.2123 | Test Acc: 90.86%
# Epoch 386/500 | Train Loss: 0.1829 | Train Acc: 93.20% | Test Loss: 0.2165 | Test Acc: 91.74%
# Epoch 387/500 | Train Loss: 0.1771 | Train Acc: 93.25% | Test Loss: 0.2149 | Test Acc: 90.69%
# Epoch 388/500 | Train Loss: 0.1772 | Train Acc: 93.73% | Test Loss: 0.2135 | Test Acc: 91.39%
# Epoch 389/500 | Train Loss: 0.1767 | Train Acc: 93.69% | Test Loss: 0.2143 | Test Acc: 90.86%
# Epoch 390/500 | Train Loss: 0.1769 | Train Acc: 93.95% | Test Loss: 0.2146 | Test Acc: 91.21%
# Epoch 391/500 | Train Loss: 0.1818 | Train Acc: 92.72% | Test Loss: 0.2211 | Test Acc: 90.33%
# Epoch 392/500 | Train Loss: 0.1764 | Train Acc: 93.69% | Test Loss: 0.2141 | Test Acc: 90.69%
# Epoch 393/500 | Train Loss: 0.1777 | Train Acc: 93.03% | Test Loss: 0.2152 | Test Acc: 89.98%
# Epoch 394/500 | Train Loss: 0.1810 | Train Acc: 93.42% | Test Loss: 0.2140 | Test Acc: 91.39%
# Epoch 395/500 | Train Loss: 0.1779 | Train Acc: 93.77% | Test Loss: 0.2138 | Test Acc: 91.39%
# Epoch 396/500 | Train Loss: 0.1775 | Train Acc: 93.20% | Test Loss: 0.2180 | Test Acc: 89.81%
# Epoch 397/500 | Train Loss: 0.1818 | Train Acc: 93.03% | Test Loss: 0.2166 | Test Acc: 91.04%
# Epoch 398/500 | Train Loss: 0.1776 | Train Acc: 93.82% | Test Loss: 0.2124 | Test Acc: 91.04%
# Epoch 399/500 | Train Loss: 0.1797 | Train Acc: 92.94% | Test Loss: 0.2197 | Test Acc: 90.16%
# Epoch 400/500 | Train Loss: 0.1757 | Train Acc: 93.64% | Test Loss: 0.2124 | Test Acc: 90.86%
# Epoch 401/500 | Train Loss: 0.1760 | Train Acc: 93.25% | Test Loss: 0.2144 | Test Acc: 90.16%
# Epoch 402/500 | Train Loss: 0.1795 | Train Acc: 93.34% | Test Loss: 0.2131 | Test Acc: 91.21%
# Epoch 403/500 | Train Loss: 0.1755 | Train Acc: 93.64% | Test Loss: 0.2129 | Test Acc: 90.86%
# Epoch 404/500 | Train Loss: 0.1818 | Train Acc: 93.20% | Test Loss: 0.2149 | Test Acc: 91.56%
# Epoch 405/500 | Train Loss: 0.1752 | Train Acc: 93.69% | Test Loss: 0.2125 | Test Acc: 90.86%
# Epoch 406/500 | Train Loss: 0.1752 | Train Acc: 93.51% | Test Loss: 0.2131 | Test Acc: 90.51%
# Epoch 407/500 | Train Loss: 0.1775 | Train Acc: 93.77% | Test Loss: 0.2135 | Test Acc: 91.21%
# Epoch 408/500 | Train Loss: 0.1779 | Train Acc: 93.38% | Test Loss: 0.2130 | Test Acc: 91.39%
# Epoch 409/500 | Train Loss: 0.1749 | Train Acc: 93.86% | Test Loss: 0.2132 | Test Acc: 91.21%
# Epoch 410/500 | Train Loss: 0.1752 | Train Acc: 93.29% | Test Loss: 0.2147 | Test Acc: 90.51%
# Epoch 411/500 | Train Loss: 0.1747 | Train Acc: 93.73% | Test Loss: 0.2119 | Test Acc: 90.86%
# Epoch 412/500 | Train Loss: 0.1749 | Train Acc: 93.82% | Test Loss: 0.2111 | Test Acc: 90.86%
# Epoch 413/500 | Train Loss: 0.1749 | Train Acc: 93.95% | Test Loss: 0.2120 | Test Acc: 91.04%
# Epoch 414/500 | Train Loss: 0.1746 | Train Acc: 93.95% | Test Loss: 0.2128 | Test Acc: 91.21%
# Epoch 415/500 | Train Loss: 0.1767 | Train Acc: 93.03% | Test Loss: 0.2156 | Test Acc: 89.98%
# Epoch 416/500 | Train Loss: 0.1753 | Train Acc: 93.20% | Test Loss: 0.2140 | Test Acc: 90.16%
# Epoch 417/500 | Train Loss: 0.1772 | Train Acc: 92.90% | Test Loss: 0.2155 | Test Acc: 90.16%
# Epoch 418/500 | Train Loss: 0.1787 | Train Acc: 93.20% | Test Loss: 0.2134 | Test Acc: 91.56%
# Epoch 419/500 | Train Loss: 0.1749 | Train Acc: 94.13% | Test Loss: 0.2124 | Test Acc: 91.21%
# Epoch 420/500 | Train Loss: 0.1745 | Train Acc: 93.64% | Test Loss: 0.2148 | Test Acc: 90.69%
# Epoch 421/500 | Train Loss: 0.1758 | Train Acc: 93.16% | Test Loss: 0.2155 | Test Acc: 90.33%
# Epoch 422/500 | Train Loss: 0.1737 | Train Acc: 93.77% | Test Loss: 0.2120 | Test Acc: 90.86%
# Epoch 423/500 | Train Loss: 0.1791 | Train Acc: 92.94% | Test Loss: 0.2201 | Test Acc: 90.16%
# Epoch 424/500 | Train Loss: 0.1747 | Train Acc: 93.20% | Test Loss: 0.2134 | Test Acc: 90.16%
# Epoch 425/500 | Train Loss: 0.1751 | Train Acc: 93.16% | Test Loss: 0.2132 | Test Acc: 90.16%
# Epoch 426/500 | Train Loss: 0.1741 | Train Acc: 94.04% | Test Loss: 0.2107 | Test Acc: 91.21%
# Epoch 427/500 | Train Loss: 0.1735 | Train Acc: 93.99% | Test Loss: 0.2112 | Test Acc: 91.21%
# Epoch 428/500 | Train Loss: 0.1739 | Train Acc: 94.04% | Test Loss: 0.2116 | Test Acc: 91.21%
# Epoch 429/500 | Train Loss: 0.1735 | Train Acc: 93.56% | Test Loss: 0.2125 | Test Acc: 90.33%
# Epoch 430/500 | Train Loss: 0.1737 | Train Acc: 94.08% | Test Loss: 0.2115 | Test Acc: 91.21%
# Epoch 431/500 | Train Loss: 0.1730 | Train Acc: 94.26% | Test Loss: 0.2118 | Test Acc: 91.04%
# Epoch 432/500 | Train Loss: 0.1771 | Train Acc: 93.20% | Test Loss: 0.2128 | Test Acc: 91.92%
# Epoch 433/500 | Train Loss: 0.1860 | Train Acc: 92.42% | Test Loss: 0.2251 | Test Acc: 89.98%
# Epoch 434/500 | Train Loss: 0.1731 | Train Acc: 94.08% | Test Loss: 0.2116 | Test Acc: 91.21%
# Epoch 435/500 | Train Loss: 0.1821 | Train Acc: 92.85% | Test Loss: 0.2171 | Test Acc: 91.39%
# Epoch 436/500 | Train Loss: 0.1781 | Train Acc: 92.94% | Test Loss: 0.2191 | Test Acc: 90.16%
# Epoch 437/500 | Train Loss: 0.1779 | Train Acc: 92.90% | Test Loss: 0.2181 | Test Acc: 90.16%
# Epoch 438/500 | Train Loss: 0.1770 | Train Acc: 93.29% | Test Loss: 0.2147 | Test Acc: 91.39%
# Epoch 439/500 | Train Loss: 0.1844 | Train Acc: 92.68% | Test Loss: 0.2188 | Test Acc: 91.39%
# Epoch 440/500 | Train Loss: 0.1732 | Train Acc: 93.95% | Test Loss: 0.2100 | Test Acc: 91.21%
# Epoch 441/500 | Train Loss: 0.1796 | Train Acc: 92.94% | Test Loss: 0.2212 | Test Acc: 89.98%
# Epoch 442/500 | Train Loss: 0.1897 | Train Acc: 92.24% | Test Loss: 0.2242 | Test Acc: 90.16%
# Epoch 443/500 | Train Loss: 0.1723 | Train Acc: 94.17% | Test Loss: 0.2105 | Test Acc: 91.21%
# Epoch 444/500 | Train Loss: 0.1737 | Train Acc: 93.16% | Test Loss: 0.2123 | Test Acc: 90.16%
# Epoch 445/500 | Train Loss: 0.1720 | Train Acc: 93.69% | Test Loss: 0.2107 | Test Acc: 90.33%
# Epoch 446/500 | Train Loss: 0.1749 | Train Acc: 93.42% | Test Loss: 0.2117 | Test Acc: 91.39%
# Epoch 447/500 | Train Loss: 0.1755 | Train Acc: 93.03% | Test Loss: 0.2147 | Test Acc: 90.16%
# Epoch 448/500 | Train Loss: 0.1812 | Train Acc: 92.63% | Test Loss: 0.2160 | Test Acc: 91.56%
# Epoch 449/500 | Train Loss: 0.1736 | Train Acc: 93.12% | Test Loss: 0.2131 | Test Acc: 90.16%
# Epoch 450/500 | Train Loss: 0.1887 | Train Acc: 92.37% | Test Loss: 0.2292 | Test Acc: 89.81%
# Epoch 451/500 | Train Loss: 0.1794 | Train Acc: 92.68% | Test Loss: 0.2142 | Test Acc: 91.39%
# Epoch 452/500 | Train Loss: 0.1714 | Train Acc: 94.13% | Test Loss: 0.2111 | Test Acc: 91.21%
# Epoch 453/500 | Train Loss: 0.1712 | Train Acc: 94.30% | Test Loss: 0.2112 | Test Acc: 91.21%
# Epoch 454/500 | Train Loss: 0.1720 | Train Acc: 93.38% | Test Loss: 0.2129 | Test Acc: 90.16%
# Epoch 455/500 | Train Loss: 0.1723 | Train Acc: 93.20% | Test Loss: 0.2123 | Test Acc: 90.16%
# Epoch 456/500 | Train Loss: 0.1759 | Train Acc: 93.16% | Test Loss: 0.2121 | Test Acc: 91.74%
# Epoch 457/500 | Train Loss: 0.1819 | Train Acc: 92.33% | Test Loss: 0.2194 | Test Acc: 90.69%
# Epoch 458/500 | Train Loss: 0.1738 | Train Acc: 93.51% | Test Loss: 0.2126 | Test Acc: 91.74%
# Epoch 459/500 | Train Loss: 0.1709 | Train Acc: 93.99% | Test Loss: 0.2089 | Test Acc: 90.33%
# Epoch 460/500 | Train Loss: 0.1722 | Train Acc: 93.25% | Test Loss: 0.2124 | Test Acc: 89.98%
# Epoch 461/500 | Train Loss: 0.1758 | Train Acc: 93.20% | Test Loss: 0.2130 | Test Acc: 91.74%
# Epoch 462/500 | Train Loss: 0.1738 | Train Acc: 93.38% | Test Loss: 0.2110 | Test Acc: 91.74%
# Epoch 463/500 | Train Loss: 0.1732 | Train Acc: 93.38% | Test Loss: 0.2151 | Test Acc: 90.16%
# Epoch 464/500 | Train Loss: 0.1714 | Train Acc: 93.25% | Test Loss: 0.2114 | Test Acc: 89.98%
# Epoch 465/500 | Train Loss: 0.1705 | Train Acc: 94.17% | Test Loss: 0.2096 | Test Acc: 91.04%
# Epoch 466/500 | Train Loss: 0.1702 | Train Acc: 94.34% | Test Loss: 0.2106 | Test Acc: 91.04%
# Epoch 467/500 | Train Loss: 0.1723 | Train Acc: 93.29% | Test Loss: 0.2145 | Test Acc: 89.98%
# Epoch 468/500 | Train Loss: 0.1708 | Train Acc: 93.47% | Test Loss: 0.2096 | Test Acc: 90.33%
# Epoch 469/500 | Train Loss: 0.1699 | Train Acc: 93.95% | Test Loss: 0.2088 | Test Acc: 90.86%
# Epoch 470/500 | Train Loss: 0.1713 | Train Acc: 93.38% | Test Loss: 0.2121 | Test Acc: 89.98%
# Epoch 471/500 | Train Loss: 0.1702 | Train Acc: 94.08% | Test Loss: 0.2115 | Test Acc: 91.04%
# Epoch 472/500 | Train Loss: 0.1719 | Train Acc: 93.38% | Test Loss: 0.2144 | Test Acc: 89.98%
# Epoch 473/500 | Train Loss: 0.1715 | Train Acc: 93.25% | Test Loss: 0.2108 | Test Acc: 90.16%
# Epoch 474/500 | Train Loss: 0.1702 | Train Acc: 94.26% | Test Loss: 0.2090 | Test Acc: 91.04%
# Epoch 475/500 | Train Loss: 0.1700 | Train Acc: 93.91% | Test Loss: 0.2081 | Test Acc: 90.69%
# Epoch 476/500 | Train Loss: 0.1718 | Train Acc: 93.29% | Test Loss: 0.2126 | Test Acc: 89.98%
# Epoch 477/500 | Train Loss: 0.1716 | Train Acc: 93.64% | Test Loss: 0.2102 | Test Acc: 91.04%
# Epoch 478/500 | Train Loss: 0.1701 | Train Acc: 93.29% | Test Loss: 0.2105 | Test Acc: 90.16%
# Epoch 479/500 | Train Loss: 0.1735 | Train Acc: 93.29% | Test Loss: 0.2151 | Test Acc: 90.33%
# Epoch 480/500 | Train Loss: 0.1692 | Train Acc: 94.04% | Test Loss: 0.2074 | Test Acc: 90.86%
# Epoch 481/500 | Train Loss: 0.1728 | Train Acc: 93.25% | Test Loss: 0.2140 | Test Acc: 90.33%
# Epoch 482/500 | Train Loss: 0.1698 | Train Acc: 93.29% | Test Loss: 0.2101 | Test Acc: 90.16%
# Epoch 483/500 | Train Loss: 0.1694 | Train Acc: 94.21% | Test Loss: 0.2081 | Test Acc: 90.86%
# Epoch 484/500 | Train Loss: 0.1840 | Train Acc: 92.28% | Test Loss: 0.2211 | Test Acc: 90.51%
# Epoch 485/500 | Train Loss: 0.1688 | Train Acc: 94.21% | Test Loss: 0.2102 | Test Acc: 91.21%
# Epoch 486/500 | Train Loss: 0.1714 | Train Acc: 93.73% | Test Loss: 0.2108 | Test Acc: 91.56%
# Epoch 487/500 | Train Loss: 0.1731 | Train Acc: 93.42% | Test Loss: 0.2166 | Test Acc: 90.33%
# Epoch 488/500 | Train Loss: 0.1753 | Train Acc: 93.12% | Test Loss: 0.2179 | Test Acc: 89.98%
# Epoch 489/500 | Train Loss: 0.1763 | Train Acc: 93.16% | Test Loss: 0.2208 | Test Acc: 89.98%
# Epoch 490/500 | Train Loss: 0.1859 | Train Acc: 91.98% | Test Loss: 0.2260 | Test Acc: 89.98%
# Epoch 491/500 | Train Loss: 0.1687 | Train Acc: 94.30% | Test Loss: 0.2069 | Test Acc: 90.86%
# Epoch 492/500 | Train Loss: 0.1696 | Train Acc: 93.29% | Test Loss: 0.2094 | Test Acc: 89.98%
# Epoch 493/500 | Train Loss: 0.1687 | Train Acc: 94.34% | Test Loss: 0.2086 | Test Acc: 90.86%
# Epoch 494/500 | Train Loss: 0.1700 | Train Acc: 93.38% | Test Loss: 0.2106 | Test Acc: 90.16%
# Epoch 495/500 | Train Loss: 0.1808 | Train Acc: 92.68% | Test Loss: 0.2177 | Test Acc: 90.86%
# Epoch 496/500 | Train Loss: 0.1722 | Train Acc: 93.34% | Test Loss: 0.2104 | Test Acc: 91.04%
# Epoch 497/500 | Train Loss: 0.1691 | Train Acc: 93.99% | Test Loss: 0.2074 | Test Acc: 91.04%
# Epoch 498/500 | Train Loss: 0.1726 | Train Acc: 93.29% | Test Loss: 0.2124 | Test Acc: 90.33%
# Epoch 499/500 | Train Loss: 0.1689 | Train Acc: 94.26% | Test Loss: 0.2088 | Test Acc: 91.04%
# Epoch 500/500 | Train Loss: 0.1690 | Train Acc: 93.34% | Test Loss: 0.2096 | Test Acc: 90.16%
# Model finished training and validation.

# %% [markdown]
# @function `evaluate_model_performance()`:
#
# * Generates a comprehensive visual report of the model's training history and final classification performance in a 3-row vertical layout.
#
# * **Loss Curve**: Visualizes the relationship between training and validation loss across epochs to detect overfitting or convergence issues.
#
# * **Accuracy Curve** : Tracks the percentage of correct predictions over time for both the training and test sets.
#
# * **Confusion Matrix** : Calculate the classification metrics (TP, TN, FP, FN) and displays them as a Seaborn heatmap for error analysis.
#
# * params
#     * `history`: A dictionary containing the logged lists of loss and accuracy values.
#     * `y_true` : The truth labels from the test dataset.
#     * `y_pred` : The binary predictions (0 or 1) generated by the model.
#     * `title` : string used as the main heading for the entire figure.

# %%
def evaluate_model_performance(history:dict, y_true:list, y_pred:list, title:str):
    # Create a figure within 3 rows
    fig, axes = plt.subplots(3, 1, figsize=(6, 20))
    fig.suptitle(f'Model Evaluation: {title}', fontsize=16, fontweight='bold')

    # --- 1. Loss Curve Plot ---
    train_loss = history['train_loss']
    val_loss = history['test_loss']
    epochs = range(1, len(train_loss) + 1)

    axes[0].plot(epochs, train_loss, label='Training Loss', color='blue', lw=1.5, marker='x', ms=4)
    axes[0].plot(epochs, val_loss, label='Validation Loss', color='orange', lw=1.5, marker='x', ms=4)
    axes[0].set_title('Loss Curve (Learning Curve)')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # --- 2. Accuracy Plot ---
    train_acc = history['train_acc']
    val_acc = history['test_acc']
    axes[1].plot(epochs, train_acc, label='Training Accuracy', color='blue', lw=1.5, marker='x', ms=4)
    axes[1].plot(epochs, val_acc, label='Validation Accuracy', color='orange', lw=1.5, marker='x', ms=4)
    axes[1].set_title('Accuracy Over Epochs')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    # --- 3. Confusion Matrix ---
    actual = np.array(y_true).flatten()
    predicted = np.array(y_pred).flatten()
    
    tp = np.sum((actual == 1) & (predicted == 1))
    tn = np.sum((actual == 0) & (predicted == 0))
    fp = np.sum((actual == 0) & (predicted == 1))
    fn = np.sum((actual == 1) & (predicted == 0))
    cm = np.array([[tn, fp], [fn, tp]])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Stay', 'Churn'], 
            yticklabels=['Stay', 'Churn'],
            ax=axes[2])
    axes[2].set_title('Confusion Matrix: Churn Prediction')
    axes[2].set_ylabel('Actual')
    axes[2].set_xlabel('Predicted')
    # Adjust layout to prevent overlap
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
    
evaluate_model_performance(history, y_test, y_hat, title='Model 1: Binary Cross Entropy')
