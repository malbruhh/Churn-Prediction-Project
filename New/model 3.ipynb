# %% [markdown]
# ## 3nd Model : Adaptive Learning Rate (Adam)
# - Network Architecture:
#     - 2 hidden layers
#     - RelU Activation on Hidden
#     - Sigmoid Activation on Output
#     - Adaptive learning rate (Exponential)
#     - epoch = 500

# %% [markdown]
# ## Steps:
# 1. Import Libraries
# 2. Read Data from `\Dataset` folder (Retrieved from UCI Repositories)
# 3. Clean Dataset (rename and format the column)
# 4. Data Preprocessing
# 5. Initialize the model
# 6. Train and test the data
# 7. Evaluate Performance using graph

# %% [markdown]
# ### 0. Install Library Requirements

# %%
# %pip install jupyter numpy pandas matplotlib seaborn tabulate imblearn

# %% [markdown]
# ### 1. Import Libraries
# Import necessary libraries:
# * `numpy`     : High performance array object
# * `pandas`    : Data analysis and manipulation tools
# * `matplotlib`: Data visualizations
# * `seaborn`   : Data visualizations framework based on **matplotlib**
# * `tabulate`  : Pretty-print tabular structure library
# * `imblearn`  : SMOTE class balance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
from imblearn.over_sampling import SMOTE
import seaborn as sns

# %% [markdown]
# #### 1.1 Helper Functions
# * Handle mathematical operation used in the `NeuralNetwork` Class

# %%
def sigmoid(x): return 1 /(1 + np.exp(-x))
def relu(x): return np.maximum(0,x)
def derivative_relu(relu_x): return (relu_x>0).astype(float)
def binary_cross_entropy(y_true, y_pred, epsilon=1e-15):
    # Clip predictions to prevent log(0)
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
    return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))

# %% [markdown]
# ### 2. Read and Display Dataset Information
# load the dataset and understand the data, and use the Interquartile Range (IQR) method to identify potential outliers in numerical columns.
# 2.1 Read dataset

# %%
def read_file(file_path: str):
    df = pd.read_csv(file_path)
    new_columns = [col.strip().replace('  ', ' ').replace(' ', '_').lower() for col in df.columns]
    df.columns = new_columns
    return df

path = r'..\Dataset\Customer Churn.csv'
df = read_file(path)
df.head(20)
# Out:
#     call_failure  complains  subscription_length  charge_amount  \
# 0              8          0                   38              0
# 1              0          0                   39              0
# 2             10          0                   37              0
# 3             10          0                   38              0
# 4              3          0                   38              0
# 5             11          0                   38              1
# 6              4          0                   38              0
# 7             13          0                   37              2
# 8              7          0                   38              0
# 9              7          0                   38              1
# 10             6          0                   38              0
# 11             9          0                   38              0
# 12            25          0                   38              3
# 13             4          0                   38              1
# 14             9          0                   37              0
# 15             3          0                   37              1
# 16             0          0                   37              0
# 17             2          0                   38              0
# 18             0          0                   37              0
# 19             3          0                   37              0
#
#     seconds_of_use  frequency_of_use  frequency_of_sms  \
# 0             4370                71                 5
# 1              318                 5                 7
# 2             2453                60               359
# 3             4198                66                 1
# 4             2393                58                 2
# 5             3775                82                32
# 6             2360                39               285
# 7             9115               121               144
# 8            13773               169                 0
# 9             4515                83                 2
# 10            5918                95                 7
# 11            2238                54                 8
# 12           15140               225                54
# 13            3095                27               483
# 14           15485               182               150
# 15            6500                86               186
# 16             875                14                 0
# 17             710                14                13
# 18               0                 0                 0
# 19            7508               127               384
#
#     distinct_called_numbers  age_group  tariff_plan  status  age  \
# 0                        17          3            1       1   30
# 1                         4          2            1       2   25
# 2                        24          3            1       1   30
# 3                        35          1            1       1   15
# 4                        33          1            1       1   15
# 5                        28          3            1       1   30
# 6                        18          3            1       1   30
# 7                        43          3            1       1   30
# 8                        44          3            1       1   30
# 9                        25          3            1       1   30
# 10                       12          3            1       1   30
# 11                       17          3            1       2   30
# 12                       32          3            1       1   30
# 13                        8          3            1       1   30
# 14                       30          2            1       1   25
# 15                       26          3            1       1   30
# 16                       11          2            1       2   25
# 17                        8          3            1       2   30
# 18                        0          2            1       2   25
# 19                       43          2            1       1   25
#
#     customer_value  churn
# 0          197.640      0
# 1           46.035      0
# 2         1536.520      0
# 3          240.020      0
# 4          145.805      0
# 5          282.280      0
# 6         1235.960      0
# 7          945.440      0
# 8          557.680      0
# 9          191.920      0
# 10         268.520      0
# 11         123.680      0
# 12         830.600      0
# 13        2056.880      0
# 14        1380.015      0
# 15        1007.440      0
# 16          40.005      1
# 17          80.960      0
# 18           0.000      1
# 19        2071.575      0

# %% [markdown]
# 2.2 Display dataset data types and null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   call_failure             3150 non-null   int64
#  1   complains                3150 non-null   int64
#  2   subscription_length      3150 non-null   int64
#  3   charge_amount            3150 non-null   int64
#  4   seconds_of_use           3150 non-null   int64
#  5   frequency_of_use         3150 non-null   int64
#  6   frequency_of_sms         3150 non-null   int64
#  7   distinct_called_numbers  3150 non-null   int64
#  8   age_group                3150 non-null   int64
#  9   tariff_plan              3150 non-null   int64
#  10  status                   3150 non-null   int64
#  11  age                      3150 non-null   int64
#  12  customer_value           3150 non-null   float64
#  13  churn                    3150 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 344.7 KB

# %% [markdown]
# 2.3 Display dataset shape and its statisical values

# %%
df.describe()
# Out:
#        call_failure    complains  subscription_length  charge_amount  \
# count   3150.000000  3150.000000          3150.000000    3150.000000
# mean       7.627937     0.076508            32.541905       0.942857
# std        7.263886     0.265851             8.573482       1.521072
# min        0.000000     0.000000             3.000000       0.000000
# 25%        1.000000     0.000000            30.000000       0.000000
# 50%        6.000000     0.000000            35.000000       0.000000
# 75%       12.000000     0.000000            38.000000       1.000000
# max       36.000000     1.000000            47.000000      10.000000
#
#        seconds_of_use  frequency_of_use  frequency_of_sms  \
# count     3150.000000       3150.000000       3150.000000
# mean      4472.459683         69.460635         73.174921
# std       4197.908687         57.413308        112.237560
# min          0.000000          0.000000          0.000000
# 25%       1391.250000         27.000000          6.000000
# 50%       2990.000000         54.000000         21.000000
# 75%       6478.250000         95.000000         87.000000
# max      17090.000000        255.000000        522.000000
#
#        distinct_called_numbers    age_group  tariff_plan       status  \
# count              3150.000000  3150.000000  3150.000000  3150.000000
# mean                 23.509841     2.826032     1.077778     1.248254
# std                  17.217337     0.892555     0.267864     0.432069
# min                   0.000000     1.000000     1.000000     1.000000
# 25%                  10.000000     2.000000     1.000000     1.000000
# 50%                  21.000000     3.000000     1.000000     1.000000
# 75%                  34.000000     3.000000     1.000000     1.000000
# max                  97.000000     5.000000     2.000000     2.000000
#
#                age  customer_value        churn
# count  3150.000000     3150.000000  3150.000000
# mean     30.998413      470.972916     0.157143
# std       8.831095      517.015433     0.363993
# min      15.000000        0.000000     0.000000
# 25%      25.000000      113.801250     0.000000
# 50%      30.000000      228.480000     0.000000
# 75%      30.000000      788.388750     0.000000
# max      55.000000     2165.280000     1.000000

# %% [markdown]
# 2.4. Detect Outliers

# %%
def detect_outliers_iqr(df, k=1.5):
    nums = df.select_dtypes(include='number')
    outlier_info = {}
    
    for c in nums.columns:
        #skip binary columns
        if(nums[c].nunique() <= 2):
            continue
        
        q1 = nums[c].quantile(0.25) #1st quartile
        q3 = nums[c].quantile(0.75) #3rd quartile
        iqr = q3 - q1
        lower = q1 - k * iqr
        upper = q3 + k * iqr
        mask = (nums[c] < lower) | (nums[c] > upper)
        outlier_info[c] = {
            'count': int(mask.sum()),
            'indices': nums.index[mask].tolist(),
            'lower': float(lower),
            'upper': float(upper)
        }
    return outlier_info

outliers = detect_outliers_iqr(df)
table_data = []
print('\nOutlier summary (IQR method):')
for col, info in outliers.items():
    if info['count'] > 0:
    # Calculate percentage
        perc = (info["count"] / len(df)) * 100
        
        # Add a list (row) to our table_data
        table_data.append([col, info["count"], f"{info['lower']:.3f}",
            f"{info['upper']:.3f}", f"{perc:.2f}%"])
headers = ["Column", "Outlier Count", "Lower Bound", "Upper Bound", "Percentage"]
print(tabulate(table_data, headers=headers))
# Out:
# Outlier summary (IQR method):
# Column                     Outlier Count    Lower Bound    Upper Bound  Percentage
# -----------------------  ---------------  -------------  -------------  ------------
# call_failure                          47         -15.5           28.5   1.49%
# subscription_length                  282          18             50     8.95%
# charge_amount                        370          -1.5            2.5   11.75%
# seconds_of_use                       200       -6239.25       14108.8   6.35%
# frequency_of_use                     129         -75            197     4.10%
# frequency_of_sms                     368        -115.5          208.5   11.68%
# distinct_called_numbers               77         -26             70     2.44%
# age_group                            170           0.5            4.5   5.40%
# age                                  688          17.5           37.5   21.84%
# customer_value                       116        -898.08        1800.27  3.68%

# %% [markdown]
# ### 3. Data Cleaning
# This process take step before handling with outliers and data preprocessing.
#
# 3.1 Remove Duplicate Row (if any)

# %%
df = df.drop_duplicates()
print(f'\n[Changes] Removed duplicate rows. New shape={df.shape}\n')
# Out:
# [Changes] Removed duplicate rows. New shape=(2850, 14)

# %% [markdown]
# 3.2 Remove Redundant Groups
#
# `age_group` and `age` columns both have the same values but in different types, numeric and nominal respectively.
# `age_group` column is dropped to prevent biases when learning

# %%
df = df.drop(columns=['age_group'])
print(f'\n[Changes] Dropped column: age_group due to redundancy. New shape={df.shape}\n\n')
# Out:
# [Changes] Dropped column: age_group due to redundancy. New shape=(2850, 13)

# %% [markdown]
# ### 4. Data Preprocessing
#
# The dataset will follows the exact steps to avoid any imbalance or data leakage during testing.

# %% [markdown]
# [Split] -> [Log] -> [Encode] -> [Fit] -> [Scale] -> [Balance]

# %% [markdown]
# #### 4.1 Split
#
# * Splitting the dataset into train, and test sets, and both input,X and output,Y
# * This function will reset the intialized index of X and Y dataset, and shuffle them before splitting to prevent **data leakage**
#
# @function `split_data()`:
# * params
#     * `X`, `y` as input and output
#     * `test_split` as testing split percentage ; default `0.2`
#     * `randomness` as random values for randomize dataset index before splitting ; default `None`
# * return
#     * `X_train` = Training set without `Churn`
#     * `Y_train` = `Churn` Training column
#     * `Y_train` = Testing set without `Churn`
#     * `Y_test` = `Churn` Testing column

# %%
def split_data(X, y, test_split=0.2, randomness=None):
    # Set seed for reproducibility
    if randomness is not None:
        np.random.seed(randomness)
    
    # reset X and Y current index
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    
    # Identify unique classes and their indices (0 and 1)
    unique_classes = np.unique(y)
    train_indices = []
    test_indices = []
    
    for cls in unique_classes:
        # Get indices of rows belonging to this class
        cls_indices = np.where(y == cls)[0]

        # Shuffle indices within this specific class
        np.random.shuffle(cls_indices)

        # Determine the split point
        total_count = len(cls_indices)
        test_count = int(total_count * test_split)
        
        # Split indices
        cls_test = cls_indices[:test_count]
        cls_train = cls_indices[test_count:]
        
        # Add to main lists
        test_indices.extend(cls_test)
        train_indices.extend(cls_train)
        
    # Shuffle the final combined indices so they aren't grouped by class
    np.random.shuffle(train_indices)
    np.random.shuffle(test_indices)
    
    # Use .iloc for DataFrames to select the rows
    X_train, X_test = X.iloc[train_indices], X.iloc[test_indices]
    y_train, y_test = y.iloc[train_indices], y.iloc[test_indices]
    return X_train, X_test, y_train, y_test

X = df.drop(columns=['churn'], axis=1)
Y = df['churn']
X_train,X_test,y_train,y_test = split_data(X,Y,test_split=0.2, randomness=42)
print(f'[Changes] Successfully split data into Training and Testing.')
# Out:
# [Changes] Successfully split data into Training and Testing.

# %% [markdown]
# #### 4.2 Log Transformation
#
# * This will treat the outliers found before, compressing all the values within the dataset to **reduce** the skewness of the data
# * This step is to prevent unfair patterns.
# * Use `numpy.log(1 + x)`
# * log transformation on seperated train and test set to prevent **data leakage**
#
# @function `log_transformation()`:
# * params
#     * `df_train`, `df_test` as training and testing dataset
#     * `cols_log` as list of column to be log transformed
# * return
#     * `df_train` = train dataset that have been log transformed
#     * `df_test` = test dataset that have been log transformed

# %%
def log_transformation(df_train, df_test, cols_log: list):
    for col in cols_log:
        df_train[col] = np.log1p(df_train[col])
        df_test[col] = np.log1p(df_test[col])
    print(f'[Changes] Applied log transformation to selected columns.')
    return df_train, df_test

cols_to_log = [
    'seconds_of_use',
    'frequency_of_use',
    'frequency_of_sms',
    'distinct_called_numbers',
    'call_failure',
    'customer_value',
    'charge_amount'
]
X_train, X_test = log_transformation(X_train,X_test,cols_to_log)
# Out:
# [Changes] Applied log transformation to selected columns.

# %% [markdown]
# #### 4.3 One-Hot Encoding
#
# * Convert categorical column into multiple, numeric dummy columns that values between `0` and `1`.
# * Example: `plan` have 3 categories  = `[cat1, cat2, cat3]`. It will split into dummy columns for each category, `plan_cat1`, `plan_cat2`, `plan_cat3`
# * use drop first column attribute to prevent **multicollinearity**
#
# @function `get_train_category()`:
# * params
#     * `df` as dataset
#     * `col_name` retrieve category from this column
# * return
#     * `list` = list of column name
#
#
# @function `one_hot_encoding()`:
# * params
#     * `df` as dataset
#     * `col_name` as column name that will apply one-hot encoding
#     * `categories` as category inside `col_name`
#     * `drop_first` drop first column to simplify the dummy column
# * return
#     * `converted_pd` = return the dataframe with the added dummy columns

# %%
def get_train_categories(df, col_name):
    return sorted(list(set(df[col_name].tolist())))

def one_hot_encoding(df, col_name:str, categories, drop_first = True):
    data = df[col_name].tolist()
    
    active_cats = categories[1:] if drop_first and len(categories) > 1 else categories
    
    encoded_mtx = []
    for item in data:
        row = [0] * len(active_cats)
        if item in active_cats:
            index = active_cats.index(item)
            row[index] = 1
        encoded_mtx.append(row)
    
    #rename column for one hot encoded column
    new_cols = [f'{col_name}_{cat}' for cat in active_cats]
    #convert back to dataframe
    converted_pd  = pd.DataFrame(encoded_mtx, columns=new_cols,index=df.index)
    return converted_pd

train_encoded_parts = []
test_encoded_parts = []

categorical = ['complains', 'tariff_plan', 'status']
for col in categorical:
    train_categories = get_train_categories(X_train, col)
    train_encoded_parts.append(one_hot_encoding(X_train, col, train_categories, drop_first=True))        
    test_encoded_parts.append(one_hot_encoding(X_test, col, train_categories, drop_first=True))
print(f'[Changes] Applied one hot encoding to categorical columns')

#drop old column and join new columns
X_train = X_train.drop(columns=categorical).join(train_encoded_parts)
X_test = X_test.drop(columns=categorical).join(test_encoded_parts)
# Out:
# [Changes] Applied one hot encoding to categorical columns

# %% [markdown]
# #### 4.4 Scaling Feature
#
# * Transforms features to fit within a specific range, usually `0`, by subtracting the minimum value and dividing by the range `(max - min)`
# * Using `min()` and `max()` function to retrieve the minimum and maximum value in a column
# * Scales the transformation on training data, and transform on train and test dataset to prevent data leakage
#
# @function `get_scaling_params()`:
# * params
#     * `df_train` as training input dataset
# * return
#     * `param_dict` = a dictionary contains the minimum and maximum value for every key column
#
# @function `min_max_transform()`:
# * params
#     * `df` as input dataset
#     * `params` as dicitionary containing min and max value for each column
# * return
#     * `df_scaled` = scaled dataset

# %%
def get_scaling_params(df_train):
    param_dict = {}
    for col in df_train.columns:   
        min_val = min(df_train[col])
        max_val = max(df_train[col])
        param_dict[col] = (min_val, max_val - min_val)
    return param_dict

#eg: min_max_transform(X_TEST, train_min_val, train_data_range)
def min_max_transform(df, params: dict):
    df_scaled = df.copy()

    for col, (min_v, data_range) in params.items():
        if data_range == 0:
            df_scaled[col] = 0.0 #base case float number
        else:
            df_scaled[col] = (df[col] - min_v) / data_range
            
    return df_scaled

X_train_scale_params = get_scaling_params(X_train)
X_train_scaled = min_max_transform(X_train, X_train_scale_params)
X_test_scaled = min_max_transform(X_test, X_train_scale_params)
print(f'[Changes] Applied Min Max Scaler on numerical columns')
# Out:
# [Changes] Applied Min Max Scaler on numerical columns

# %% [markdown]
# #### 4.5 Class Balancing
#
# * The dataset contains around 80% `0` (Not Churn) and 20% `1` (Churn), causing imbalance and can cause the model to become biased, favor the majority class, and perform poorly on the crucial minority class.
# * `SMOTE` is a **oversampling** technique used to create synthetic data using its algorithm to balance the class.
# * Only apply to training data only to prevent data leakage

# %%
# smote = SMOTE(sampling_strategy=0.8, random_state=42)
# X_train_final, y_train_final = smote.fit_resample(X_train_scaled, y_train)
# print(f"Before SMOTE - Class Distribution: {y_train.value_counts()}")
# print(f"After SMOTE - Class Distribution: {pd.Series(y_train_final).value_counts()}")
# print(f"Final training set size: {len(X_train_final)}")

# %% [markdown]
# ### 5. Initialize the Model
#
# #### 5.1 Intialize Variables
# * `EPOCHS`      : Iteration counts
# * `BATCH_SIZE`  : Hyperparameter of size of batch for smaller subsets
# * `PATIENCE`    : Hyperparameter stopping condition that wait for an improvement
# * `input_dim` = input layer size (nodes)

# %%
EPOCHS = 500
BATCH_SIZE = 32
PATIENCE = 100

input_dim = X_train_scaled.shape[1]

# %% [markdown]
# @Class `NeuralNetwork`
# * A multi-layer perceptron (Backpropagation Neural Network) designed for binary classification.
# * He initialization for weight stability, mini-batch gradient descent, and early stopping based on patience or error thresholds.
#
# @function `feedforward()`:
# * Feed the data forward, [Input] -> w1 -> [Hidden] -> w2 -> [Output]
# * Input to hidden layer will use **ReLU** activation function to handle nonlinear
# * Hidden layer to output layer will use **Sigmoid** activation function to **0 - 1** output
#
# @function `backpropagation()`:
# * Calculates the gradients of the loss function with respect to each weight and bias in the network.
# * Uses Gradient Clipping (max value of 5.0) to prevent exploding gradients and stability.
# * Updates weight1, weight2, bias1, and bias2 using the calculated deltas and the learning rate (`alpha`).
#
# @function `train()`
# * Manages the entire learning process over a set number of EPOCHS using Mini-batch Gradient Descent.
# * Shuffles the training data every epoch to improve generalization and prevent the model from learning the order of the data.
# * Stopping Condition:
#     * `max_error`
#     * `patience`
#
# @function `calculate_accuracy()`
# * Computes the percentage of correct predictions by comparing predicted probabilities against true labels
# * 0.5 threshold to convert sigmoid probabilities into binary classes (0 or 1).
#
# @function `predict()`
# * Performs a final feedforward pass on unseen data to generate class predictions.
# * Flattens the final output and applies a boolean threshold (0.5) to return integer class labels.

# %%
class NeuralNetwork:
    def __init__(self, input_dimension, hidden1_nodes=16, hidden2_nodes=8, alpha=0.01):
        self.alpha = alpha
        self.weight1 = np.random.randn(input_dimension, hidden1_nodes) * np.sqrt(2/input_dimension) #He Initializaion keeps Weight stable
        self.weight2 = np.random.randn(hidden1_nodes, hidden2_nodes) * np.sqrt(2/hidden1_nodes)
        self.weight3 = np.random.randn(hidden2_nodes, 1) * np.sqrt(2/hidden2_nodes)
        self.bias1 = np.zeros((1, hidden1_nodes))
        self.bias2 = np.zeros((1, hidden2_nodes))
        self.bias3 = np.zeros((1, 1))
        
        self.train_loss, self.test_loss, self.train_acc, self.test_acc = [], [], [], []
        self.history = {
            'train_loss': self.train_loss,
            'test_loss': self.test_loss,
            'train_acc': self.train_acc,
            'test_acc': self.test_acc
        }    
        
    def feedforward(self,X):
        self.hidden1_Z = X @ self.weight1 + self.bias1
        self.hidden1_A = relu(self.hidden1_Z)
        self.hidden2_Z = self.hidden1_A @ self.weight2 + self.bias2
        self.hidden2_A = relu(self.hidden2_Z)
        self.output_Z = self.hidden2_A @ self.weight3 + self.bias3
        self.output_A= sigmoid(self.output_Z)
        
        return self.output_A
    
    def backpropagation(self, X, y, output):
        size = y.shape[0] 
        
        d_output = (output - y)
        d_weight3 = self.hidden2_A.T @ d_output / size
        d_bias3 = np.sum(d_output, axis=0, keepdims=True) / size
        
        d_hidden2_A = d_output @ self.weight3.T
        d_hidden2_Z = d_hidden2_A * derivative_relu(self.hidden2_Z)
        d_weight2 = self.hidden1_A.T @ d_hidden2_Z / size
        d_bias2 = np.sum(d_hidden2_Z, axis=0, keepdims=True) / size
        
        d_hidden1_A = d_hidden2_Z @ self.weight2.T
        d_hidden1_Z = d_hidden1_A * derivative_relu(self.hidden1_Z)
        d_weight1 = X.T @ d_hidden1_Z / size
        d_bias1 = np.sum(d_hidden1_Z, axis=0, keepdims=True) / size
        
        #update weights using gradient descent
        self.weight3 -= self.alpha * d_weight3
        self.bias3 -= self.alpha * d_bias3
        self.weight2 -= self.alpha * d_weight2
        self.bias2 -= self.alpha * d_bias2
        self.weight1 -= self.alpha * d_weight1
        self.bias1 -= self.alpha * d_bias1

    def calculate_accuracy(self, y_true, y_pred_prob):
        # Threshold at 0.5 for binary classification
        predictions = (y_pred_prob > 0.5).astype(int)
        correct = np.sum(predictions == y_true)
        return correct / len(y_true)
    
    def train(self, X_train, y_train, X_test, y_test):
        epochs = EPOCHS
        batch_size = BATCH_SIZE
        max_error = 0.01
        best_loss = float('inf')
        patience_count = 0
        patience = PATIENCE
        initial_alpha = self.alpha
        
        X_tr = X_train.values if isinstance(X_train, pd.DataFrame) else X_train
        y_tr = np.array(y_train).reshape(-1, 1)
        X_te = X_test.values if isinstance(X_test, pd.DataFrame) else X_test
        y_te = np.array(y_test).reshape(-1, 1)
        
        n_samples = X_tr.shape[0]
        
        for epoch in range(epochs):
            
            if (epoch + 1) % 100 == 0:
                self.alpha = initial_alpha * (0.95 ** (epoch / 10)) 
                print(f"Learning rate reduced to: {self.alpha:.6f}")
            # Shuffle data each epoch
            indices = np.random.permutation(n_samples)
            X_tr_shuffled = X_tr[indices]
            y_tr_shuffled = y_tr[indices]
            
            # Mini-batch training
            for i in range(0, n_samples, batch_size):
                batch_X = X_tr_shuffled[i:i+batch_size]
                batch_y = y_tr_shuffled[i:i+batch_size]
                
                output = self.feedforward(batch_X)
                self.backpropagation(batch_X, batch_y, output)
            
            # Calculate metrics on full dataset
            output_full = self.feedforward(X_tr)
            train_loss = binary_cross_entropy(y_tr, output_full)
            train_acc = np.mean((output_full > 0.5).astype(int) == y_tr) * 100
            
            output_test = self.feedforward(X_te)
            test_loss = binary_cross_entropy(y_te, output_test)
            test_acc = np.mean((output_test > 0.5).astype(int) == y_te) * 100
            
            self.train_loss.append(train_loss)
            self.test_loss.append(test_loss)
            self.train_acc.append(train_acc)
            self.test_acc.append(test_acc)
            
            print(f'Epoch {epoch + 1}/{epochs} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%')
            
            if test_loss < best_loss:
                best_loss = test_loss
                patience_count = 0
            else:
                patience_count += 1
            
            if patience_count >= patience:
                print(f'[Training Stopped] Patience {patience} reached')
                break
            
            if train_loss <= max_error:
                print(f'[Training Stopped] Max error {max_error} reached')
                break
            
        return self.history

    def predict(self, X):
        X_vals = X.values if isinstance(X, pd.DataFrame) else X        
        h1_Z = X_vals @ self.weight1 + self.bias1
        h1_A = relu(h1_Z)
        h2_Z = h1_A @ self.weight2 + self.bias2
        h2_A = relu(h2_Z)
        o_Z = h2_A @ self.weight3 + self.bias3
        probs = sigmoid(o_Z)
        return (probs > 0.5).astype(int).flatten()

# %% [markdown]
# 5.2 Initialize, Train and Predict
#
# * Input Layer : 12 nodes
# * Hidden Layer : 8 nodes
# * Learning Rate : Adaptive exponential
# * Epochs : 500
# * Batch Size : 32

# %%
nn = NeuralNetwork(input_dimension= input_dim, alpha=0.01)
history = nn.train(X_train_scaled, y_train, X_test_scaled, y_test)    
y_hat = nn.predict(X_test_scaled)

print('Model finished training and validation.')
# Out:
# Epoch 1/500 | Train Loss: 0.4181 | Train Acc: 84.70% | Test Loss: 0.4219 | Test Acc: 84.53%
# Epoch 2/500 | Train Loss: 0.3693 | Train Acc: 85.31% | Test Loss: 0.3763 | Test Acc: 85.06%
# Epoch 3/500 | Train Loss: 0.3418 | Train Acc: 85.36% | Test Loss: 0.3515 | Test Acc: 84.18%
# Epoch 4/500 | Train Loss: 0.3205 | Train Acc: 85.53% | Test Loss: 0.3337 | Test Acc: 84.18%
# Epoch 5/500 | Train Loss: 0.3021 | Train Acc: 86.23% | Test Loss: 0.3187 | Test Acc: 84.89%
# Epoch 6/500 | Train Loss: 0.2874 | Train Acc: 88.25% | Test Loss: 0.3072 | Test Acc: 87.17%
# Epoch 7/500 | Train Loss: 0.2750 | Train Acc: 89.61% | Test Loss: 0.2969 | Test Acc: 87.52%
# Epoch 8/500 | Train Loss: 0.2645 | Train Acc: 89.57% | Test Loss: 0.2878 | Test Acc: 87.35%
# Epoch 9/500 | Train Loss: 0.2569 | Train Acc: 89.65% | Test Loss: 0.2812 | Test Acc: 87.17%
# Epoch 10/500 | Train Loss: 0.2505 | Train Acc: 89.79% | Test Loss: 0.2759 | Test Acc: 87.17%
# Epoch 11/500 | Train Loss: 0.2451 | Train Acc: 90.14% | Test Loss: 0.2722 | Test Acc: 87.70%
# Epoch 12/500 | Train Loss: 0.2407 | Train Acc: 90.18% | Test Loss: 0.2686 | Test Acc: 87.87%
# Epoch 13/500 | Train Loss: 0.2373 | Train Acc: 90.14% | Test Loss: 0.2655 | Test Acc: 87.52%
# Epoch 14/500 | Train Loss: 0.2347 | Train Acc: 90.66% | Test Loss: 0.2638 | Test Acc: 87.87%
# Epoch 15/500 | Train Loss: 0.2324 | Train Acc: 90.84% | Test Loss: 0.2621 | Test Acc: 88.05%
# Epoch 16/500 | Train Loss: 0.2307 | Train Acc: 90.49% | Test Loss: 0.2604 | Test Acc: 87.87%
# Epoch 17/500 | Train Loss: 0.2292 | Train Acc: 90.53% | Test Loss: 0.2594 | Test Acc: 88.05%
# Epoch 18/500 | Train Loss: 0.2280 | Train Acc: 90.84% | Test Loss: 0.2586 | Test Acc: 88.58%
# Epoch 19/500 | Train Loss: 0.2271 | Train Acc: 91.19% | Test Loss: 0.2581 | Test Acc: 88.75%
# Epoch 20/500 | Train Loss: 0.2264 | Train Acc: 90.79% | Test Loss: 0.2574 | Test Acc: 88.22%
# Epoch 21/500 | Train Loss: 0.2257 | Train Acc: 91.36% | Test Loss: 0.2572 | Test Acc: 88.93%
# Epoch 22/500 | Train Loss: 0.2252 | Train Acc: 91.36% | Test Loss: 0.2571 | Test Acc: 89.10%
# Epoch 23/500 | Train Loss: 0.2245 | Train Acc: 91.19% | Test Loss: 0.2565 | Test Acc: 89.10%
# Epoch 24/500 | Train Loss: 0.2242 | Train Acc: 90.88% | Test Loss: 0.2561 | Test Acc: 88.58%
# Epoch 25/500 | Train Loss: 0.2246 | Train Acc: 91.23% | Test Loss: 0.2572 | Test Acc: 89.10%
# Epoch 26/500 | Train Loss: 0.2243 | Train Acc: 90.93% | Test Loss: 0.2561 | Test Acc: 88.58%
# Epoch 27/500 | Train Loss: 0.2232 | Train Acc: 91.28% | Test Loss: 0.2557 | Test Acc: 89.28%
# Epoch 28/500 | Train Loss: 0.2234 | Train Acc: 91.23% | Test Loss: 0.2563 | Test Acc: 89.10%
# Epoch 29/500 | Train Loss: 0.2235 | Train Acc: 91.32% | Test Loss: 0.2566 | Test Acc: 89.10%
# Epoch 30/500 | Train Loss: 0.2225 | Train Acc: 91.19% | Test Loss: 0.2555 | Test Acc: 89.28%
# Epoch 31/500 | Train Loss: 0.2221 | Train Acc: 91.06% | Test Loss: 0.2548 | Test Acc: 88.40%
# Epoch 32/500 | Train Loss: 0.2225 | Train Acc: 91.28% | Test Loss: 0.2558 | Test Acc: 89.10%
# Epoch 33/500 | Train Loss: 0.2216 | Train Acc: 91.14% | Test Loss: 0.2545 | Test Acc: 89.10%
# Epoch 34/500 | Train Loss: 0.2213 | Train Acc: 91.28% | Test Loss: 0.2544 | Test Acc: 89.10%
# Epoch 35/500 | Train Loss: 0.2211 | Train Acc: 91.10% | Test Loss: 0.2542 | Test Acc: 89.10%
# Epoch 36/500 | Train Loss: 0.2212 | Train Acc: 91.06% | Test Loss: 0.2541 | Test Acc: 88.58%
# Epoch 37/500 | Train Loss: 0.2207 | Train Acc: 91.28% | Test Loss: 0.2539 | Test Acc: 89.10%
# Epoch 38/500 | Train Loss: 0.2207 | Train Acc: 91.06% | Test Loss: 0.2537 | Test Acc: 88.58%
# Epoch 39/500 | Train Loss: 0.2209 | Train Acc: 91.14% | Test Loss: 0.2544 | Test Acc: 89.10%
# Epoch 40/500 | Train Loss: 0.2204 | Train Acc: 91.14% | Test Loss: 0.2537 | Test Acc: 89.10%
# Epoch 41/500 | Train Loss: 0.2198 | Train Acc: 91.06% | Test Loss: 0.2527 | Test Acc: 88.75%
# Epoch 42/500 | Train Loss: 0.2209 | Train Acc: 90.88% | Test Loss: 0.2534 | Test Acc: 88.22%
# Epoch 43/500 | Train Loss: 0.2193 | Train Acc: 91.14% | Test Loss: 0.2522 | Test Acc: 88.93%
# Epoch 44/500 | Train Loss: 0.2191 | Train Acc: 90.97% | Test Loss: 0.2519 | Test Acc: 88.75%
# Epoch 45/500 | Train Loss: 0.2192 | Train Acc: 90.97% | Test Loss: 0.2528 | Test Acc: 89.10%
# Epoch 46/500 | Train Loss: 0.2185 | Train Acc: 91.14% | Test Loss: 0.2518 | Test Acc: 88.93%
# Epoch 47/500 | Train Loss: 0.2186 | Train Acc: 90.97% | Test Loss: 0.2524 | Test Acc: 89.10%
# Epoch 48/500 | Train Loss: 0.2180 | Train Acc: 90.93% | Test Loss: 0.2513 | Test Acc: 88.58%
# Epoch 49/500 | Train Loss: 0.2179 | Train Acc: 90.84% | Test Loss: 0.2512 | Test Acc: 88.75%
# Epoch 50/500 | Train Loss: 0.2175 | Train Acc: 91.14% | Test Loss: 0.2513 | Test Acc: 88.93%
# Epoch 51/500 | Train Loss: 0.2173 | Train Acc: 90.93% | Test Loss: 0.2510 | Test Acc: 88.58%
# Epoch 52/500 | Train Loss: 0.2173 | Train Acc: 90.79% | Test Loss: 0.2509 | Test Acc: 88.40%
# Epoch 53/500 | Train Loss: 0.2168 | Train Acc: 91.10% | Test Loss: 0.2507 | Test Acc: 88.75%
# Epoch 54/500 | Train Loss: 0.2166 | Train Acc: 91.10% | Test Loss: 0.2507 | Test Acc: 88.75%
# Epoch 55/500 | Train Loss: 0.2164 | Train Acc: 91.14% | Test Loss: 0.2506 | Test Acc: 88.75%
# Epoch 56/500 | Train Loss: 0.2162 | Train Acc: 91.19% | Test Loss: 0.2507 | Test Acc: 88.93%
# Epoch 57/500 | Train Loss: 0.2160 | Train Acc: 91.01% | Test Loss: 0.2507 | Test Acc: 89.28%
# Epoch 58/500 | Train Loss: 0.2158 | Train Acc: 91.23% | Test Loss: 0.2504 | Test Acc: 88.93%
# Epoch 59/500 | Train Loss: 0.2156 | Train Acc: 91.06% | Test Loss: 0.2505 | Test Acc: 89.28%
# Epoch 60/500 | Train Loss: 0.2154 | Train Acc: 91.01% | Test Loss: 0.2504 | Test Acc: 89.10%
# Epoch 61/500 | Train Loss: 0.2177 | Train Acc: 90.79% | Test Loss: 0.2516 | Test Acc: 88.05%
# Epoch 62/500 | Train Loss: 0.2156 | Train Acc: 90.57% | Test Loss: 0.2501 | Test Acc: 88.22%
# Epoch 63/500 | Train Loss: 0.2151 | Train Acc: 90.84% | Test Loss: 0.2499 | Test Acc: 88.22%
# Epoch 64/500 | Train Loss: 0.2147 | Train Acc: 91.01% | Test Loss: 0.2497 | Test Acc: 88.58%
# Epoch 65/500 | Train Loss: 0.2147 | Train Acc: 90.93% | Test Loss: 0.2502 | Test Acc: 88.75%
# Epoch 66/500 | Train Loss: 0.2155 | Train Acc: 90.79% | Test Loss: 0.2515 | Test Acc: 88.75%
# Epoch 67/500 | Train Loss: 0.2153 | Train Acc: 90.57% | Test Loss: 0.2501 | Test Acc: 88.22%
# Epoch 68/500 | Train Loss: 0.2143 | Train Acc: 90.93% | Test Loss: 0.2500 | Test Acc: 88.75%
# Epoch 69/500 | Train Loss: 0.2139 | Train Acc: 91.06% | Test Loss: 0.2493 | Test Acc: 88.58%
# Epoch 70/500 | Train Loss: 0.2153 | Train Acc: 90.88% | Test Loss: 0.2517 | Test Acc: 88.93%
# Epoch 71/500 | Train Loss: 0.2135 | Train Acc: 91.01% | Test Loss: 0.2491 | Test Acc: 88.58%
# Epoch 72/500 | Train Loss: 0.2135 | Train Acc: 90.97% | Test Loss: 0.2490 | Test Acc: 88.40%
# Epoch 73/500 | Train Loss: 0.2136 | Train Acc: 90.84% | Test Loss: 0.2490 | Test Acc: 88.22%
# Epoch 74/500 | Train Loss: 0.2145 | Train Acc: 90.79% | Test Loss: 0.2511 | Test Acc: 88.75%
# Epoch 75/500 | Train Loss: 0.2130 | Train Acc: 91.06% | Test Loss: 0.2488 | Test Acc: 88.58%
# Epoch 76/500 | Train Loss: 0.2128 | Train Acc: 90.97% | Test Loss: 0.2489 | Test Acc: 89.10%
# Epoch 77/500 | Train Loss: 0.2127 | Train Acc: 90.93% | Test Loss: 0.2489 | Test Acc: 88.75%
# Epoch 78/500 | Train Loss: 0.2126 | Train Acc: 91.06% | Test Loss: 0.2486 | Test Acc: 88.40%
# Epoch 79/500 | Train Loss: 0.2126 | Train Acc: 91.01% | Test Loss: 0.2490 | Test Acc: 88.75%
# Epoch 80/500 | Train Loss: 0.2123 | Train Acc: 90.93% | Test Loss: 0.2487 | Test Acc: 88.75%
# Epoch 81/500 | Train Loss: 0.2123 | Train Acc: 91.01% | Test Loss: 0.2488 | Test Acc: 88.93%
# Epoch 82/500 | Train Loss: 0.2141 | Train Acc: 90.84% | Test Loss: 0.2514 | Test Acc: 87.87%
# Epoch 83/500 | Train Loss: 0.2121 | Train Acc: 90.84% | Test Loss: 0.2489 | Test Acc: 88.93%
# Epoch 84/500 | Train Loss: 0.2120 | Train Acc: 91.01% | Test Loss: 0.2481 | Test Acc: 88.58%
# Epoch 85/500 | Train Loss: 0.2118 | Train Acc: 91.01% | Test Loss: 0.2485 | Test Acc: 88.93%
# Epoch 86/500 | Train Loss: 0.2115 | Train Acc: 91.01% | Test Loss: 0.2480 | Test Acc: 88.93%
# Epoch 87/500 | Train Loss: 0.2120 | Train Acc: 90.84% | Test Loss: 0.2492 | Test Acc: 88.93%
# Epoch 88/500 | Train Loss: 0.2118 | Train Acc: 90.79% | Test Loss: 0.2490 | Test Acc: 88.75%
# Epoch 89/500 | Train Loss: 0.2111 | Train Acc: 90.97% | Test Loss: 0.2478 | Test Acc: 88.58%
# Epoch 90/500 | Train Loss: 0.2111 | Train Acc: 90.93% | Test Loss: 0.2476 | Test Acc: 88.75%
# Epoch 91/500 | Train Loss: 0.2109 | Train Acc: 90.93% | Test Loss: 0.2477 | Test Acc: 88.75%
# Epoch 92/500 | Train Loss: 0.2110 | Train Acc: 90.93% | Test Loss: 0.2482 | Test Acc: 88.93%
# Epoch 93/500 | Train Loss: 0.2109 | Train Acc: 91.01% | Test Loss: 0.2474 | Test Acc: 88.58%
# Epoch 94/500 | Train Loss: 0.2143 | Train Acc: 90.44% | Test Loss: 0.2524 | Test Acc: 88.05%
# Epoch 95/500 | Train Loss: 0.2104 | Train Acc: 90.93% | Test Loss: 0.2472 | Test Acc: 88.93%
# Epoch 96/500 | Train Loss: 0.2118 | Train Acc: 90.97% | Test Loss: 0.2495 | Test Acc: 88.40%
# Epoch 97/500 | Train Loss: 0.2105 | Train Acc: 91.01% | Test Loss: 0.2471 | Test Acc: 88.58%
# Epoch 98/500 | Train Loss: 0.2108 | Train Acc: 90.79% | Test Loss: 0.2483 | Test Acc: 89.10%
# Epoch 99/500 | Train Loss: 0.2108 | Train Acc: 90.84% | Test Loss: 0.2484 | Test Acc: 89.10%
# Learning rate reduced to: 0.006018
# Epoch 100/500 | Train Loss: 0.2100 | Train Acc: 90.97% | Test Loss: 0.2468 | Test Acc: 89.10%
# Epoch 101/500 | Train Loss: 0.2098 | Train Acc: 90.97% | Test Loss: 0.2468 | Test Acc: 88.93%
# Epoch 102/500 | Train Loss: 0.2106 | Train Acc: 90.88% | Test Loss: 0.2483 | Test Acc: 88.93%
# Epoch 103/500 | Train Loss: 0.2097 | Train Acc: 90.93% | Test Loss: 0.2466 | Test Acc: 88.93%
# Epoch 104/500 | Train Loss: 0.2096 | Train Acc: 90.97% | Test Loss: 0.2467 | Test Acc: 89.10%
# Epoch 105/500 | Train Loss: 0.2096 | Train Acc: 91.06% | Test Loss: 0.2466 | Test Acc: 89.10%
# Epoch 106/500 | Train Loss: 0.2100 | Train Acc: 90.84% | Test Loss: 0.2476 | Test Acc: 89.10%
# Epoch 107/500 | Train Loss: 0.2095 | Train Acc: 91.01% | Test Loss: 0.2467 | Test Acc: 89.10%
# Epoch 108/500 | Train Loss: 0.2094 | Train Acc: 91.01% | Test Loss: 0.2466 | Test Acc: 89.10%
# Epoch 109/500 | Train Loss: 0.2093 | Train Acc: 90.97% | Test Loss: 0.2464 | Test Acc: 88.93%
# Epoch 110/500 | Train Loss: 0.2094 | Train Acc: 90.88% | Test Loss: 0.2463 | Test Acc: 89.10%
# Epoch 111/500 | Train Loss: 0.2098 | Train Acc: 90.97% | Test Loss: 0.2465 | Test Acc: 88.75%
# Epoch 112/500 | Train Loss: 0.2092 | Train Acc: 90.93% | Test Loss: 0.2462 | Test Acc: 88.93%
# Epoch 113/500 | Train Loss: 0.2093 | Train Acc: 90.88% | Test Loss: 0.2462 | Test Acc: 89.10%
# Epoch 114/500 | Train Loss: 0.2090 | Train Acc: 91.01% | Test Loss: 0.2462 | Test Acc: 89.10%
# Epoch 115/500 | Train Loss: 0.2089 | Train Acc: 90.93% | Test Loss: 0.2463 | Test Acc: 89.10%
# Epoch 116/500 | Train Loss: 0.2089 | Train Acc: 90.93% | Test Loss: 0.2460 | Test Acc: 89.10%
# Epoch 117/500 | Train Loss: 0.2088 | Train Acc: 90.93% | Test Loss: 0.2459 | Test Acc: 88.93%
# Epoch 118/500 | Train Loss: 0.2088 | Train Acc: 90.93% | Test Loss: 0.2462 | Test Acc: 88.93%
# Epoch 119/500 | Train Loss: 0.2093 | Train Acc: 90.88% | Test Loss: 0.2470 | Test Acc: 88.93%
# Epoch 120/500 | Train Loss: 0.2086 | Train Acc: 91.01% | Test Loss: 0.2458 | Test Acc: 89.10%
# Epoch 121/500 | Train Loss: 0.2085 | Train Acc: 90.97% | Test Loss: 0.2459 | Test Acc: 89.10%
# Epoch 122/500 | Train Loss: 0.2087 | Train Acc: 90.93% | Test Loss: 0.2464 | Test Acc: 89.10%
# Epoch 123/500 | Train Loss: 0.2088 | Train Acc: 90.84% | Test Loss: 0.2466 | Test Acc: 89.10%
# Epoch 124/500 | Train Loss: 0.2091 | Train Acc: 90.97% | Test Loss: 0.2459 | Test Acc: 88.75%
# Epoch 125/500 | Train Loss: 0.2083 | Train Acc: 91.06% | Test Loss: 0.2456 | Test Acc: 89.10%
# Epoch 126/500 | Train Loss: 0.2089 | Train Acc: 90.97% | Test Loss: 0.2468 | Test Acc: 88.75%
# Epoch 127/500 | Train Loss: 0.2082 | Train Acc: 91.06% | Test Loss: 0.2454 | Test Acc: 89.10%
# Epoch 128/500 | Train Loss: 0.2081 | Train Acc: 91.06% | Test Loss: 0.2454 | Test Acc: 89.10%
# Epoch 129/500 | Train Loss: 0.2081 | Train Acc: 91.01% | Test Loss: 0.2453 | Test Acc: 89.10%
# Epoch 130/500 | Train Loss: 0.2084 | Train Acc: 90.97% | Test Loss: 0.2453 | Test Acc: 88.93%
# Epoch 131/500 | Train Loss: 0.2085 | Train Acc: 91.10% | Test Loss: 0.2454 | Test Acc: 88.75%
# Epoch 132/500 | Train Loss: 0.2088 | Train Acc: 90.88% | Test Loss: 0.2456 | Test Acc: 88.75%
# Epoch 133/500 | Train Loss: 0.2078 | Train Acc: 91.06% | Test Loss: 0.2451 | Test Acc: 89.10%
# Epoch 134/500 | Train Loss: 0.2078 | Train Acc: 91.06% | Test Loss: 0.2450 | Test Acc: 89.10%
# Epoch 135/500 | Train Loss: 0.2076 | Train Acc: 91.06% | Test Loss: 0.2451 | Test Acc: 89.10%
# Epoch 136/500 | Train Loss: 0.2076 | Train Acc: 90.97% | Test Loss: 0.2451 | Test Acc: 88.93%
# Epoch 137/500 | Train Loss: 0.2085 | Train Acc: 91.10% | Test Loss: 0.2467 | Test Acc: 88.22%
# Epoch 138/500 | Train Loss: 0.2075 | Train Acc: 90.97% | Test Loss: 0.2449 | Test Acc: 89.28%
# Epoch 139/500 | Train Loss: 0.2076 | Train Acc: 90.93% | Test Loss: 0.2455 | Test Acc: 89.10%
# Epoch 140/500 | Train Loss: 0.2075 | Train Acc: 90.97% | Test Loss: 0.2447 | Test Acc: 88.93%
# Epoch 141/500 | Train Loss: 0.2072 | Train Acc: 91.01% | Test Loss: 0.2447 | Test Acc: 89.10%
# Epoch 142/500 | Train Loss: 0.2073 | Train Acc: 90.93% | Test Loss: 0.2449 | Test Acc: 88.93%
# Epoch 143/500 | Train Loss: 0.2071 | Train Acc: 91.06% | Test Loss: 0.2446 | Test Acc: 89.10%
# Epoch 144/500 | Train Loss: 0.2079 | Train Acc: 91.10% | Test Loss: 0.2448 | Test Acc: 88.93%
# Epoch 145/500 | Train Loss: 0.2070 | Train Acc: 91.06% | Test Loss: 0.2445 | Test Acc: 88.93%
# Epoch 146/500 | Train Loss: 0.2069 | Train Acc: 91.01% | Test Loss: 0.2444 | Test Acc: 89.10%
# Epoch 147/500 | Train Loss: 0.2071 | Train Acc: 90.88% | Test Loss: 0.2450 | Test Acc: 89.10%
# Epoch 148/500 | Train Loss: 0.2069 | Train Acc: 90.97% | Test Loss: 0.2441 | Test Acc: 89.10%
# Epoch 149/500 | Train Loss: 0.2068 | Train Acc: 90.97% | Test Loss: 0.2444 | Test Acc: 88.93%
# Epoch 150/500 | Train Loss: 0.2067 | Train Acc: 91.01% | Test Loss: 0.2441 | Test Acc: 88.93%
# Epoch 151/500 | Train Loss: 0.2066 | Train Acc: 91.01% | Test Loss: 0.2440 | Test Acc: 88.93%
# Epoch 152/500 | Train Loss: 0.2071 | Train Acc: 91.06% | Test Loss: 0.2441 | Test Acc: 89.10%
# Epoch 153/500 | Train Loss: 0.2065 | Train Acc: 90.97% | Test Loss: 0.2441 | Test Acc: 88.93%
# Epoch 154/500 | Train Loss: 0.2066 | Train Acc: 90.88% | Test Loss: 0.2444 | Test Acc: 89.10%
# Epoch 155/500 | Train Loss: 0.2066 | Train Acc: 90.93% | Test Loss: 0.2437 | Test Acc: 88.93%
# Epoch 156/500 | Train Loss: 0.2063 | Train Acc: 91.01% | Test Loss: 0.2436 | Test Acc: 89.10%
# Epoch 157/500 | Train Loss: 0.2062 | Train Acc: 90.97% | Test Loss: 0.2437 | Test Acc: 88.93%
# Epoch 158/500 | Train Loss: 0.2061 | Train Acc: 90.93% | Test Loss: 0.2436 | Test Acc: 88.93%
# Epoch 159/500 | Train Loss: 0.2062 | Train Acc: 90.97% | Test Loss: 0.2434 | Test Acc: 89.28%
# Epoch 160/500 | Train Loss: 0.2060 | Train Acc: 91.06% | Test Loss: 0.2433 | Test Acc: 89.10%
# Epoch 161/500 | Train Loss: 0.2059 | Train Acc: 91.06% | Test Loss: 0.2433 | Test Acc: 88.93%
# Epoch 162/500 | Train Loss: 0.2060 | Train Acc: 90.97% | Test Loss: 0.2432 | Test Acc: 89.28%
# Epoch 163/500 | Train Loss: 0.2058 | Train Acc: 90.93% | Test Loss: 0.2434 | Test Acc: 89.10%
# Epoch 164/500 | Train Loss: 0.2064 | Train Acc: 91.14% | Test Loss: 0.2433 | Test Acc: 89.28%
# Epoch 165/500 | Train Loss: 0.2058 | Train Acc: 91.06% | Test Loss: 0.2434 | Test Acc: 89.10%
# Epoch 166/500 | Train Loss: 0.2057 | Train Acc: 91.06% | Test Loss: 0.2434 | Test Acc: 89.10%
# Epoch 167/500 | Train Loss: 0.2055 | Train Acc: 91.01% | Test Loss: 0.2430 | Test Acc: 88.93%
# Epoch 168/500 | Train Loss: 0.2055 | Train Acc: 91.06% | Test Loss: 0.2429 | Test Acc: 89.10%
# Epoch 169/500 | Train Loss: 0.2054 | Train Acc: 91.06% | Test Loss: 0.2428 | Test Acc: 89.10%
# Epoch 170/500 | Train Loss: 0.2054 | Train Acc: 90.97% | Test Loss: 0.2429 | Test Acc: 89.10%
# Epoch 171/500 | Train Loss: 0.2062 | Train Acc: 91.28% | Test Loss: 0.2430 | Test Acc: 89.10%
# Epoch 172/500 | Train Loss: 0.2052 | Train Acc: 90.97% | Test Loss: 0.2428 | Test Acc: 89.10%
# Epoch 173/500 | Train Loss: 0.2053 | Train Acc: 91.10% | Test Loss: 0.2425 | Test Acc: 89.28%
# Epoch 174/500 | Train Loss: 0.2051 | Train Acc: 91.01% | Test Loss: 0.2426 | Test Acc: 88.93%
# Epoch 175/500 | Train Loss: 0.2053 | Train Acc: 91.10% | Test Loss: 0.2424 | Test Acc: 89.10%
# Epoch 176/500 | Train Loss: 0.2049 | Train Acc: 90.97% | Test Loss: 0.2424 | Test Acc: 88.93%
# Epoch 177/500 | Train Loss: 0.2050 | Train Acc: 91.14% | Test Loss: 0.2423 | Test Acc: 89.28%
# Epoch 178/500 | Train Loss: 0.2049 | Train Acc: 91.14% | Test Loss: 0.2422 | Test Acc: 89.28%
# Epoch 179/500 | Train Loss: 0.2048 | Train Acc: 91.01% | Test Loss: 0.2424 | Test Acc: 89.10%
# Epoch 180/500 | Train Loss: 0.2047 | Train Acc: 91.01% | Test Loss: 0.2423 | Test Acc: 89.10%
# Epoch 181/500 | Train Loss: 0.2046 | Train Acc: 91.06% | Test Loss: 0.2423 | Test Acc: 89.10%
# Epoch 182/500 | Train Loss: 0.2045 | Train Acc: 91.01% | Test Loss: 0.2422 | Test Acc: 89.10%
# Epoch 183/500 | Train Loss: 0.2048 | Train Acc: 91.23% | Test Loss: 0.2420 | Test Acc: 89.28%
# Epoch 184/500 | Train Loss: 0.2044 | Train Acc: 90.97% | Test Loss: 0.2420 | Test Acc: 89.10%
# Epoch 185/500 | Train Loss: 0.2047 | Train Acc: 91.19% | Test Loss: 0.2419 | Test Acc: 89.28%
# Epoch 186/500 | Train Loss: 0.2050 | Train Acc: 91.28% | Test Loss: 0.2421 | Test Acc: 89.10%
# Epoch 187/500 | Train Loss: 0.2047 | Train Acc: 91.19% | Test Loss: 0.2428 | Test Acc: 88.58%
# Epoch 188/500 | Train Loss: 0.2044 | Train Acc: 91.28% | Test Loss: 0.2424 | Test Acc: 88.58%
# Epoch 189/500 | Train Loss: 0.2048 | Train Acc: 91.14% | Test Loss: 0.2430 | Test Acc: 88.22%
# Epoch 190/500 | Train Loss: 0.2040 | Train Acc: 91.14% | Test Loss: 0.2416 | Test Acc: 89.10%
# Epoch 191/500 | Train Loss: 0.2040 | Train Acc: 91.23% | Test Loss: 0.2414 | Test Acc: 89.10%
# Epoch 192/500 | Train Loss: 0.2039 | Train Acc: 91.14% | Test Loss: 0.2414 | Test Acc: 89.10%
# Epoch 193/500 | Train Loss: 0.2045 | Train Acc: 91.28% | Test Loss: 0.2416 | Test Acc: 89.10%
# Epoch 194/500 | Train Loss: 0.2037 | Train Acc: 91.14% | Test Loss: 0.2413 | Test Acc: 89.28%
# Epoch 195/500 | Train Loss: 0.2047 | Train Acc: 90.97% | Test Loss: 0.2428 | Test Acc: 88.22%
# Epoch 196/500 | Train Loss: 0.2038 | Train Acc: 91.19% | Test Loss: 0.2415 | Test Acc: 88.75%
# Epoch 197/500 | Train Loss: 0.2035 | Train Acc: 91.28% | Test Loss: 0.2409 | Test Acc: 89.10%
# Epoch 198/500 | Train Loss: 0.2035 | Train Acc: 91.28% | Test Loss: 0.2408 | Test Acc: 89.10%
# Epoch 199/500 | Train Loss: 0.2034 | Train Acc: 91.28% | Test Loss: 0.2407 | Test Acc: 89.10%
# Learning rate reduced to: 0.003603
# Epoch 200/500 | Train Loss: 0.2034 | Train Acc: 91.19% | Test Loss: 0.2407 | Test Acc: 89.10%
# Epoch 201/500 | Train Loss: 0.2033 | Train Acc: 91.23% | Test Loss: 0.2407 | Test Acc: 89.10%
# Epoch 202/500 | Train Loss: 0.2038 | Train Acc: 91.36% | Test Loss: 0.2408 | Test Acc: 89.10%
# Epoch 203/500 | Train Loss: 0.2033 | Train Acc: 91.32% | Test Loss: 0.2405 | Test Acc: 89.10%
# Epoch 204/500 | Train Loss: 0.2033 | Train Acc: 91.32% | Test Loss: 0.2408 | Test Acc: 89.10%
# Epoch 205/500 | Train Loss: 0.2032 | Train Acc: 91.32% | Test Loss: 0.2405 | Test Acc: 89.10%
# Epoch 206/500 | Train Loss: 0.2031 | Train Acc: 91.23% | Test Loss: 0.2405 | Test Acc: 89.28%
# Epoch 207/500 | Train Loss: 0.2031 | Train Acc: 91.28% | Test Loss: 0.2405 | Test Acc: 89.28%
# Epoch 208/500 | Train Loss: 0.2031 | Train Acc: 91.36% | Test Loss: 0.2406 | Test Acc: 89.10%
# Epoch 209/500 | Train Loss: 0.2030 | Train Acc: 91.32% | Test Loss: 0.2403 | Test Acc: 89.10%
# Epoch 210/500 | Train Loss: 0.2033 | Train Acc: 91.41% | Test Loss: 0.2403 | Test Acc: 89.28%
# Epoch 211/500 | Train Loss: 0.2030 | Train Acc: 91.32% | Test Loss: 0.2402 | Test Acc: 89.10%
# Epoch 212/500 | Train Loss: 0.2030 | Train Acc: 91.36% | Test Loss: 0.2405 | Test Acc: 88.75%
# Epoch 213/500 | Train Loss: 0.2030 | Train Acc: 91.45% | Test Loss: 0.2401 | Test Acc: 89.10%
# Epoch 214/500 | Train Loss: 0.2028 | Train Acc: 91.36% | Test Loss: 0.2403 | Test Acc: 89.10%
# Epoch 215/500 | Train Loss: 0.2028 | Train Acc: 91.28% | Test Loss: 0.2401 | Test Acc: 89.10%
# Epoch 216/500 | Train Loss: 0.2029 | Train Acc: 91.45% | Test Loss: 0.2400 | Test Acc: 89.46%
# Epoch 217/500 | Train Loss: 0.2027 | Train Acc: 91.28% | Test Loss: 0.2400 | Test Acc: 89.10%
# Epoch 218/500 | Train Loss: 0.2026 | Train Acc: 91.28% | Test Loss: 0.2399 | Test Acc: 89.10%
# Epoch 219/500 | Train Loss: 0.2027 | Train Acc: 91.41% | Test Loss: 0.2403 | Test Acc: 88.58%
# Epoch 220/500 | Train Loss: 0.2026 | Train Acc: 91.23% | Test Loss: 0.2398 | Test Acc: 89.10%
# Epoch 221/500 | Train Loss: 0.2025 | Train Acc: 91.28% | Test Loss: 0.2397 | Test Acc: 89.10%
# Epoch 222/500 | Train Loss: 0.2025 | Train Acc: 91.36% | Test Loss: 0.2397 | Test Acc: 89.10%
# Epoch 223/500 | Train Loss: 0.2025 | Train Acc: 91.45% | Test Loss: 0.2401 | Test Acc: 88.58%
# Epoch 224/500 | Train Loss: 0.2024 | Train Acc: 91.32% | Test Loss: 0.2398 | Test Acc: 89.28%
# Epoch 225/500 | Train Loss: 0.2024 | Train Acc: 91.32% | Test Loss: 0.2398 | Test Acc: 89.28%
# Epoch 226/500 | Train Loss: 0.2023 | Train Acc: 91.32% | Test Loss: 0.2397 | Test Acc: 89.28%
# Epoch 227/500 | Train Loss: 0.2023 | Train Acc: 91.32% | Test Loss: 0.2396 | Test Acc: 89.28%
# Epoch 228/500 | Train Loss: 0.2022 | Train Acc: 91.32% | Test Loss: 0.2394 | Test Acc: 89.10%
# Epoch 229/500 | Train Loss: 0.2023 | Train Acc: 91.45% | Test Loss: 0.2397 | Test Acc: 88.75%
# Epoch 230/500 | Train Loss: 0.2021 | Train Acc: 91.32% | Test Loss: 0.2394 | Test Acc: 89.28%
# Epoch 231/500 | Train Loss: 0.2021 | Train Acc: 91.32% | Test Loss: 0.2394 | Test Acc: 89.28%
# Epoch 232/500 | Train Loss: 0.2022 | Train Acc: 91.54% | Test Loss: 0.2392 | Test Acc: 89.46%
# Epoch 233/500 | Train Loss: 0.2020 | Train Acc: 91.54% | Test Loss: 0.2391 | Test Acc: 89.10%
# Epoch 234/500 | Train Loss: 0.2020 | Train Acc: 91.54% | Test Loss: 0.2391 | Test Acc: 89.10%
# Epoch 235/500 | Train Loss: 0.2019 | Train Acc: 91.32% | Test Loss: 0.2391 | Test Acc: 89.10%
# Epoch 236/500 | Train Loss: 0.2019 | Train Acc: 91.32% | Test Loss: 0.2391 | Test Acc: 89.10%
# Epoch 237/500 | Train Loss: 0.2019 | Train Acc: 91.45% | Test Loss: 0.2392 | Test Acc: 88.93%
# Epoch 238/500 | Train Loss: 0.2019 | Train Acc: 91.45% | Test Loss: 0.2392 | Test Acc: 88.93%
# Epoch 239/500 | Train Loss: 0.2018 | Train Acc: 91.32% | Test Loss: 0.2390 | Test Acc: 89.28%
# Epoch 240/500 | Train Loss: 0.2019 | Train Acc: 91.58% | Test Loss: 0.2387 | Test Acc: 89.28%
# Epoch 241/500 | Train Loss: 0.2019 | Train Acc: 91.58% | Test Loss: 0.2387 | Test Acc: 89.28%
# Epoch 242/500 | Train Loss: 0.2017 | Train Acc: 91.45% | Test Loss: 0.2390 | Test Acc: 88.93%
# Epoch 243/500 | Train Loss: 0.2017 | Train Acc: 91.45% | Test Loss: 0.2389 | Test Acc: 88.93%
# Epoch 244/500 | Train Loss: 0.2027 | Train Acc: 91.14% | Test Loss: 0.2405 | Test Acc: 88.40%
# Epoch 245/500 | Train Loss: 0.2017 | Train Acc: 91.49% | Test Loss: 0.2391 | Test Acc: 88.75%
# Epoch 246/500 | Train Loss: 0.2015 | Train Acc: 91.41% | Test Loss: 0.2388 | Test Acc: 89.10%
# Epoch 247/500 | Train Loss: 0.2014 | Train Acc: 91.45% | Test Loss: 0.2385 | Test Acc: 89.46%
# Epoch 248/500 | Train Loss: 0.2014 | Train Acc: 91.49% | Test Loss: 0.2385 | Test Acc: 89.46%
# Epoch 249/500 | Train Loss: 0.2016 | Train Acc: 91.58% | Test Loss: 0.2385 | Test Acc: 89.28%
# Epoch 250/500 | Train Loss: 0.2013 | Train Acc: 91.45% | Test Loss: 0.2385 | Test Acc: 89.46%
# Epoch 251/500 | Train Loss: 0.2015 | Train Acc: 91.63% | Test Loss: 0.2383 | Test Acc: 89.10%
# Epoch 252/500 | Train Loss: 0.2026 | Train Acc: 91.14% | Test Loss: 0.2404 | Test Acc: 88.40%
# Epoch 253/500 | Train Loss: 0.2014 | Train Acc: 91.45% | Test Loss: 0.2388 | Test Acc: 88.75%
# Epoch 254/500 | Train Loss: 0.2011 | Train Acc: 91.45% | Test Loss: 0.2382 | Test Acc: 89.46%
# Epoch 255/500 | Train Loss: 0.2013 | Train Acc: 91.45% | Test Loss: 0.2387 | Test Acc: 88.75%
# Epoch 256/500 | Train Loss: 0.2011 | Train Acc: 91.54% | Test Loss: 0.2381 | Test Acc: 89.28%
# Epoch 257/500 | Train Loss: 0.2011 | Train Acc: 91.58% | Test Loss: 0.2380 | Test Acc: 89.28%
# Epoch 258/500 | Train Loss: 0.2011 | Train Acc: 91.67% | Test Loss: 0.2379 | Test Acc: 89.28%
# Epoch 259/500 | Train Loss: 0.2010 | Train Acc: 91.58% | Test Loss: 0.2379 | Test Acc: 89.28%
# Epoch 260/500 | Train Loss: 0.2009 | Train Acc: 91.54% | Test Loss: 0.2379 | Test Acc: 89.46%
# Epoch 261/500 | Train Loss: 0.2009 | Train Acc: 91.45% | Test Loss: 0.2381 | Test Acc: 89.10%
# Epoch 262/500 | Train Loss: 0.2009 | Train Acc: 91.63% | Test Loss: 0.2378 | Test Acc: 89.10%
# Epoch 263/500 | Train Loss: 0.2008 | Train Acc: 91.58% | Test Loss: 0.2378 | Test Acc: 89.46%
# Epoch 264/500 | Train Loss: 0.2008 | Train Acc: 91.45% | Test Loss: 0.2380 | Test Acc: 89.10%
# Epoch 265/500 | Train Loss: 0.2011 | Train Acc: 91.36% | Test Loss: 0.2385 | Test Acc: 88.75%
# Epoch 266/500 | Train Loss: 0.2006 | Train Acc: 91.58% | Test Loss: 0.2377 | Test Acc: 89.28%
# Epoch 267/500 | Train Loss: 0.2007 | Train Acc: 91.63% | Test Loss: 0.2376 | Test Acc: 89.10%
# Epoch 268/500 | Train Loss: 0.2009 | Train Acc: 91.41% | Test Loss: 0.2382 | Test Acc: 88.75%
# Epoch 269/500 | Train Loss: 0.2007 | Train Acc: 91.71% | Test Loss: 0.2373 | Test Acc: 89.46%
# Epoch 270/500 | Train Loss: 0.2008 | Train Acc: 91.41% | Test Loss: 0.2381 | Test Acc: 88.75%
# Epoch 271/500 | Train Loss: 0.2006 | Train Acc: 91.45% | Test Loss: 0.2377 | Test Acc: 88.93%
# Epoch 272/500 | Train Loss: 0.2007 | Train Acc: 91.45% | Test Loss: 0.2380 | Test Acc: 88.75%
# Epoch 273/500 | Train Loss: 0.2005 | Train Acc: 91.49% | Test Loss: 0.2378 | Test Acc: 88.93%
# Epoch 274/500 | Train Loss: 0.2019 | Train Acc: 91.32% | Test Loss: 0.2396 | Test Acc: 88.58%
# Epoch 275/500 | Train Loss: 0.2003 | Train Acc: 91.67% | Test Loss: 0.2371 | Test Acc: 89.10%
# Epoch 276/500 | Train Loss: 0.2003 | Train Acc: 91.41% | Test Loss: 0.2375 | Test Acc: 89.10%
# Epoch 277/500 | Train Loss: 0.2002 | Train Acc: 91.58% | Test Loss: 0.2372 | Test Acc: 89.46%
# Epoch 278/500 | Train Loss: 0.2007 | Train Acc: 91.45% | Test Loss: 0.2382 | Test Acc: 88.75%
# Epoch 279/500 | Train Loss: 0.2001 | Train Acc: 91.58% | Test Loss: 0.2370 | Test Acc: 89.46%
# Epoch 280/500 | Train Loss: 0.2001 | Train Acc: 91.58% | Test Loss: 0.2369 | Test Acc: 89.46%
# Epoch 281/500 | Train Loss: 0.2003 | Train Acc: 91.71% | Test Loss: 0.2369 | Test Acc: 89.46%
# Epoch 282/500 | Train Loss: 0.2002 | Train Acc: 91.76% | Test Loss: 0.2368 | Test Acc: 89.46%
# Epoch 283/500 | Train Loss: 0.2002 | Train Acc: 91.76% | Test Loss: 0.2367 | Test Acc: 89.46%
# Epoch 284/500 | Train Loss: 0.1999 | Train Acc: 91.58% | Test Loss: 0.2368 | Test Acc: 89.46%
# Epoch 285/500 | Train Loss: 0.2002 | Train Acc: 91.54% | Test Loss: 0.2374 | Test Acc: 88.75%
# Epoch 286/500 | Train Loss: 0.1998 | Train Acc: 91.54% | Test Loss: 0.2367 | Test Acc: 89.46%
# Epoch 287/500 | Train Loss: 0.2000 | Train Acc: 91.80% | Test Loss: 0.2366 | Test Acc: 89.63%
# Epoch 288/500 | Train Loss: 0.1997 | Train Acc: 91.71% | Test Loss: 0.2366 | Test Acc: 89.28%
# Epoch 289/500 | Train Loss: 0.1998 | Train Acc: 91.54% | Test Loss: 0.2368 | Test Acc: 88.93%
# Epoch 290/500 | Train Loss: 0.1997 | Train Acc: 91.71% | Test Loss: 0.2363 | Test Acc: 89.46%
# Epoch 291/500 | Train Loss: 0.1996 | Train Acc: 91.71% | Test Loss: 0.2364 | Test Acc: 89.10%
# Epoch 292/500 | Train Loss: 0.1996 | Train Acc: 91.71% | Test Loss: 0.2364 | Test Acc: 89.10%
# Epoch 293/500 | Train Loss: 0.1995 | Train Acc: 91.71% | Test Loss: 0.2364 | Test Acc: 89.10%
# Epoch 294/500 | Train Loss: 0.1995 | Train Acc: 91.63% | Test Loss: 0.2365 | Test Acc: 89.28%
# Epoch 295/500 | Train Loss: 0.1995 | Train Acc: 91.76% | Test Loss: 0.2361 | Test Acc: 89.46%
# Epoch 296/500 | Train Loss: 0.1994 | Train Acc: 91.71% | Test Loss: 0.2362 | Test Acc: 89.46%
# Epoch 297/500 | Train Loss: 0.1994 | Train Acc: 91.67% | Test Loss: 0.2361 | Test Acc: 89.81%
# Epoch 298/500 | Train Loss: 0.1993 | Train Acc: 91.63% | Test Loss: 0.2361 | Test Acc: 89.46%
# Epoch 299/500 | Train Loss: 0.1993 | Train Acc: 91.63% | Test Loss: 0.2360 | Test Acc: 89.46%
# Learning rate reduced to: 0.002157
# Epoch 300/500 | Train Loss: 0.1992 | Train Acc: 91.63% | Test Loss: 0.2360 | Test Acc: 89.46%
# Epoch 301/500 | Train Loss: 0.1992 | Train Acc: 91.67% | Test Loss: 0.2359 | Test Acc: 89.81%
# Epoch 302/500 | Train Loss: 0.1992 | Train Acc: 91.71% | Test Loss: 0.2358 | Test Acc: 89.81%
# Epoch 303/500 | Train Loss: 0.1992 | Train Acc: 91.71% | Test Loss: 0.2358 | Test Acc: 89.46%
# Epoch 304/500 | Train Loss: 0.1991 | Train Acc: 91.71% | Test Loss: 0.2358 | Test Acc: 89.46%
# Epoch 305/500 | Train Loss: 0.1992 | Train Acc: 91.67% | Test Loss: 0.2358 | Test Acc: 89.81%
# Epoch 306/500 | Train Loss: 0.1991 | Train Acc: 91.67% | Test Loss: 0.2357 | Test Acc: 89.81%
# Epoch 307/500 | Train Loss: 0.1991 | Train Acc: 91.67% | Test Loss: 0.2357 | Test Acc: 89.81%
# Epoch 308/500 | Train Loss: 0.1991 | Train Acc: 91.67% | Test Loss: 0.2357 | Test Acc: 89.81%
# Epoch 309/500 | Train Loss: 0.1990 | Train Acc: 91.71% | Test Loss: 0.2357 | Test Acc: 89.81%
# Epoch 310/500 | Train Loss: 0.1990 | Train Acc: 91.63% | Test Loss: 0.2357 | Test Acc: 89.46%
# Epoch 311/500 | Train Loss: 0.1990 | Train Acc: 91.71% | Test Loss: 0.2356 | Test Acc: 89.63%
# Epoch 312/500 | Train Loss: 0.1990 | Train Acc: 91.76% | Test Loss: 0.2357 | Test Acc: 89.10%
# Epoch 313/500 | Train Loss: 0.1990 | Train Acc: 91.71% | Test Loss: 0.2355 | Test Acc: 89.46%
# Epoch 314/500 | Train Loss: 0.1989 | Train Acc: 91.71% | Test Loss: 0.2355 | Test Acc: 89.81%
# Epoch 315/500 | Train Loss: 0.1989 | Train Acc: 91.76% | Test Loss: 0.2357 | Test Acc: 89.28%
# Epoch 316/500 | Train Loss: 0.1989 | Train Acc: 91.71% | Test Loss: 0.2355 | Test Acc: 89.46%
# Epoch 317/500 | Train Loss: 0.1989 | Train Acc: 91.71% | Test Loss: 0.2354 | Test Acc: 89.63%
# Epoch 318/500 | Train Loss: 0.1988 | Train Acc: 91.76% | Test Loss: 0.2356 | Test Acc: 89.28%
# Epoch 319/500 | Train Loss: 0.1988 | Train Acc: 91.71% | Test Loss: 0.2354 | Test Acc: 89.46%
# Epoch 320/500 | Train Loss: 0.1988 | Train Acc: 91.71% | Test Loss: 0.2353 | Test Acc: 89.63%
# Epoch 321/500 | Train Loss: 0.1988 | Train Acc: 91.76% | Test Loss: 0.2355 | Test Acc: 89.28%
# Epoch 322/500 | Train Loss: 0.1988 | Train Acc: 91.76% | Test Loss: 0.2355 | Test Acc: 89.28%
# Epoch 323/500 | Train Loss: 0.1988 | Train Acc: 91.76% | Test Loss: 0.2356 | Test Acc: 88.93%
# Epoch 324/500 | Train Loss: 0.1988 | Train Acc: 91.80% | Test Loss: 0.2355 | Test Acc: 89.10%
# Epoch 325/500 | Train Loss: 0.1988 | Train Acc: 91.80% | Test Loss: 0.2352 | Test Acc: 89.46%
# Epoch 326/500 | Train Loss: 0.1986 | Train Acc: 91.71% | Test Loss: 0.2352 | Test Acc: 89.81%
# Epoch 327/500 | Train Loss: 0.1986 | Train Acc: 91.67% | Test Loss: 0.2351 | Test Acc: 89.81%
# Epoch 328/500 | Train Loss: 0.1986 | Train Acc: 91.76% | Test Loss: 0.2352 | Test Acc: 89.63%
# Epoch 329/500 | Train Loss: 0.1986 | Train Acc: 91.76% | Test Loss: 0.2352 | Test Acc: 89.46%
# Epoch 330/500 | Train Loss: 0.1986 | Train Acc: 91.71% | Test Loss: 0.2351 | Test Acc: 89.81%
# Epoch 331/500 | Train Loss: 0.1985 | Train Acc: 91.76% | Test Loss: 0.2351 | Test Acc: 89.28%
# Epoch 332/500 | Train Loss: 0.1985 | Train Acc: 91.76% | Test Loss: 0.2351 | Test Acc: 89.81%
# Epoch 333/500 | Train Loss: 0.1985 | Train Acc: 91.71% | Test Loss: 0.2350 | Test Acc: 89.81%
# Epoch 334/500 | Train Loss: 0.1985 | Train Acc: 91.76% | Test Loss: 0.2351 | Test Acc: 89.28%
# Epoch 335/500 | Train Loss: 0.1985 | Train Acc: 91.76% | Test Loss: 0.2353 | Test Acc: 88.93%
# Epoch 336/500 | Train Loss: 0.1984 | Train Acc: 91.67% | Test Loss: 0.2349 | Test Acc: 89.81%
# Epoch 337/500 | Train Loss: 0.1984 | Train Acc: 91.67% | Test Loss: 0.2349 | Test Acc: 89.81%
# Epoch 338/500 | Train Loss: 0.1984 | Train Acc: 91.76% | Test Loss: 0.2349 | Test Acc: 89.81%
# Epoch 339/500 | Train Loss: 0.1984 | Train Acc: 91.67% | Test Loss: 0.2348 | Test Acc: 89.81%
# Epoch 340/500 | Train Loss: 0.1983 | Train Acc: 91.76% | Test Loss: 0.2350 | Test Acc: 89.46%
# Epoch 341/500 | Train Loss: 0.1983 | Train Acc: 91.71% | Test Loss: 0.2348 | Test Acc: 89.81%
# Epoch 342/500 | Train Loss: 0.1983 | Train Acc: 91.76% | Test Loss: 0.2348 | Test Acc: 89.81%
# Epoch 343/500 | Train Loss: 0.1983 | Train Acc: 91.80% | Test Loss: 0.2348 | Test Acc: 89.81%
# Epoch 344/500 | Train Loss: 0.1982 | Train Acc: 91.80% | Test Loss: 0.2348 | Test Acc: 89.63%
# Epoch 345/500 | Train Loss: 0.1982 | Train Acc: 91.76% | Test Loss: 0.2347 | Test Acc: 89.81%
# Epoch 346/500 | Train Loss: 0.1983 | Train Acc: 91.85% | Test Loss: 0.2346 | Test Acc: 89.46%
# Epoch 347/500 | Train Loss: 0.1982 | Train Acc: 91.80% | Test Loss: 0.2346 | Test Acc: 89.81%
# Epoch 348/500 | Train Loss: 0.1982 | Train Acc: 91.76% | Test Loss: 0.2346 | Test Acc: 89.81%
# Epoch 349/500 | Train Loss: 0.1981 | Train Acc: 91.76% | Test Loss: 0.2346 | Test Acc: 89.81%
# Epoch 350/500 | Train Loss: 0.1981 | Train Acc: 91.76% | Test Loss: 0.2347 | Test Acc: 89.46%
# Epoch 351/500 | Train Loss: 0.1981 | Train Acc: 91.85% | Test Loss: 0.2347 | Test Acc: 89.28%
# Epoch 352/500 | Train Loss: 0.1980 | Train Acc: 91.80% | Test Loss: 0.2345 | Test Acc: 89.46%
# Epoch 353/500 | Train Loss: 0.1981 | Train Acc: 91.85% | Test Loss: 0.2347 | Test Acc: 89.10%
# Epoch 354/500 | Train Loss: 0.1980 | Train Acc: 91.71% | Test Loss: 0.2344 | Test Acc: 89.81%
# Epoch 355/500 | Train Loss: 0.1980 | Train Acc: 91.80% | Test Loss: 0.2345 | Test Acc: 89.63%
# Epoch 356/500 | Train Loss: 0.1980 | Train Acc: 91.80% | Test Loss: 0.2344 | Test Acc: 89.81%
# Epoch 357/500 | Train Loss: 0.1979 | Train Acc: 91.80% | Test Loss: 0.2344 | Test Acc: 89.46%
# Epoch 358/500 | Train Loss: 0.1979 | Train Acc: 91.80% | Test Loss: 0.2345 | Test Acc: 89.28%
# Epoch 359/500 | Train Loss: 0.1979 | Train Acc: 91.80% | Test Loss: 0.2344 | Test Acc: 89.46%
# Epoch 360/500 | Train Loss: 0.1979 | Train Acc: 91.80% | Test Loss: 0.2343 | Test Acc: 89.63%
# Epoch 361/500 | Train Loss: 0.1980 | Train Acc: 91.85% | Test Loss: 0.2342 | Test Acc: 89.46%
# Epoch 362/500 | Train Loss: 0.1978 | Train Acc: 91.85% | Test Loss: 0.2343 | Test Acc: 89.28%
# Epoch 363/500 | Train Loss: 0.1978 | Train Acc: 91.80% | Test Loss: 0.2342 | Test Acc: 89.46%
# Epoch 364/500 | Train Loss: 0.1978 | Train Acc: 91.85% | Test Loss: 0.2344 | Test Acc: 89.28%
# Epoch 365/500 | Train Loss: 0.1978 | Train Acc: 91.76% | Test Loss: 0.2341 | Test Acc: 89.63%
# Epoch 366/500 | Train Loss: 0.1977 | Train Acc: 91.80% | Test Loss: 0.2341 | Test Acc: 89.63%
# Epoch 367/500 | Train Loss: 0.1977 | Train Acc: 91.80% | Test Loss: 0.2341 | Test Acc: 89.63%
# Epoch 368/500 | Train Loss: 0.1977 | Train Acc: 91.76% | Test Loss: 0.2340 | Test Acc: 89.63%
# Epoch 369/500 | Train Loss: 0.1978 | Train Acc: 91.80% | Test Loss: 0.2340 | Test Acc: 89.46%
# Epoch 370/500 | Train Loss: 0.1976 | Train Acc: 91.76% | Test Loss: 0.2340 | Test Acc: 89.81%
# Epoch 371/500 | Train Loss: 0.1976 | Train Acc: 91.89% | Test Loss: 0.2340 | Test Acc: 89.63%
# Epoch 372/500 | Train Loss: 0.1976 | Train Acc: 91.80% | Test Loss: 0.2339 | Test Acc: 89.81%
# Epoch 373/500 | Train Loss: 0.1976 | Train Acc: 91.80% | Test Loss: 0.2338 | Test Acc: 89.63%
# Epoch 374/500 | Train Loss: 0.1975 | Train Acc: 91.85% | Test Loss: 0.2338 | Test Acc: 89.81%
# Epoch 375/500 | Train Loss: 0.1976 | Train Acc: 91.89% | Test Loss: 0.2341 | Test Acc: 89.28%
# Epoch 376/500 | Train Loss: 0.1975 | Train Acc: 91.80% | Test Loss: 0.2338 | Test Acc: 89.81%
# Epoch 377/500 | Train Loss: 0.1976 | Train Acc: 91.89% | Test Loss: 0.2341 | Test Acc: 89.28%
# Epoch 378/500 | Train Loss: 0.1976 | Train Acc: 91.89% | Test Loss: 0.2338 | Test Acc: 89.46%
# Epoch 379/500 | Train Loss: 0.1974 | Train Acc: 91.80% | Test Loss: 0.2338 | Test Acc: 89.81%
# Epoch 380/500 | Train Loss: 0.1974 | Train Acc: 91.85% | Test Loss: 0.2337 | Test Acc: 89.81%
# Epoch 381/500 | Train Loss: 0.1974 | Train Acc: 91.80% | Test Loss: 0.2337 | Test Acc: 89.63%
# Epoch 382/500 | Train Loss: 0.1974 | Train Acc: 91.80% | Test Loss: 0.2337 | Test Acc: 89.81%
# Epoch 383/500 | Train Loss: 0.1973 | Train Acc: 91.89% | Test Loss: 0.2338 | Test Acc: 89.46%
# Epoch 384/500 | Train Loss: 0.1974 | Train Acc: 91.89% | Test Loss: 0.2339 | Test Acc: 89.28%
# Epoch 385/500 | Train Loss: 0.1973 | Train Acc: 91.89% | Test Loss: 0.2337 | Test Acc: 89.46%
# Epoch 386/500 | Train Loss: 0.1974 | Train Acc: 91.80% | Test Loss: 0.2340 | Test Acc: 88.93%
# Epoch 387/500 | Train Loss: 0.1973 | Train Acc: 91.89% | Test Loss: 0.2337 | Test Acc: 89.28%
# Epoch 388/500 | Train Loss: 0.1972 | Train Acc: 91.89% | Test Loss: 0.2337 | Test Acc: 89.28%
# Epoch 389/500 | Train Loss: 0.1972 | Train Acc: 91.93% | Test Loss: 0.2337 | Test Acc: 89.46%
# Epoch 390/500 | Train Loss: 0.1972 | Train Acc: 91.89% | Test Loss: 0.2335 | Test Acc: 89.63%
# Epoch 391/500 | Train Loss: 0.1972 | Train Acc: 91.76% | Test Loss: 0.2334 | Test Acc: 89.81%
# Epoch 392/500 | Train Loss: 0.1972 | Train Acc: 91.89% | Test Loss: 0.2334 | Test Acc: 89.63%
# Epoch 393/500 | Train Loss: 0.1971 | Train Acc: 91.80% | Test Loss: 0.2334 | Test Acc: 89.81%
# Epoch 394/500 | Train Loss: 0.1971 | Train Acc: 91.89% | Test Loss: 0.2335 | Test Acc: 89.46%
# Epoch 395/500 | Train Loss: 0.1971 | Train Acc: 91.93% | Test Loss: 0.2335 | Test Acc: 89.46%
# Epoch 396/500 | Train Loss: 0.1970 | Train Acc: 91.93% | Test Loss: 0.2333 | Test Acc: 89.81%
# Epoch 397/500 | Train Loss: 0.1971 | Train Acc: 91.89% | Test Loss: 0.2336 | Test Acc: 89.10%
# Epoch 398/500 | Train Loss: 0.1970 | Train Acc: 91.89% | Test Loss: 0.2334 | Test Acc: 89.28%
# Epoch 399/500 | Train Loss: 0.1971 | Train Acc: 91.85% | Test Loss: 0.2332 | Test Acc: 89.63%
# Learning rate reduced to: 0.001292
# Epoch 400/500 | Train Loss: 0.1970 | Train Acc: 91.85% | Test Loss: 0.2332 | Test Acc: 89.63%
# Epoch 401/500 | Train Loss: 0.1969 | Train Acc: 91.85% | Test Loss: 0.2332 | Test Acc: 89.81%
# Epoch 402/500 | Train Loss: 0.1969 | Train Acc: 91.93% | Test Loss: 0.2333 | Test Acc: 89.46%
# Epoch 403/500 | Train Loss: 0.1969 | Train Acc: 91.89% | Test Loss: 0.2332 | Test Acc: 89.46%
# Epoch 404/500 | Train Loss: 0.1969 | Train Acc: 91.93% | Test Loss: 0.2333 | Test Acc: 89.46%
# Epoch 405/500 | Train Loss: 0.1969 | Train Acc: 91.89% | Test Loss: 0.2332 | Test Acc: 89.46%
# Epoch 406/500 | Train Loss: 0.1969 | Train Acc: 91.89% | Test Loss: 0.2332 | Test Acc: 89.46%
# Epoch 407/500 | Train Loss: 0.1969 | Train Acc: 91.93% | Test Loss: 0.2332 | Test Acc: 89.46%
# Epoch 408/500 | Train Loss: 0.1969 | Train Acc: 91.93% | Test Loss: 0.2332 | Test Acc: 89.46%
# Epoch 409/500 | Train Loss: 0.1969 | Train Acc: 91.93% | Test Loss: 0.2332 | Test Acc: 89.46%
# Epoch 410/500 | Train Loss: 0.1968 | Train Acc: 91.89% | Test Loss: 0.2331 | Test Acc: 89.46%
# Epoch 411/500 | Train Loss: 0.1968 | Train Acc: 91.93% | Test Loss: 0.2331 | Test Acc: 89.63%
# Epoch 412/500 | Train Loss: 0.1968 | Train Acc: 91.93% | Test Loss: 0.2331 | Test Acc: 89.46%
# Epoch 413/500 | Train Loss: 0.1968 | Train Acc: 91.93% | Test Loss: 0.2330 | Test Acc: 89.46%
# Epoch 414/500 | Train Loss: 0.1968 | Train Acc: 91.93% | Test Loss: 0.2330 | Test Acc: 89.81%
# Epoch 415/500 | Train Loss: 0.1968 | Train Acc: 91.93% | Test Loss: 0.2329 | Test Acc: 89.63%
# Epoch 416/500 | Train Loss: 0.1967 | Train Acc: 91.89% | Test Loss: 0.2329 | Test Acc: 89.81%
# Epoch 417/500 | Train Loss: 0.1968 | Train Acc: 91.85% | Test Loss: 0.2328 | Test Acc: 89.63%
# Epoch 418/500 | Train Loss: 0.1967 | Train Acc: 91.93% | Test Loss: 0.2329 | Test Acc: 89.63%
# Epoch 419/500 | Train Loss: 0.1967 | Train Acc: 91.98% | Test Loss: 0.2330 | Test Acc: 89.46%
# Epoch 420/500 | Train Loss: 0.1967 | Train Acc: 91.93% | Test Loss: 0.2330 | Test Acc: 89.46%
# Epoch 421/500 | Train Loss: 0.1967 | Train Acc: 91.93% | Test Loss: 0.2329 | Test Acc: 89.63%
# Epoch 422/500 | Train Loss: 0.1967 | Train Acc: 91.93% | Test Loss: 0.2329 | Test Acc: 89.63%
# Epoch 423/500 | Train Loss: 0.1966 | Train Acc: 91.93% | Test Loss: 0.2328 | Test Acc: 89.63%
# Epoch 424/500 | Train Loss: 0.1966 | Train Acc: 91.98% | Test Loss: 0.2329 | Test Acc: 89.46%
# Epoch 425/500 | Train Loss: 0.1966 | Train Acc: 91.93% | Test Loss: 0.2328 | Test Acc: 89.63%
# Epoch 426/500 | Train Loss: 0.1966 | Train Acc: 91.93% | Test Loss: 0.2328 | Test Acc: 89.81%
# Epoch 427/500 | Train Loss: 0.1966 | Train Acc: 91.93% | Test Loss: 0.2328 | Test Acc: 89.46%
# Epoch 428/500 | Train Loss: 0.1966 | Train Acc: 91.98% | Test Loss: 0.2328 | Test Acc: 89.46%
# Epoch 429/500 | Train Loss: 0.1966 | Train Acc: 91.98% | Test Loss: 0.2327 | Test Acc: 89.81%
# Epoch 430/500 | Train Loss: 0.1965 | Train Acc: 91.93% | Test Loss: 0.2327 | Test Acc: 89.63%
# Epoch 431/500 | Train Loss: 0.1965 | Train Acc: 91.98% | Test Loss: 0.2328 | Test Acc: 89.46%
# Epoch 432/500 | Train Loss: 0.1966 | Train Acc: 91.98% | Test Loss: 0.2329 | Test Acc: 89.46%
# Epoch 433/500 | Train Loss: 0.1965 | Train Acc: 92.02% | Test Loss: 0.2327 | Test Acc: 89.81%
# Epoch 434/500 | Train Loss: 0.1965 | Train Acc: 91.98% | Test Loss: 0.2328 | Test Acc: 89.46%
# Epoch 435/500 | Train Loss: 0.1965 | Train Acc: 91.98% | Test Loss: 0.2329 | Test Acc: 89.28%
# Epoch 436/500 | Train Loss: 0.1965 | Train Acc: 91.98% | Test Loss: 0.2327 | Test Acc: 89.46%
# Epoch 437/500 | Train Loss: 0.1965 | Train Acc: 91.85% | Test Loss: 0.2326 | Test Acc: 89.81%
# Epoch 438/500 | Train Loss: 0.1964 | Train Acc: 91.98% | Test Loss: 0.2326 | Test Acc: 89.46%
# Epoch 439/500 | Train Loss: 0.1964 | Train Acc: 92.02% | Test Loss: 0.2326 | Test Acc: 89.46%
# Epoch 440/500 | Train Loss: 0.1964 | Train Acc: 91.98% | Test Loss: 0.2326 | Test Acc: 89.46%
# Epoch 441/500 | Train Loss: 0.1964 | Train Acc: 91.89% | Test Loss: 0.2324 | Test Acc: 89.81%
# Epoch 442/500 | Train Loss: 0.1964 | Train Acc: 91.98% | Test Loss: 0.2326 | Test Acc: 89.46%
# Epoch 443/500 | Train Loss: 0.1964 | Train Acc: 91.98% | Test Loss: 0.2325 | Test Acc: 89.46%
# Epoch 444/500 | Train Loss: 0.1964 | Train Acc: 91.98% | Test Loss: 0.2324 | Test Acc: 89.81%
# Epoch 445/500 | Train Loss: 0.1963 | Train Acc: 92.02% | Test Loss: 0.2324 | Test Acc: 89.81%
# Epoch 446/500 | Train Loss: 0.1963 | Train Acc: 91.98% | Test Loss: 0.2325 | Test Acc: 89.46%
# Epoch 447/500 | Train Loss: 0.1963 | Train Acc: 91.98% | Test Loss: 0.2324 | Test Acc: 89.81%
# Epoch 448/500 | Train Loss: 0.1963 | Train Acc: 92.02% | Test Loss: 0.2325 | Test Acc: 89.46%
# Epoch 449/500 | Train Loss: 0.1963 | Train Acc: 92.02% | Test Loss: 0.2325 | Test Acc: 89.46%
# Epoch 450/500 | Train Loss: 0.1964 | Train Acc: 91.89% | Test Loss: 0.2323 | Test Acc: 89.63%
# Epoch 451/500 | Train Loss: 0.1963 | Train Acc: 92.02% | Test Loss: 0.2323 | Test Acc: 89.98%
# Epoch 452/500 | Train Loss: 0.1963 | Train Acc: 91.98% | Test Loss: 0.2323 | Test Acc: 89.81%
# Epoch 453/500 | Train Loss: 0.1962 | Train Acc: 91.98% | Test Loss: 0.2323 | Test Acc: 89.81%
# Epoch 454/500 | Train Loss: 0.1962 | Train Acc: 91.98% | Test Loss: 0.2323 | Test Acc: 89.81%
# Epoch 455/500 | Train Loss: 0.1962 | Train Acc: 92.02% | Test Loss: 0.2323 | Test Acc: 89.46%
# Epoch 456/500 | Train Loss: 0.1962 | Train Acc: 92.02% | Test Loss: 0.2324 | Test Acc: 89.46%
# Epoch 457/500 | Train Loss: 0.1963 | Train Acc: 91.98% | Test Loss: 0.2327 | Test Acc: 89.10%
# Epoch 458/500 | Train Loss: 0.1962 | Train Acc: 92.02% | Test Loss: 0.2324 | Test Acc: 89.46%
# Epoch 459/500 | Train Loss: 0.1961 | Train Acc: 92.06% | Test Loss: 0.2323 | Test Acc: 89.46%
# Epoch 460/500 | Train Loss: 0.1961 | Train Acc: 92.02% | Test Loss: 0.2322 | Test Acc: 89.81%
# Epoch 461/500 | Train Loss: 0.1961 | Train Acc: 92.06% | Test Loss: 0.2323 | Test Acc: 89.46%
# Epoch 462/500 | Train Loss: 0.1961 | Train Acc: 92.06% | Test Loss: 0.2323 | Test Acc: 89.46%
# Epoch 463/500 | Train Loss: 0.1961 | Train Acc: 92.06% | Test Loss: 0.2322 | Test Acc: 89.46%
# Epoch 464/500 | Train Loss: 0.1961 | Train Acc: 91.89% | Test Loss: 0.2321 | Test Acc: 89.63%
# Epoch 465/500 | Train Loss: 0.1961 | Train Acc: 92.06% | Test Loss: 0.2321 | Test Acc: 89.81%
# Epoch 466/500 | Train Loss: 0.1961 | Train Acc: 92.06% | Test Loss: 0.2322 | Test Acc: 89.46%
# Epoch 467/500 | Train Loss: 0.1961 | Train Acc: 92.02% | Test Loss: 0.2321 | Test Acc: 89.98%
# Epoch 468/500 | Train Loss: 0.1960 | Train Acc: 92.06% | Test Loss: 0.2321 | Test Acc: 89.81%
# Epoch 469/500 | Train Loss: 0.1960 | Train Acc: 92.06% | Test Loss: 0.2321 | Test Acc: 89.46%
# Epoch 470/500 | Train Loss: 0.1960 | Train Acc: 92.11% | Test Loss: 0.2321 | Test Acc: 89.81%
# Epoch 471/500 | Train Loss: 0.1960 | Train Acc: 92.06% | Test Loss: 0.2321 | Test Acc: 89.46%
# Epoch 472/500 | Train Loss: 0.1960 | Train Acc: 92.06% | Test Loss: 0.2320 | Test Acc: 89.46%
# Epoch 473/500 | Train Loss: 0.1960 | Train Acc: 92.11% | Test Loss: 0.2320 | Test Acc: 89.81%
# Epoch 474/500 | Train Loss: 0.1959 | Train Acc: 92.06% | Test Loss: 0.2321 | Test Acc: 89.46%
# Epoch 475/500 | Train Loss: 0.1959 | Train Acc: 92.11% | Test Loss: 0.2320 | Test Acc: 89.63%
# Epoch 476/500 | Train Loss: 0.1959 | Train Acc: 92.06% | Test Loss: 0.2320 | Test Acc: 89.46%
# Epoch 477/500 | Train Loss: 0.1959 | Train Acc: 92.06% | Test Loss: 0.2320 | Test Acc: 89.46%
# Epoch 478/500 | Train Loss: 0.1959 | Train Acc: 92.02% | Test Loss: 0.2319 | Test Acc: 89.98%
# Epoch 479/500 | Train Loss: 0.1959 | Train Acc: 92.06% | Test Loss: 0.2319 | Test Acc: 89.46%
# Epoch 480/500 | Train Loss: 0.1959 | Train Acc: 92.06% | Test Loss: 0.2319 | Test Acc: 89.46%
# Epoch 481/500 | Train Loss: 0.1958 | Train Acc: 92.06% | Test Loss: 0.2319 | Test Acc: 89.46%
# Epoch 482/500 | Train Loss: 0.1958 | Train Acc: 92.06% | Test Loss: 0.2318 | Test Acc: 89.46%
# Epoch 483/500 | Train Loss: 0.1958 | Train Acc: 92.11% | Test Loss: 0.2318 | Test Acc: 89.81%
# Epoch 484/500 | Train Loss: 0.1959 | Train Acc: 92.02% | Test Loss: 0.2320 | Test Acc: 89.46%
# Epoch 485/500 | Train Loss: 0.1958 | Train Acc: 92.06% | Test Loss: 0.2319 | Test Acc: 89.46%
# Epoch 486/500 | Train Loss: 0.1958 | Train Acc: 92.06% | Test Loss: 0.2318 | Test Acc: 89.46%
# Epoch 487/500 | Train Loss: 0.1958 | Train Acc: 92.06% | Test Loss: 0.2318 | Test Acc: 89.46%
# Epoch 488/500 | Train Loss: 0.1958 | Train Acc: 92.06% | Test Loss: 0.2317 | Test Acc: 89.63%
# Epoch 489/500 | Train Loss: 0.1958 | Train Acc: 92.02% | Test Loss: 0.2317 | Test Acc: 89.98%
# Epoch 490/500 | Train Loss: 0.1958 | Train Acc: 92.02% | Test Loss: 0.2319 | Test Acc: 89.46%
# Epoch 491/500 | Train Loss: 0.1957 | Train Acc: 92.06% | Test Loss: 0.2317 | Test Acc: 89.46%
# Epoch 492/500 | Train Loss: 0.1957 | Train Acc: 92.11% | Test Loss: 0.2317 | Test Acc: 89.81%
# Epoch 493/500 | Train Loss: 0.1957 | Train Acc: 92.11% | Test Loss: 0.2316 | Test Acc: 89.81%
# Epoch 494/500 | Train Loss: 0.1957 | Train Acc: 92.06% | Test Loss: 0.2316 | Test Acc: 89.98%
# Epoch 495/500 | Train Loss: 0.1957 | Train Acc: 92.11% | Test Loss: 0.2318 | Test Acc: 89.46%
# Epoch 496/500 | Train Loss: 0.1957 | Train Acc: 92.11% | Test Loss: 0.2317 | Test Acc: 89.46%
# Epoch 497/500 | Train Loss: 0.1956 | Train Acc: 92.11% | Test Loss: 0.2317 | Test Acc: 89.46%
# Epoch 498/500 | Train Loss: 0.1956 | Train Acc: 92.11% | Test Loss: 0.2316 | Test Acc: 89.81%
# Epoch 499/500 | Train Loss: 0.1956 | Train Acc: 92.11% | Test Loss: 0.2317 | Test Acc: 89.46%
# Learning rate reduced to: 0.000773
# Epoch 500/500 | Train Loss: 0.1956 | Train Acc: 92.06% | Test Loss: 0.2316 | Test Acc: 89.46%
# Model finished training and validation.

# %% [markdown]
# @function `evaluate_model_performance()`:
#
# * Generates a comprehensive visual report of the model's training history and final classification performance in a 3-row vertical layout.
#
# * **Loss Curve**: Visualizes the relationship between training and validation loss across epochs to detect overfitting or convergence issues.
#
# * **Accuracy Curve** : Tracks the percentage of correct predictions over time for both the training and test sets.
#
# * **Confusion Matrix** : Calculate the classification metrics (TP, TN, FP, FN) and displays them as a Seaborn heatmap for error analysis.
#
# * params
#     * `history`: A dictionary containing the logged lists of loss and accuracy values.
#     * `y_true` : The truth labels from the test dataset.
#     * `y_pred` : The binary predictions (0 or 1) generated by the model.
#     * `title` : string used as the main heading for the entire figure.

# %%
def evaluate_model_performance(history:dict, y_true:list, y_pred:list, title:str):
    # Create a figure within 3 rows
    fig, axes = plt.subplots(3, 1, figsize=(6, 20))
    fig.suptitle(f'Model Evaluation: {title}', fontsize=16, fontweight='bold')

    # --- 1. Loss Curve Plot ---
    train_loss = history['train_loss']
    val_loss = history['test_loss']
    epochs = range(1, len(train_loss) + 1)

    axes[0].plot(epochs, train_loss, label='Training Loss', color='blue', lw=1.5, marker='x', ms=4)
    axes[0].plot(epochs, val_loss, label='Validation Loss', color='orange', lw=1.5, marker='x', ms=4)
    axes[0].set_title('Loss Curve (Learning Curve)')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # --- 2. Accuracy Plot ---
    train_acc = history['train_acc']
    val_acc = history['test_acc']
    axes[1].plot(epochs, train_acc, label='Training Accuracy', color='blue', lw=1.5, marker='x', ms=4)
    axes[1].plot(epochs, val_acc, label='Validation Accuracy', color='orange', lw=1.5, marker='x', ms=4)
    axes[1].set_title('Accuracy Over Epochs')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    # --- 3. Confusion Matrix ---
    actual = np.array(y_true).flatten()
    predicted = np.array(y_pred).flatten()
    
    tp = np.sum((actual == 1) & (predicted == 1))
    tn = np.sum((actual == 0) & (predicted == 0))
    fp = np.sum((actual == 0) & (predicted == 1))
    fn = np.sum((actual == 1) & (predicted == 0))
    cm = np.array([[tn, fp], [fn, tp]])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Stay', 'Churn'], 
            yticklabels=['Stay', 'Churn'],
            ax=axes[2])
    axes[2].set_title('Confusion Matrix: Churn Prediction')
    axes[2].set_ylabel('Actual')
    axes[2].set_xlabel('Predicted')
    # Adjust layout to prevent overlap
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
    
evaluate_model_performance(history, y_test, y_hat, title='Model 1: Binary Cross Entropy')
